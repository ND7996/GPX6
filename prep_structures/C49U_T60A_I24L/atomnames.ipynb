# %%
import os

# Define the base directory containing all PDB subdirectories with minim.pdb files
base_directory = '/home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L'

# Define atom name replacements for residue SEC 49
atom_replacements = {
    'HB3': 'HB2',
    'HB2': 'HB1',  # HB2 should be changed to HB1, but HB1 will be handled separately
    'HG': 'HG1',
    'H': 'HN',
}

def replace_atom_names(pdb_file):
    print(f"Processing file: {pdb_file}")
    output_lines = []

    with open(pdb_file, 'r') as file:
        for line in file:
            # Only consider lines with ATOM and SEC 49
            if line.startswith("ATOM") and " SEC " in line and " 49 " in line:
                # If the atom is HB1, replace it directly with HB2
                if 'HB1' in line:
                    print(f"Original line (HB1): {line.strip()}")
                    line = line.replace('HB1', 'HB2')
                    print(f"Replaced 'HB1' with 'HB2' in line: {line.strip()}")
                # Then proceed with other replacements
                for old_name, new_name in atom_replacements.items():
                    if f" {old_name} " in line:
                        line = line.replace(f" {old_name} ", f" {new_name} ")
                        print(f"Replaced '{old_name}' with '{new_name}' in line: {line.strip()}")

            # Append the line (modified or not) to output
            output_lines.append(line)

    # Write back to the same file to overwrite it
    with open(pdb_file, 'w') as out_file:
        out_file.writelines(output_lines)
    
    print(f"Modified file saved as: {pdb_file}")

# Iterate through all files in the base directory and its subdirectories
for root, dirs, files in os.walk(base_directory):
    for file in files:
        # Check if the file has a '.pdb' extension
        if file.endswith('.pdb'):  
            pdb_filepath = os.path.join(root, file)
            replace_atom_names(pdb_filepath)
# Out:
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/H177Q.pdb
# Replaced 'H' with 'HN' in line: ATOM    737  HN   SEC    49      36.801  34.548  52.492
# Replaced 'HB2' with 'HB1' in line: ATOM    741  HB1 SEC    49      37.385  34.086  49.892
# Replaced 'HB3' with 'HB2' in line: ATOM    742  HB2 SEC    49      36.066  32.883  50.202
# Replaced 'HB2' with 'HB1' in line: ATOM    742  HB1 SEC    49      36.066  32.883  50.202
# Replaced 'HG' with 'HG1' in line: ATOM    744  HG1  SEC    49      39.095  32.573  48.794
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/H177Q.pdb
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/T52A.pdb
# Replaced 'H' with 'HN' in line: ATOM    737  HN   SEC    49      36.801  34.548  52.492
# Replaced 'HB2' with 'HB1' in line: ATOM    741  HB1 SEC    49      37.385  34.086  49.892
# Replaced 'HB3' with 'HB2' in line: ATOM    742  HB2 SEC    49      36.066  32.883  50.202
# Replaced 'HB2' with 'HB1' in line: ATOM    742  HB1 SEC    49      36.066  32.883  50.202
# Replaced 'HG' with 'HG1' in line: ATOM    744  HG1  SEC    49      39.095  32.573  48.794
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/T52A.pdb
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/T178A.pdb
# Replaced 'H' with 'HN' in line: ATOM    737  HN   SEC    49      36.801  34.548  52.492
# Replaced 'HB2' with 'HB1' in line: ATOM    741  HB1 SEC    49      37.385  34.086  49.892
# Replaced 'HB3' with 'HB2' in line: ATOM    742  HB2 SEC    49      36.066  32.883  50.202
# Replaced 'HB2' with 'HB1' in line: ATOM    742  HB1 SEC    49      36.066  32.883  50.202
# Replaced 'HG' with 'HG1' in line: ATOM    744  HG1  SEC    49      39.095  32.573  48.794
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/T178A.pdb
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/P142S.pdb
# Replaced 'H' with 'HN' in line: ATOM    737  HN   SEC    49      36.801  34.548  52.492
# Replaced 'HB2' with 'HB1' in line: ATOM    741  HB1 SEC    49      37.385  34.086  49.892
# Replaced 'HB3' with 'HB2' in line: ATOM    742  HB2 SEC    49      36.066  32.883  50.202
# Replaced 'HB2' with 'HB1' in line: ATOM    742  HB1 SEC    49      36.066  32.883  50.202
# Replaced 'HG' with 'HG1' in line: ATOM    744  HG1  SEC    49      39.095  32.573  48.794
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/P142S.pdb
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/D148E.pdb
# Replaced 'H' with 'HN' in line: ATOM    737  HN   SEC    49      36.801  34.548  52.492
# Replaced 'HB2' with 'HB1' in line: ATOM    741  HB1 SEC    49      37.385  34.086  49.892
# Replaced 'HB3' with 'HB2' in line: ATOM    742  HB2 SEC    49      36.066  32.883  50.202
# Replaced 'HB2' with 'HB1' in line: ATOM    742  HB1 SEC    49      36.066  32.883  50.202
# Replaced 'HG' with 'HG1' in line: ATOM    744  HG1  SEC    49      39.095  32.573  48.794
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/D148E.pdb
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/C49U_T60A_I24L.pdb
# Replaced 'H' with 'HN' in line: ATOM    731  H01 SEC X  49      37.588  31.782  51.957  0.00  0.00           HN
# Replaced 'H' with 'HN' in line: ATOM    732  H02 SEC X  49      39.802  33.368  52.504  0.00  0.00           HN
# Replaced 'H' with 'HN' in line: ATOM    733  H03 SEC X  49      39.568  34.514  52.860  0.00  0.00           HN
# Replaced 'H' with 'HN' in line: ATOM    734  H04 SEC X  49      37.388  34.089  49.905  0.00  0.00           HN
# Replaced 'H' with 'HN' in line: ATOM    735  H05 SEC X  49      36.056  32.957  50.199  0.00  0.00           HN
# Replaced 'H' with 'HN' in line: ATOM    736  H06 SEC X  49      38.008  32.391  47.871  0.00  0.00           HN
# Replaced 'H' with 'HN' in line: ATOM    737  H10 SEC X  49      36.538  34.476  52.387  0.00  0.00           HN
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/C49U_T60A_I24L.pdb
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/T54Q.pdb
# Replaced 'H' with 'HN' in line: ATOM    737  HN   SEC    49      36.801  34.548  52.492
# Replaced 'HB2' with 'HB1' in line: ATOM    741  HB1 SEC    49      37.385  34.086  49.892
# Replaced 'HB3' with 'HB2' in line: ATOM    742  HB2 SEC    49      36.066  32.883  50.202
# Replaced 'HB2' with 'HB1' in line: ATOM    742  HB1 SEC    49      36.066  32.883  50.202
# Replaced 'HG' with 'HG1' in line: ATOM    744  HG1  SEC    49      39.095  32.573  48.794
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/T54Q.pdb
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/R181S.pdb
# Replaced 'H' with 'HN' in line: ATOM    737  HN   SEC    49      36.801  34.548  52.492
# Replaced 'HB2' with 'HB1' in line: ATOM    741  HB1 SEC    49      37.385  34.086  49.892
# Replaced 'HB3' with 'HB2' in line: ATOM    742  HB2 SEC    49      36.066  32.883  50.202
# Replaced 'HB2' with 'HB1' in line: ATOM    742  HB1 SEC    49      36.066  32.883  50.202
# Replaced 'HG' with 'HG1' in line: ATOM    744  HG1  SEC    49      39.095  32.573  48.794
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/R181S.pdb
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/H144Q.pdb
# Replaced 'H' with 'HN' in line: ATOM    737  HN   SEC    49      36.801  34.548  52.492
# Replaced 'HB2' with 'HB1' in line: ATOM    741  HB1 SEC    49      37.385  34.086  49.892
# Replaced 'HB3' with 'HB2' in line: ATOM    742  HB2 SEC    49      36.066  32.883  50.202
# Replaced 'HB2' with 'HB1' in line: ATOM    742  HB1 SEC    49      36.066  32.883  50.202
# Replaced 'HG' with 'HG1' in line: ATOM    744  HG1  SEC    49      39.095  32.573  48.794
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/H144Q.pdb
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/N107S.pdb
# Replaced 'H' with 'HN' in line: ATOM    737  HN   SEC    49      36.801  34.548  52.492
# Replaced 'HB2' with 'HB1' in line: ATOM    741  HB1 SEC    49      37.385  34.086  49.892
# Replaced 'HB3' with 'HB2' in line: ATOM    742  HB2 SEC    49      36.066  32.883  50.202
# Replaced 'HB2' with 'HB1' in line: ATOM    742  HB1 SEC    49      36.066  32.883  50.202
# Replaced 'HG' with 'HG1' in line: ATOM    744  HG1  SEC    49      39.095  32.573  48.794
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/N107S.pdb
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/Y104F.pdb
# Replaced 'H' with 'HN' in line: ATOM    737  HN   SEC    49      36.801  34.548  52.492
# Replaced 'HB2' with 'HB1' in line: ATOM    741  HB1 SEC    49      37.385  34.086  49.892
# Replaced 'HB3' with 'HB2' in line: ATOM    742  HB2 SEC    49      36.066  32.883  50.202
# Replaced 'HB2' with 'HB1' in line: ATOM    742  HB1 SEC    49      36.066  32.883  50.202
# Replaced 'HG' with 'HG1' in line: ATOM    744  HG1  SEC    49      39.095  32.573  48.794
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/Y104F.pdb
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/S4R.pdb
# Replaced 'H' with 'HN' in line: ATOM    737  HN   SEC    49      36.819  34.552  52.515
# Replaced 'HB2' with 'HB1' in line: ATOM    741  HB1 SEC    49      37.385  34.086  49.892
# Replaced 'HB3' with 'HB2' in line: ATOM    742  HB2 SEC    49      36.066  32.883  50.202
# Replaced 'HB2' with 'HB1' in line: ATOM    742  HB1 SEC    49      36.066  32.883  50.202
# Replaced 'HG' with 'HG1' in line: ATOM    744  HG1  SEC    49      39.095  32.573  48.794
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/S4R.pdb
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/S47A.pdb
# Replaced 'H' with 'HN' in line: ATOM    736  HN   SEC    49      36.819  34.552  52.515
# Replaced 'HB2' with 'HB1' in line: ATOM    740  HB1 SEC    49      37.385  34.086  49.892
# Replaced 'HB3' with 'HB2' in line: ATOM    741  HB2 SEC    49      36.066  32.883  50.202
# Replaced 'HB2' with 'HB1' in line: ATOM    741  HB1 SEC    49      36.066  32.883  50.202
# Replaced 'HG' with 'HG1' in line: ATOM    743  HG1  SEC    49      39.095  32.573  48.794
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/S47A.pdb
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/K87T.pdb
# Replaced 'H' with 'HN' in line: ATOM    737  HN   SEC    49      36.801  34.548  52.492
# Replaced 'HB2' with 'HB1' in line: ATOM    741  HB1 SEC    49      37.385  34.086  49.892
# Replaced 'HB3' with 'HB2' in line: ATOM    742  HB2 SEC    49      36.066  32.883  50.202
# Replaced 'HB2' with 'HB1' in line: ATOM    742  HB1 SEC    49      36.066  32.883  50.202
# Replaced 'HG' with 'HG1' in line: ATOM    744  HG1  SEC    49      39.095  32.573  48.794
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/K87T.pdb
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/F48Y.pdb
# Replaced 'H' with 'HN' in line: ATOM    737  HN   SEC    49      36.801  34.548  52.492
# Replaced 'HB2' with 'HB1' in line: ATOM    741  HB1 SEC    49      37.385  34.086  49.892
# Replaced 'HB3' with 'HB2' in line: ATOM    742  HB2 SEC    49      36.066  32.883  50.202
# Replaced 'HB2' with 'HB1' in line: ATOM    742  HB1 SEC    49      36.066  32.883  50.202
# Replaced 'HG' with 'HG1' in line: ATOM    744  HG1  SEC    49      39.095  32.573  48.794
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/F48Y.pdb
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/R99C.pdb
# Replaced 'H' with 'HN' in line: ATOM    737  HN   SEC    49      36.801  34.548  52.492
# Replaced 'HB2' with 'HB1' in line: ATOM    741  HB1 SEC    49      37.385  34.086  49.892
# Replaced 'HB3' with 'HB2' in line: ATOM    742  HB2 SEC    49      36.066  32.883  50.202
# Replaced 'HB2' with 'HB1' in line: ATOM    742  HB1 SEC    49      36.066  32.883  50.202
# Replaced 'HG' with 'HG1' in line: ATOM    744  HG1  SEC    49      39.095  32.573  48.794
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/R99C.pdb
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/G102S.pdb
# Replaced 'H' with 'HN' in line: ATOM    737  HN   SEC    49      36.801  34.548  52.492
# Replaced 'HB2' with 'HB1' in line: ATOM    741  HB1 SEC    49      37.385  34.086  49.892
# Replaced 'HB3' with 'HB2' in line: ATOM    742  HB2 SEC    49      36.066  32.883  50.202
# Replaced 'HB2' with 'HB1' in line: ATOM    742  HB1 SEC    49      36.066  32.883  50.202
# Replaced 'HG' with 'HG1' in line: ATOM    744  HG1  SEC    49      39.095  32.573  48.794
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/G102S.pdb
# Processing file: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/E143S.pdb
# Replaced 'H' with 'HN' in line: ATOM    737  HN   SEC    49      36.801  34.548  52.492
# Replaced 'HB2' with 'HB1' in line: ATOM    741  HB1 SEC    49      37.385  34.086  49.892
# Replaced 'HB3' with 'HB2' in line: ATOM    742  HB2 SEC    49      36.066  32.883  50.202
# Replaced 'HB2' with 'HB1' in line: ATOM    742  HB1 SEC    49      36.066  32.883  50.202
# Replaced 'HG' with 'HG1' in line: ATOM    744  HG1  SEC    49      39.095  32.573  48.794
# Modified file saved as: /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/E143S.pdb
