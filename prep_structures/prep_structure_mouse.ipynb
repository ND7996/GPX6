# %%
import os
from pymol import cmd

# Mapping of one-letter to three-letter amino acid codes
amino_acid_map = {
    'A': 'ALA', 'R': 'ARG', 'N': 'ASN', 'D': 'ASP', 'C': 'CYS', 'E': 'GLU', 
    'Q': 'GLN', 'G': 'GLY', 'H': 'HIS', 'I': 'ILE', 'L': 'LEU', 'K': 'LYS', 
    'M': 'MET', 'F': 'PHE', 'P': 'PRO', 'S': 'SER', 'T': 'THR', 'W': 'TRP', 
    'Y': 'TYR', 'V': 'VAL', 'U': 'SEC'  # Adding SEC for selenocysteine
}

# Mutation list (Mouse Cys -> Human Sec)
mutations_list = [
    (4, 'S', 'R'), (47, 'S', 'A'), (48, 'F', 'Y'), (60, 'T', 'A'), (24, 'I', 'L'),
    (52, 'T', 'A'), (54, 'T', 'Q'), (87, 'K', 'T'), (99, 'R', 'C'),
    (102, 'G', 'S'), (104, 'Y', 'F'), (107, 'N', 'S'), (142, 'P', 'S'), (143, 'E', 'S'),
    (144, 'H', 'Q'), (148, 'D', 'E'), (177, 'H', 'Q'), (178, 'T', 'A'), (139, 'F', 'L'),
    (181, 'R', 'S')
]

# Directory to save the modified structures
output_dir = "/home/hp/nayanika/github/GPX6/prep_structures/48_47_52_99_54_144_177_74_178_143_87_142_104_102_139_24_181_4_60_107"

# Ensure the output directory exists
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Function to mutate residues in a given PDB file
def mutate_residues(pdb_file, mutations):
    """
    Mutate residues in a PDB file using PyMOL and save each mutation as a separate file.
    
    Parameters:
    - pdb_file: Path to the input PDB file.
    - mutations: List of mutation tuples, e.g., [(49, "C", "U")].
    """
    # Load the PDB file
    cmd.load(pdb_file, "structure")
    
    # Loop through each mutation request
    for resi, mouse_residue, human_residue in mutations:
        selection = f"chain X and resi {resi}"  # Apply mutation to chain X
        
        # Check if the current residue matches the intended target
        cmd.wizard("mutagenesis")
        cmd.do(f"select {selection}")
        cmd.get_wizard().do_select(selection)
        
        # Special handling for SEC at position 49
        if resi == 49 and human_residue == 'U':  # Explicitly set residue 49 to SEC
            cmd.alter(selection, "resn='SEC'")
            cmd.alter(f"{selection} and name HB3", "name='HB2'")
            cmd.alter(f"{selection} and name HB2", "name='HB1'")
            cmd.alter(f"{selection} and name HG", "name='HG1'")
            cmd.alter(f"{selection} and name H", "name='HN'")
            print(f"Residue 49 set to SEC with modified atom names.")
        else:
            three_letter_residue = amino_acid_map.get(human_residue, "UNK")
            cmd.get_wizard().set_mode(three_letter_residue)
            cmd.get_wizard().apply()
        
        # Close the mutagenesis wizard
        cmd.set_wizard()
        
        # Remove hydrogens
        cmd.remove("hydro")
        
        # Output file name using residue name and number (e.g., "K3N.pdb" for K->N at residue 3)
        output_file = f"{output_dir}/{mouse_residue}{resi}{human_residue}.pdb"
        
        # Save the mutated structure
        cmd.save(output_file, "structure", format="pdb")
        print(f"Mutation applied at residue {resi}: {mouse_residue} -> {human_residue}. Saved to {output_file}.")
    
    cmd.delete("all")

# Example usage
pdb_file_path = "/home/hp/nayanika/github/GPX6/prep_structures/C49U/C49U.pdb"

# Run the mutation function
mutate_residues(pdb_file_path, mutations_list)
# Out:
# PyMOL>select chain X and resi 4
#  Selector: selection "sele" defined with 11 atoms.
# Selected!
#  Mutagenesis: 3 rotamers loaded.
#  Rotamer 2/3, strain=17.05
#  ExecutiveRMSPairs: RMSD =    0.041 (4 to 4 atoms)
#  Mutagenesis: 27 rotamers loaded.
#  Rotamer 1/27, strain=16.48
# Mutation applied at residue 4: S -> R. Saved to /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/S4R.pdb.
# PyMOL>select chain X and resi 47
# Selected!
#  Selector: selection "sele" defined with 6 atoms.
#  ExecutiveRMSPairs: RMSD =    0.084 (4 to 4 atoms)
#  Mutagenesis: 21 rotamers loaded.
#  Rotamer 17/21, strain=18.03
#  ExecutiveRMSPairs: RMSD =    0.088 (4 to 4 atoms)
#  Mutagenesis: no rotamers found in library.
# Mutation applied at residue 47: S -> A. Saved to /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/S47A.pdb.
# PyMOL>select chain X and resi 48
# Selected!
#  Selector: selection "sele" defined with 11 atoms.
#  ExecutiveRMSPairs: RMSD =    0.041 (4 to 4 atoms)
#  Mutagenesis: no rotamers found in library.
#  ExecutiveRMSPairs: RMSD =    0.073 (4 to 4 atoms)
#  Mutagenesis: 2 rotamers loaded.
#  Rotamer 2/2, strain=16.31
# Mutation applied at residue 48: F -> Y. Saved to /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/F48Y.pdb.
# PyMOL>select chain X and resi 52
#  Selector: selection "sele" defined with 7 atoms.
# Selected!
#  ExecutiveRMSPairs: RMSD =    0.044 (4 to 4 atoms)
#  Mutagenesis: 5 rotamers loaded.
#  Rotamer 4/5, strain=20.04
#  ExecutiveRMSPairs: RMSD =    0.040 (4 to 4 atoms)
#  Mutagenesis: no rotamers found in library.
# Mutation applied at residue 52: T -> A. Saved to /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/T52A.pdb.
# PyMOL>select chain X and resi 54
#  Selector: selection "sele" defined with 7 atoms.
# Selected!
#  ExecutiveRMSPairs: RMSD =    0.080 (4 to 4 atoms)
#  Mutagenesis: no rotamers found in library.
#  ExecutiveRMSPairs: RMSD =    0.085 (4 to 4 atoms)
#  Mutagenesis: 16 rotamers loaded.
#  Rotamer 6/16, strain=18.80
# Mutation applied at residue 54: T -> Q. Saved to /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/T54Q.pdb.
# PyMOL>select chain X and resi 87
#  Selector: selection "sele" defined with 9 atoms.
# Selected!
#  ExecutiveRMSPairs: RMSD =    0.049 (4 to 4 atoms)
#  Mutagenesis: 18 rotamers loaded.
#  Rotamer 7/18, strain=1.03
#  ExecutiveRMSPairs: RMSD =    0.065 (4 to 4 atoms)
#  Mutagenesis: 3 rotamers loaded.
#  Rotamer 1/3, strain=5.61
# Mutation applied at residue 87: K -> T. Saved to /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/K87T.pdb.
# PyMOL>select chain X and resi 99
#  Selector: selection "sele" defined with 11 atoms.
# Selected!
#  ExecutiveRMSPairs: RMSD =    0.037 (4 to 4 atoms)
#  Mutagenesis: 3 rotamers loaded.
#  Rotamer 3/3, strain=33.40
#  ExecutiveRMSPairs: RMSD =    0.039 (4 to 4 atoms)
#  Mutagenesis: 3 rotamers loaded.
#  Rotamer 1/3, strain=35.38
# Mutation applied at residue 99: R -> C. Saved to /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/R99C.pdb.
# PyMOL>select chain X and resi 102
# Selected!
#  Selector: selection "sele" defined with 4 atoms.
#  ExecutiveRMSPairs: RMSD =    0.028 (3 to 3 atoms)
#  Mutagenesis: 2 rotamers loaded.
#  Rotamer 2/2, strain=32.25
#  ExecutiveRMSPairs: RMSD =    0.028 (3 to 3 atoms)
#  Mutagenesis: 3 rotamers loaded.
#  Rotamer 2/3, strain=13.01
# Mutation applied at residue 102: G -> S. Saved to /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/G102S.pdb.
# PyMOL>select chain X and resi 104
# Selected!
#  Selector: selection "sele" defined with 12 atoms.
#  ExecutiveRMSPairs: RMSD =    0.066 (4 to 4 atoms)
#  Mutagenesis: 3 rotamers loaded.
#  Rotamer 1/3, strain=20.15
#  ExecutiveRMSPairs: RMSD =    0.058 (4 to 4 atoms)
#  Mutagenesis: 5 rotamers loaded.
#  Rotamer 1/5, strain=15.97
# Mutation applied at residue 104: Y -> F. Saved to /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/Y104F.pdb.
# PyMOL>select chain X and resi 107
#  Selector: selection "sele" defined with 8 atoms.
# Selected!
#  ExecutiveRMSPairs: RMSD =    0.074 (4 to 4 atoms)
#  Mutagenesis: 4 rotamers loaded.
#  Rotamer 2/4, strain=7.00
#  ExecutiveRMSPairs: RMSD =    0.071 (4 to 4 atoms)
#  Mutagenesis: 3 rotamers loaded.
#  Rotamer 1/3, strain=4.42
# Mutation applied at residue 107: N -> S. Saved to /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/N107S.pdb.
# PyMOL>select chain X and resi 142
#  Selector: selection "sele" defined with 7 atoms.
# Selected!
#  ExecutiveRMSPairs: RMSD =    0.060 (4 to 4 atoms)
#  Mutagenesis: 2 rotamers loaded.
#  Rotamer 1/2, strain=19.30
#  ExecutiveRMSPairs: RMSD =    0.060 (4 to 4 atoms)
#  Mutagenesis: 2 rotamers loaded.
#  Rotamer 1/2, strain=19.30
# Mutation applied at residue 142: P -> S. Saved to /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/P142S.pdb.
# PyMOL>select chain X and resi 143
# Selected!
#  Selector: selection "sele" defined with 9 atoms.
#  ExecutiveRMSPairs: RMSD =    0.059 (4 to 4 atoms)
#  Mutagenesis: 3 rotamers loaded.
#  Rotamer 1/3, strain=19.33
#  ExecutiveRMSPairs: RMSD =    0.059 (4 to 4 atoms)
#  Mutagenesis: 3 rotamers loaded.
#  Rotamer 1/3, strain=19.33
# Mutation applied at residue 143: E -> S. Saved to /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/E143S.pdb.
# PyMOL>select chain X and resi 144
# Selected!
#  Selector: selection "sele" defined with 10 atoms.
#  ExecutiveRMSPairs: RMSD =    0.056 (4 to 4 atoms)
#  Mutagenesis: 3 rotamers loaded.
#  Rotamer 1/3, strain=32.23
#  ExecutiveRMSPairs: RMSD =    0.059 (4 to 4 atoms)
#  Mutagenesis: 15 rotamers loaded.
#  Rotamer 6/15, strain=15.48
# Mutation applied at residue 144: H -> Q. Saved to /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/H144Q.pdb.
# PyMOL>select chain X and resi 148
# Selected!
#  Selector: selection "sele" defined with 8 atoms.
#  ExecutiveRMSPairs: RMSD =    0.035 (4 to 4 atoms)
#  Mutagenesis: 16 rotamers loaded.
#  Rotamer 12/16, strain=27.47
#  ExecutiveRMSPairs: RMSD =    0.034 (4 to 4 atoms)
#  Mutagenesis: 16 rotamers loaded.
#  Rotamer 9/16, strain=20.06
# Mutation applied at residue 148: D -> E. Saved to /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/D148E.pdb.
# PyMOL>select chain X and resi 177
#  Selector: selection "sele" defined with 10 atoms.
# Selected!
#  ExecutiveRMSPairs: RMSD =    0.055 (4 to 4 atoms)
#  Mutagenesis: 15 rotamers loaded.
#  Rotamer 7/15, strain=14.37
#  ExecutiveRMSPairs: RMSD =    0.055 (4 to 4 atoms)
#  Mutagenesis: 16 rotamers loaded.
#  Rotamer 1/16, strain=19.00
# Mutation applied at residue 177: H -> Q. Saved to /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/H177Q.pdb.
# PyMOL>select chain X and resi 178
# Selected!
#  Selector: selection "sele" defined with 7 atoms.
#  ExecutiveRMSPairs: RMSD =    0.064 (4 to 4 atoms)
#  Mutagenesis: 17 rotamers loaded.
#  Rotamer 17/17, strain=18.11
#  ExecutiveRMSPairs: RMSD =    0.077 (4 to 4 atoms)
#  Mutagenesis: no rotamers found in library.
# Mutation applied at residue 178: T -> A. Saved to /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/T178A.pdb.
# PyMOL>select chain X and resi 181
# Selected!
#  Selector: selection "sele" defined with 11 atoms.
#  ExecutiveRMSPairs: RMSD =    0.031 (4 to 4 atoms)
#  Mutagenesis: no rotamers found in library.
#  ExecutiveRMSPairs: RMSD =    0.030 (4 to 4 atoms)
#  Mutagenesis: 3 rotamers loaded.
#  Rotamer 1/3, strain=21.04
# Mutation applied at residue 181: R -> S. Saved to /home/hp/nayanika/github/GPX6/prep_structures/C49U_T60A_I24L/R181S.pdb.
