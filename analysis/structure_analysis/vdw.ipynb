# %%
ion pair and salt bridges
# Out:
# Van der Waals Interactions:
# ------------------------------------------------------------
# Residue    Chain    Distance(Å)  Atoms           VDW Sum(Å)
# ------------------------------------------------------------
# ALA46      X        3.0999999046325684 N-O             3.07
# ALA46      X        3.2300000190734863 CB-O            3.22
# ALA46      X        2.819999933242798 H04-O           2.72
# ALA46      X        2.869999885559082 H05-O           2.72
# ALA46      X        2.369999885559082 H05-H02         2.4
# ALA46      X        2.990000009536743 H10-C           2.9
# ALA46      X        2.240000009536743 H10-O           2.72
# ALA47      X        3.299999952316284 N-C             3.25
# ALA47      X        2.8399999141693115 H10-C           2.9
# TYR48      X        2.809999942779541 N-N             3.1
# TYR48      X        2.450000047683716 N-CA            3.25
# TYR48      X        1.3200000524520874 N-C             3.25
# ...
