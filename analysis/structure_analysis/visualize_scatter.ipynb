# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for each cluster (residue position, residue type, and distance in Å)
cluster_data = {
    0: {
        "residues": [22, 24, 25, 27, 29, 87],
        "distances": [22.91, 18.69, 20.70, 24.28, 26.66, 16.44],
    },
    1: {
        "residues": [3, 4, 173, 177, 178],
        "distances": [19.64, 19.64, 20.19, 11.51, 14.81],
    },
    2: {
        "residues": [16, 30, 31, 33, 35],
        "distances": [27.12, 26.67, 28.12, 30.54, 28.03],
    },
    3: {
        "residues": [137, 139, 142, 143, 144],
        "distances": [21.60, 16.28, 16.44, 15.29, 11.60],
    },
    4: {
        "residues": [40, 69, 71, 74, 107],
        "distances": [23.17, 27.97, 23.11, 14.29, 19.80],
    },
    5: {
        "residues": [67, 192, 194, 195],
        "distances": [30.74, 33.41, 34.61, 35.43],
    },
    6: {
        "residues": [102, 104],
        "distances": [16.77, 16.10],
    },
    7: {
        "residues": [119, 120, 126, 148],
        "distances": [23.30, 22.14, 23.16, 20.84],
    },
    8: {
        "residues": [60, 181, 182, 184, 188],
        "distances": [19.05, 19.54, 20.11, 21.90, 27.64],
    },
    9: {
        "residues": [47, 48, 52, 54, 99],
        "distances": [5.59, 3.88, 5.20, 10.00, 9.50],
    }
}

# Prepare a plot
plt.figure(figsize=(10, 8))

# Define colors for each cluster
cluster_colors = [
    'red', 'blue', 'green', 'yellow', 'cyan', 
    'magenta', 'orange', 'purple', 'lime', 'pink'
]

# Plot data for each cluster
for cluster_id, data in cluster_data.items():
    plt.scatter(
        data["residues"], data["distances"], 
        color=cluster_colors[cluster_id], 
        label=f'Cluster {cluster_id}', 
        s=100, edgecolor='black', linewidth=1
    )

# Add titles and labels
plt.title('Residue Distance by Cluster', fontsize=16)
plt.xlabel('Residue Position', fontsize=14)
plt.ylabel('Distance (Å)', fontsize=14)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Add legend
plt.legend(title='Clusters', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()
