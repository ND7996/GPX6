# %%
import sys
import matplotlib.pyplot as plt
import numpy as np

# Define data according to the given distances
sorted_data = [
    {"mutation": "mousecys", "dg_star": 17.68, "dg_star_error": 0.91, "dg0": -56.96, "dg0_error": 1.03},
    {"mutation": "C49U", "dg_star": 14.84, "dg_star_error": 0.52, "dg0": -62.60, "dg0_error": 0.59},
    {"mutation": "F48Y", "dg_star": 17.38, "dg_star_error": 2.54, "dg0": -55.26, "dg0_error": 1.54},
    {"mutation": "T52A", "dg_star": 16.16, "dg_star_error": 0.89, "dg0": -61.77, "dg0_error": 1.79},
    {"mutation": "S47A", "dg_star": 21.57, "dg_star_error": 2.46, "dg0": -56.18, "dg0_error": 3.49},
    {"mutation": "R99C", "dg_star": 24.29, "dg_star_error": 2.79, "dg0": -55.41, "dg0_error": 3.13},
    {"mutation": "T54Q", "dg_star": 14.62, "dg_star_error": 0.68, "dg0": -55.68, "dg0_error": 3.78},
    {"mutation": "H177Q", "dg_star": 18.66, "dg_star_error": 2.09, "dg0": -55.40, "dg0_error": 3.89},
    {"mutation": "H144Q", "dg_star": 17.66, "dg_star_error": 2.18, "dg0": -53.40, "dg0_error": 3.89},
    {"mutation": "T178A", "dg_star": 14.77, "dg_star_error": 0.51, "dg0": -61.57, "dg0_error": 0.57},
    {"mutation": "A74G", "dg_star" : 15.06, "dg_star_error": 0.90, "dg0": -60.08, "dg0_error": 2.50},
    {"mutation": "E143S", "dg_star": 19.04, "dg_star_error": 1.40, "dg0": -57.10, "dg0_error": 1.56},
    {"mutation": "F139L", "dg_star": 15.72, "dg_star_error": 0.48, "dg0": -54.00, "dg0_error": 1.27},
    {"mutation": "K87T", "dg_star": 18.21, "dg_star_error": 2.52, "dg0": -53.05, "dg0_error": 3.25},
    {"mutation": "P142S", "dg_star": 16.30, "dg_star_error": 0.87, "dg0": -59.56, "dg0_error": 1.10},
    {"mutation": "G102S", "dg_star": 15.83, "dg_star_error": 1.30, "dg0": -59.61, "dg0_error": 1.52},
    {"mutation": "Y104F", "dg_star": 16.94, "dg_star_error": 1.28, "dg0": -58.41, "dg0_error": 1.58},
    {"mutation": "L24I", "dg_star": 15.68, "dg_star_error": 0.94, "dg0": -60.30, "dg0_error": 1.09},
    {"mutation": "T60A", "dg_star": 18.09, "dg_star_error": 1.04, "dg0": -58.09, "dg0_error": 2.08},
    {"mutation": "R181S", "dg_star": 16.38, "dg_star_error": 0.97, "dg0": -60.55, "dg0_error": 1.26},
    {"mutation": "S4R", "dg_star": 17.37, "dg_star_error": 2.94, "dg0": -56.97, "dg0_error": 3.69},
    {"mutation": "N107S", "dg_star": 20.05, "dg_star_error": 2.12, "dg0": -56.09, "dg0_error": 3.33},
]

# Extract data into lists
mutations = [item['mutation'] for item in sorted_data]
dg_star_values = [item['dg_star'] for item in sorted_data]
dg_star_errors = [item['dg_star_error'] for item in sorted_data]
dg0_values = [item['dg0'] for item in sorted_data]
dg0_errors = [item['dg0_error'] for item in sorted_data]

# Mousecys dG* value
mousecys_dg_star = 17.68

# Color scheme: green if dG* < mousecys, blue if dG* > mousecys
colors = ['#2ca02c' if dg_star < mousecys_dg_star else '#1f77b4' for dg_star in dg_star_values]

# Plot the data
fig, ax = plt.subplots(figsize=(20, 10))

x = np.arange(len(mutations))
bar_width = 0.4

# Bar plot for dG*
bars1 = ax.bar(x - bar_width/2, dg_star_values, yerr=dg_star_errors, capsize=5, 
               label="Mean dG*", color=colors, width=bar_width, align='center')

# Bar plot for dG0
bars2 = ax.bar(x + bar_width/2, dg0_values, yerr=dg0_errors, capsize=5,
               color='gray', width=bar_width, align='center', label="Mean dG0")

# Highlight mousecys in red
mousecys_index = mutations.index("mousecys")
bars1[mousecys_index].set_color('red')

# Annotate mousecys threshold
ax.axhline(mousecys_dg_star, color='red', linestyle='--', label=f'Threshold (mousecys dG*) = {mousecys_dg_star:.2f} kcal/mol')

# Formatting
ax.set_xticks(x)
ax.set_xticklabels(mutations, rotation=90, ha="center", fontsize=10)
ax.set_xlabel("Mutation", fontsize=12)
ax.set_ylabel("Free Energy (kcal/mol)", fontsize=12)
ax.set_title("Free Energy Changes for Mouse To Human Mutations", fontsize=16)
ax.legend(loc='upper left', fontsize=10, frameon=True)

# Save the figure
output_path = "/home/hp/nayanika/github/GPX6/figures/mousecys_0_barplot.png"
plt.savefig(output_path, dpi=300, bbox_inches='tight')
print(f"Plot saved to {output_path}")

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Plot saved to /home/hp/nayanika/github/GPX6/figures/mousecys_0_barplot.png

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define data according to the new table, maintaining the original mutation sequence
sorted_data = [
    {"mutation": "mousecys", "dg_star": 17.68, "dg_star_error": 0.91, "dg0": -56.96, "dg0_error": 1.03},
    {"mutation": "C49U", "dg_star": 14.84, "dg_star_error": 0.52, "dg0": -62.60, "dg0_error": 0.59},
    {"mutation": "F48Y", "dg_star": 17.16, "dg_star_error": 1.01, "dg0": -58.24, "dg0_error": 0.96},
    {"mutation": "T52A", "dg_star": 17.83, "dg_star_error": 1.37, "dg0": -57.60, "dg0_error": 1.69},
    {"mutation": "S47A", "dg_star": 19.07, "dg_star_error": 1.20, "dg0": -56.18, "dg0_error": 2.49},
    {"mutation": "R99C", "dg_star": 17.29, "dg_star_error": 2.79, "dg0": -59.41, "dg0_error": 3.13},
    {"mutation": "H177Q", "dg_star": 16.09, "dg_star_error": 1.39, "dg0": -60.31, "dg0_error": 2.04},
    {"mutation": "H144Q", "dg_star": 16.60, "dg_star_error": 1.48, "dg0": -59.10, "dg0_error": 2.02},
    {"mutation": "T178A", "dg_star": 15.41, "dg_star_error": 0.95, "dg0": -60.28, "dg0_error": 1.01},
    {"mutation": "A74G", "dg_star": 17.88, "dg_star_error": 1.52, "dg0": -57.70, "dg0_error": 2.00},
    {"mutation": "E143S", "dg_star": 17.52, "dg_star_error": 1.36, "dg0": -55.99, "dg0_error": 2.94},
    {"mutation": "F139L", "dg_star": 17.01, "dg_star_error": 1.28, "dg0": -58.28, "dg0_error": 1.29},
    {"mutation": "K87T", "dg_star": 20.21, "dg_star_error": 0.52, "dg0": -55.05, "dg0_error": 3.25},
    {"mutation": "P142S", "dg_star": 18.30, "dg_star_error": 1.83, "dg0": -59.56, "dg0_error": 1.10},
    {"mutation": "G102S", "dg_star": 18.72, "dg_star_error": 1.43, "dg0": -57.37, "dg0_error": 1.99},
    {"mutation": "Y104F", "dg_star": 15.75, "dg_star_error": 2.32, "dg0": -59.93, "dg0_error": 3.28},
    {"mutation": "L24I", "dg_star": 17.88, "dg_star_error": 1.52, "dg0": -57.70, "dg0_error": 2.00},
    {"mutation": "T60A", "dg_star": 19.22, "dg_star_error": 1.23, "dg0": -55.88, "dg0_error": 1.48},
    {"mutation": "R181S", "dg_star": 19.38, "dg_star_error": 0.97, "dg0": -62.55, "dg0_error": 1.26},
    {"mutation": "S4R", "dg_star": 15.73, "dg_star_error": 0.64, "dg0": -55.48, "dg0_error": 3.92},
    {"mutation": "N107S", "dg_star": 21.25, "dg_star_error": 2.12, "dg0": -58.09, "dg0_error": 3.30},
]

# Extract data into lists
mutations = [item['mutation'] for item in sorted_data]
dg_star_values = [item['dg_star'] for item in sorted_data]
dg_star_errors = [item['dg_star_error'] for item in sorted_data]
dg0_values = [item['dg0'] for item in sorted_data]
dg0_errors = [item['dg0_error'] for item in sorted_data]

# Mousecys dG* value
mousecys_dg_star = 17.68

# Color scheme: green if dG* < mousecys, blue if dG* > mousecys
colors = ['#2ca02c' if not np.isnan(dg_star) and dg_star < mousecys_dg_star else '#1f77b4' for dg_star in dg_star_values]

# Plot the data
fig, ax = plt.subplots(figsize=(22, 13))

x = np.arange(len(mutations))
bar_width = 0.4

# Bar plot for dG*
bars1 = ax.bar(x - bar_width/2, dg_star_values, yerr=dg_star_errors, capsize=5, 
               label="Mean dG*", color=colors, width=bar_width, align='center')

# Bar plot for dG0
bars2 = ax.bar(x + bar_width/2, dg0_values, yerr=dg0_errors, capsize=5,
               color='gray', width=bar_width, align='center', label="Mean dG0")

# Highlight mousecys in red
mousecys_index = mutations.index("mousecys")
bars1[mousecys_index].set_color('red')

# Annotate mousecys threshold
ax.axhline(mousecys_dg_star, color='red', linestyle='--', label=f'Threshold (mousecys dG*) = {mousecys_dg_star:.2f} kcal/mol')

# Formatting
ax.set_xticks(x)
ax.set_xticklabels(mutations, rotation=90, ha="center", fontsize=10)
ax.set_xlabel("Mutation", fontsize=12)
ax.set_ylabel("Free Energy (kcal/mol)", fontsize=12)
ax.set_title("Free Energy Changes for Mouse To Human Mutations", fontsize=16)
ax.legend(loc='upper left', fontsize=10, frameon=True)

# Save the figure
output_path = "/home/hp/nayanika/github/GPX6/figures/mousecys_1_barplot.png"
plt.savefig(output_path, dpi=300, bbox_inches='tight')
print(f"Plot saved to {output_path}")

# Print confirmation
print(f"Plotting {len(mutations)} mutations in sorted order")

plt.tight_layout()
plt.show()
# Out:
# Plot saved to /home/hp/nayanika/github/GPX6/figures/mousecys_1_barplot.png
# Plotting 21 mutations in sorted order

# %%
import sys
import matplotlib.pyplot as plt
import numpy as np

# Define data according to the new table values
sorted_data = [
    {"mutation": "C49U", "dg_star": 14.84, "dg_star_error": 1.02, "dg0": -61.50, "dg0_error": 0.75},
    {"mutation": "F48Y", "dg_star": 19.51, "dg_star_error": 2.46, "dg0": -57.96, "dg0_error": 2.57},
    {"mutation": "T52A", "dg_star": 22.54, "dg_star_error": 2.29, "dg0": -55.78, "dg0_error": 2.29},
    {"mutation": "S47A", "dg_star": 16.47, "dg_star_error": 0.67, "dg0": -61.31, "dg0_error": 0.68},
    {"mutation": "R99C", "dg_star": 14.48, "dg_star_error": 0.45, "dg0": -61.50, "dg0_error": 0.69},
    {"mutation": "H177Q", "dg_star": 15.53, "dg_star_error": 0.65, "dg0": -61.08, "dg0_error": 0.75},
    {"mutation": "H144Q", "dg_star": 23.14, "dg_star_error": 2.11, "dg0": -52.96, "dg0_error": 2.03},
    {"mutation": "T178A", "dg_star": 14.80, "dg_star_error": 0.54, "dg0": -62.54, "dg0_error": 0.67},
    {"mutation": "A74G", "dg_star": 18.73, "dg_star_error": 1.89, "dg0": -58.21, "dg0_error": 2.28},
    {"mutation": "E143S", "dg_star": 15.54, "dg_star_error": 0.83, "dg0": -61.72, "dg0_error": 1.08},
    {"mutation": "F139L", "dg_star": 19.13, "dg_star_error": 2.19, "dg0": -57.40, "dg0_error": 2.16},
    {"mutation": "K87T", "dg_star": 15.19, "dg_star_error": 0.48, "dg0": -62.04, "dg0_error": 0.79},
    {"mutation": "P142S", "dg_star": 23.40, "dg_star_error": 2.34, "dg0": -54.47, "dg0_error": 2.36},
    {"mutation": "G102S", "dg_star": 15.74, "dg_star_error": 0.56, "dg0": -62.64, "dg0_error": 0.63},
    {"mutation": "Y104F", "dg_star": 14.94, "dg_star_error": 0.68, "dg0": -63.49, "dg0_error": 0.84},
    {"mutation": "L24I", "dg_star": 13.99, "dg_star_error": 1.03, "dg0": -62.10, "dg0_error": 1.04},
    {"mutation": "T60A", "dg_star": 15.22, "dg_star_error": 0.62, "dg0": -61.19, "dg0_error": 0.95},
    {"mutation": "R181S", "dg_star": 15.35, "dg_star_error": 0.75, "dg0": -61.19, "dg0_error": 0.74},
    {"mutation": "S4R", "dg_star": 27.91, "dg_star_error": 1.91, "dg0": -55.34, "dg0_error": 2.95},
    {"mutation": "N107S", "dg_star": 14.57, "dg_star_error": 0.65, "dg0": -62.62, "dg0_error": 0.99},
]

# Rearrange data according to the specified order
ordered_mutations = [
    "C49U", "F48Y", "T52A", "S47A", "R99C", "T54Q", "H177Q", "H144Q", "T178A",
    "A74G", "E143S", "F139L", "K87T", "P142S", "G102S", "Y104F", "L24I", "T60A",
    "R181S", "S4R", "N107S"
]

# Rearranging data based on the specified order
sorted_data = sorted(sorted_data, key=lambda x: ordered_mutations.index(x['mutation']))

# Extract data into lists
mutations = [item['mutation'] for item in sorted_data]
dg_star_values = [item['dg_star'] for item in sorted_data]
dg_star_errors = [item['dg_star_error'] for item in sorted_data]
dg0_values = [item['dg0'] for item in sorted_data]
dg0_errors = [item['dg0_error'] for item in sorted_data]

# Threshold: "C49U" mutation
threshold_mutation = "C49U"
mousecys_dg_star = 14.84  # Replace with the actual value of C49U

# Color scheme: green if dG* < mousecys, blue if dG* > mousecys
colors = ['#2ca02c' if dg_star < mousecys_dg_star else '#1f77b4' for dg_star in dg_star_values]

# Plot the data
fig, ax = plt.subplots(figsize=(20, 10))

x = np.arange(len(mutations))
bar_width = 0.4

# Bar plot for dG*
bars1 = ax.bar(x - bar_width/2, dg_star_values, yerr=dg_star_errors, capsize=5, 
               label="Mean dG*", color=colors, width=bar_width, align='center')

# Bar plot for dG0
bars2 = ax.bar(x + bar_width/2, dg0_values, yerr=dg0_errors, capsize=5,
               color='gray', width=bar_width, align='center', label="Mean dG0")

# Highlight mousecys in red
bars1[mutations.index(threshold_mutation)].set_color('red')

# Annotate threshold
ax.axhline(mousecys_dg_star, color='red', linestyle='--', label=f'Threshold (C49U dG*) = {mousecys_dg_star:.2f} kcal/mol')

# Formatting
ax.set_xticks(x)
ax.set_xticklabels(mutations, rotation=90, ha="center", fontsize=10)
ax.set_xlabel("Mutation", fontsize=12)
ax.set_ylabel("Free Energy (kcal/mol)", fontsize=12)
ax.set_title("Free Energy Changes for Mouse to Human Mutations", fontsize=16)
ax.legend(loc='upper left', fontsize=10, frameon=True)

# Save the figure
output_path = "/home/hp/nayanika/github/GPX6/figures/mousesec_2_barplot.png"
plt.savefig(output_path, dpi=300, bbox_inches='tight')
print(f"Plot saved to {output_path}")

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Plot saved to /home/hp/nayanika/github/GPX6/figures/mousesec_2_barplot.png

# %%
import sys
import matplotlib.pyplot as plt
import numpy as np

# Define data according to the new table values
sorted_data = [
    {"mutation": "C49U", "dg_star": 14.84, "dg_star_error": 1.02, "dg0": -61.50, "dg0_error": 0.75},
    {"mutation": "F48Y", "dg_star": 15.65, "dg_star_error": 0.87, "dg0": -60.30, "dg0_error": 1.09},
    {"mutation": "T52A", "dg_star": 20.54, "dg_star_error": 2.29, "dg0": -58.78, "dg0_error": 2.29},
    {"mutation": "S47A", "dg_star": 17.75, "dg_star_error": 1.05, "dg0": -57.61, "dg0_error": 1.08},
    {"mutation": "R99C", "dg_star": 14.78, "dg_star_error": 0.80, "dg0": -61.20, "dg0_error": 0.60},
    {"mutation": "H177Q", "dg_star": 14.73, "dg_star_error": 0.47, "dg0": -63.48, "dg0_error": 0.89},
    {"mutation": "H144Q", "dg_star": 15.63, "dg_star_error": 0.72, "dg0": -62.39, "dg0_error": 0.97},
    {"mutation": "T178A", "dg_star": 16.67, "dg_star_error": 1.08, "dg0": -59.26, "dg0_error": 1.32},
    {"mutation": "A74G", "dg_star": 19.70, "dg_star_error": 1.89, "dg0": -57.21, "dg0_error": 2.28},
    {"mutation": "E143S", "dg_star": 16.54, "dg_star_error": 0.89, "dg0": -63.72, "dg0_error": 1.08},
    {"mutation": "F139L", "dg_star": 14.69,  "dg_star_error": 0.49, "dg0": -61.98, "dg0_error": 0.85},
    {"mutation": "K87T", "dg_star": 18.29, "dg_star_error": 0.78, "dg0": -63.04, "dg0_error": 0.79},
    {"mutation": "P142S", "dg_star":15.39, "dg_star_error":  0.78, "dg0": -61.25, "dg0_error": 1.32},
    {"mutation": "G102S", "dg_star": 17.44, "dg_star_error": 0.96, "dg0": -60.64, "dg0_error": 0.63},
    {"mutation": "Y104F", "dg_star": 17.94, "dg_star_error": 1.08, "dg0": -61.49, "dg0_error": 0.84},
    {"mutation": "T60A", "dg_star": 16.05, "dg_star_error": 0.73, "dg0": -59.86, "dg0_error": 0.63},
    {"mutation": "R181S", "dg_star": 17.35, "dg_star_error": 0.78, "dg0": -58.19, "dg0_error": 0.74},
    {"mutation": "S4R", "dg_star": 17.20, "dg_star_error": 0.76, "dg0": -59.44, "dg0_error": 1.01},
    {"mutation": "N107S", "dg_star": 15.43, "dg_star_error":  0.57, "dg0": -61.88, "dg0_error": 0.69},
]

# Rearrange data according to the specified order
ordered_mutations = [
    "C49U", "F48Y", "T52A", "S47A", "R99C", "T54Q", "H177Q", "H144Q", "T178A",
    "A74G", "E143S", "F139L", "K87T", "P142S", "G102S", "Y104F", "L24I", "T60A",
    "R181S", "S4R", "N107S"
]

# Rearranging data based on the specified order
sorted_data = sorted(sorted_data, key=lambda x: ordered_mutations.index(x['mutation']))

# Extract data into lists
mutations = [item['mutation'] for item in sorted_data]
dg_star_values = [item['dg_star'] for item in sorted_data]
dg_star_errors = [item['dg_star_error'] for item in sorted_data]
dg0_values = [item['dg0'] for item in sorted_data]
dg0_errors = [item['dg0_error'] for item in sorted_data]

# Threshold: "C49U" mutation
threshold_mutation = "C49U"
mousecys_dg_star = 14.84  # Replace with the actual value of C49U

# Color scheme: green if dG* < mousecys, blue if dG* > mousecys
colors = ['#2ca02c' if dg_star < mousecys_dg_star else '#1f77b4' for dg_star in dg_star_values]

# Plot the data
fig, ax = plt.subplots(figsize=(20, 10))

x = np.arange(len(mutations))
bar_width = 0.4

# Bar plot for dG*
bars1 = ax.bar(x - bar_width/2, dg_star_values, yerr=dg_star_errors, capsize=5, 
               label="Mean dG*", color=colors, width=bar_width, align='center')

# Bar plot for dG0
bars2 = ax.bar(x + bar_width/2, dg0_values, yerr=dg0_errors, capsize=5,
               color='gray', width=bar_width, align='center', label="Mean dG0")

# Highlight mousecys in red
bars1[mutations.index(threshold_mutation)].set_color('red')

# Annotate threshold
ax.axhline(mousecys_dg_star, color='red', linestyle='--', label=f'Threshold (C49U dG*) = {mousecys_dg_star:.2f} kcal/mol')

# Formatting
ax.set_xticks(x)
ax.set_xticklabels(mutations, rotation=90, ha="center", fontsize=10)
ax.set_xlabel("Mutation", fontsize=12)
ax.set_ylabel("Free Energy (kcal/mol)", fontsize=12)
ax.set_title("Free Energy Changes for Mouse to Human Mutations", fontsize=16)
ax.legend(loc='upper left', fontsize=10, frameon=True)

# Save the figure
output_path = "/home/hp/nayanika/github/GPX6/figures/mousesec_3_barplot.png"
plt.savefig(output_path, dpi=300, bbox_inches='tight')
print(f"Plot saved to {output_path}")

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Plot saved to /home/hp/nayanika/github/GPX6/figures/mousesec_3_barplot.png

# %%
import sys
import matplotlib.pyplot as plt
import numpy as np

# Define data according to the new table values
sorted_data = [
    {"mutation": "C49U", "dg_star": 14.84, "dg_star_error": 1.02, "dg0": -61.50, "dg0_error": 0.75},
    {"mutation": "F48Y", "dg_star": 14.50, "dg_star_error": 0.86, "dg0": -62.85, "dg0_error": 0.79},
    {"mutation": "T52A", "dg_star": 14.83, "dg_star_error": 1.00, "dg0": -61.57, "dg0_error": 1.36},
    {"mutation": "S47A", "dg_star": 14.35, "dg_star_error": 0.55, "dg0": -62.66, "dg0_error": 0.76},
    {"mutation": "R99C", "dg_star": 18.48, "dg_star_error": 1.79, "dg0": -58.51, "dg0_error": 2.98},
    {"mutation": "H177Q", "dg_star": 15.05, "dg_star_error": 0.94, "dg0": -61.80, "dg0_error": 1.19},
    {"mutation": "H144Q", "dg_star": 15.28, "dg_star_error": 0.70, "dg0": -62.13, "dg0_error": 0.87},
    {"mutation": "T178A", "dg_star": 23.52, "dg_star_error": 1.56, "dg0": -53.57, "dg0_error": 2.68},
    {"mutation": "A74G", "dg_star": 16.93, "dg_star_error": 0.68, "dg0": -60.28, "dg0_error": 0.93},
    {"mutation": "E143S", "dg_star": 14.75, "dg_star_error": 0.47, "dg0": -57.69, "dg0_error": 2.80},
    {"mutation": "K87T", "dg_star": 15.59, "dg_star_error": 0.76, "dg0": -61.23, "dg0_error": 1.06},
    {"mutation": "P142S", "dg_star": 23.08, "dg_star_error": 2.56, "dg0": -53.30, "dg0_error": 2.65},
    {"mutation": "G102S", "dg_star": 15.09, "dg_star_error": 0.56, "dg0": -58.00, "dg0_error": 2.26},
    {"mutation": "Y104F", "dg_star": 16.16, "dg_star_error": 0.96, "dg0": -61.13, "dg0_error": 0.97},
    {"mutation": "T60A", "dg_star": 19.61, "dg_star_error": 2.21, "dg0": -57.27, "dg0_error": 2.49},
    {"mutation": "R181S", "dg_star": 16.87, "dg_star_error": 0.80, "dg0": -59.32, "dg0_error": 0.88},
    {"mutation": "S4R", "dg_star": 16.36, "dg_star_error": 0.95, "dg0": -61.21, "dg0_error": 1.08},
    {"mutation": "N107S", "dg_star": 19.79, "dg_star_error": 3.84, "dg0": -57.58, "dg0_error": 3.95},
]

# Rearrange data according to the specified order
ordered_mutations = [
    "C49U", "F48Y", "T52A", "S47A", "R99C", "T54Q", "H177Q", "H144Q", "T178A",
    "A74G", "E143S", "F139L", "K87T", "P142S", "G102S", "Y104F", "L24I", "T60A",
    "R181S", "S4R", "N107S"
]

# Rearranging data based on the specified order
sorted_data = sorted(sorted_data, key=lambda x: ordered_mutations.index(x['mutation']))

# Extract data into lists
mutations = [item['mutation'] for item in sorted_data]
dg_star_values = [item['dg_star'] for item in sorted_data]
dg_star_errors = [item['dg_star_error'] for item in sorted_data]
dg0_values = [item['dg0'] for item in sorted_data]
dg0_errors = [item['dg0_error'] for item in sorted_data]

# Threshold: "C49U" mutation
threshold_mutation = "C49U"
mousecys_dg_star = 14.84  # Replace with the actual value of C49U

# Color scheme: green if dG* < mousecys, blue if dG* > mousecys
colors = ['#2ca02c' if dg_star < mousecys_dg_star else '#1f77b4' for dg_star in dg_star_values]

# Plot the data
fig, ax = plt.subplots(figsize=(20, 10))

x = np.arange(len(mutations))
bar_width = 0.4

# Bar plot for dG*
bars1 = ax.bar(x - bar_width/2, dg_star_values, yerr=dg_star_errors, capsize=5, 
               label="Mean dG*", color=colors, width=bar_width, align='center')

# Bar plot for dG0
bars2 = ax.bar(x + bar_width/2, dg0_values, yerr=dg0_errors, capsize=5,
               color='gray', width=bar_width, align='center', label="Mean dG0")

# Highlight mousecys in red
bars1[mutations.index(threshold_mutation)].set_color('red')

# Annotate threshold
ax.axhline(mousecys_dg_star, color='red', linestyle='--', label=f'Threshold (C49U dG*) = {mousecys_dg_star:.2f} kcal/mol')

# Formatting
ax.set_xticks(x)
ax.set_xticklabels(mutations, rotation=90, ha="center", fontsize=10)
ax.set_xlabel("Mutation", fontsize=12)
ax.set_ylabel("Free Energy (kcal/mol)", fontsize=12)
ax.set_title("Free Energy Changes for Mouse to Human Mutations", fontsize=16)
ax.legend(loc='upper left', fontsize=10, frameon=True)

# Save the figure
output_path = "/home/hp/nayanika/github/GPX6/figures/mousesec_4_barplot.png"
plt.savefig(output_path, dpi=300, bbox_inches='tight')
print(f"Plot saved to {output_path}")

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Plot saved to /home/hp/nayanika/github/GPX6/figures/mousesec_4_barplot.png

# %%
import sys
import matplotlib.pyplot as plt
import numpy as np

# Define data according to the new table values
sorted_data = [
    {"mutation": "C49U", "dg_star": 14.84, "dg_star_error": 1.02, "dg0": -61.50, "dg0_error": 0.75},
    {"mutation": "F48Y", "dg_star": 15.16, "dg_star_error": 0.66, "dg0": -57.61, "dg0_error": 2.52},
    {"mutation": "T52A", "dg_star": 16.04, "dg_star_error": 1.02, "dg0": -60.97, "dg0_error": 1.35},
    {"mutation": "R99C", "dg_star": 19.13, "dg_star_error": 2.06, "dg0": -57.60, "dg0_error": 2.30},
    {"mutation": "H177Q", "dg_star": 15.23, "dg_star_error": 0.47, "dg0": -58.75, "dg0_error": 3.95},
    {"mutation": "H144Q", "dg_star": 14.64, "dg_star_error": 0.53, "dg0": -62.96, "dg0_error": 0.86},
    {"mutation": "T178A", "dg_star": 15.21, "dg_star_error": 0.60, "dg0": -61.51, "dg0_error": 0.76},
    {"mutation": "A74G", "dg_star": 17.02, "dg_star_error": 0.96, "dg0": -56.24, "dg0_error": 2.69},
    {"mutation": "E143S", "dg_star": 16.06, "dg_star_error": 1.27, "dg0": -61.12, "dg0_error": 1.63},
    {"mutation": "K87T", "dg_star": 15.98, "dg_star_error": 0.90, "dg0": -61.48, "dg0_error": 1.02},
    {"mutation": "P142S", "dg_star": 18.98, "dg_star_error": 1.93, "dg0": -53.20, "dg0_error": 2.38},
    {"mutation": "G102S", "dg_star": 14.64, "dg_star_error": 0.47, "dg0": -61.97, "dg0_error": 0.73},
    {"mutation": "Y104F", "dg_star": 19.56, "dg_star_error": 4.47, "dg0": -57.44, "dg0_error": 2.17},
    {"mutation": "T60A", "dg_star": 14.37, "dg_star_error": 0.75, "dg0": -59.12, "dg0_error": 2.31},
    {"mutation": "R181S", "dg_star": 14.49, "dg_star_error": 0.43, "dg0": -63.53, "dg0_error": 0.70},
    {"mutation": "S4R", "dg_star": 15.85, "dg_star_error": 0.80, "dg0": -60.66, "dg0_error": 0.74},
    {"mutation": "N107S", "dg_star": 18.58, "dg_star_error": 2.45, "dg0": -59.24, "dg0_error": 2.61},
]

# Rearrange data according to the specified order
ordered_mutations = [
    "C49U", "F48Y", "T52A", "S47A", "R99C", "T54Q", "H177Q", "H144Q", "T178A",
    "A74G", "E143S", "F139L", "K87T", "P142S", "G102S", "Y104F", "L24I", "T60A",
    "R181S", "S4R", "N107S"
]

# Rearranging data based on the specified order
sorted_data = sorted(sorted_data, key=lambda x: ordered_mutations.index(x['mutation']))

# Extract data into lists
mutations = [item['mutation'] for item in sorted_data]
dg_star_values = [item['dg_star'] for item in sorted_data]
dg_star_errors = [item['dg_star_error'] for item in sorted_data]
dg0_values = [item['dg0'] for item in sorted_data]
dg0_errors = [item['dg0_error'] for item in sorted_data]

# Threshold: "C49U" mutation
threshold_mutation = "C49U"
mousecys_dg_star = 14.84  # Replace with the actual value of C49U

# Color scheme: green if dG* < mousecys, blue if dG* > mousecys
colors = ['#2ca02c' if dg_star < mousecys_dg_star else '#1f77b4' for dg_star in dg_star_values]

# Plot the data
fig, ax = plt.subplots(figsize=(20, 10))

x = np.arange(len(mutations))
bar_width = 0.4

# Bar plot for dG*
bars1 = ax.bar(x - bar_width/2, dg_star_values, yerr=dg_star_errors, capsize=5, 
               label="Mean dG*", color=colors, width=bar_width, align='center')

# Bar plot for dG0
bars2 = ax.bar(x + bar_width/2, dg0_values, yerr=dg0_errors, capsize=5,
               color='gray', width=bar_width, align='center', label="Mean dG0")

# Highlight mousecys in red
bars1[mutations.index(threshold_mutation)].set_color('red')

# Annotate threshold
ax.axhline(mousecys_dg_star, color='red', linestyle='--', label=f'Threshold (C49U dG*) = {mousecys_dg_star:.2f} kcal/mol')

# Formatting
ax.set_xticks(x)
ax.set_xticklabels(mutations, rotation=90, ha="center", fontsize=10)
ax.set_xlabel("Mutation", fontsize=12)
ax.set_ylabel("Free Energy (kcal/mol)", fontsize=12)
ax.set_title("Free Energy Changes for Mouse to Human Mutations", fontsize=16)
ax.legend(loc='upper left', fontsize=10, frameon=True)

# Save the figure
output_path = "/home/hp/nayanika/github/GPX6/figures/mousesec_5_barplot.png"
plt.savefig(output_path, dpi=300, bbox_inches='tight')
print(f"Plot saved to {output_path}")

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Plot saved to /home/hp/nayanika/github/GPX6/figures/mousesec_5_barplot.png

# %%
import sys
import matplotlib.pyplot as plt
import numpy as np

# Define data according to the new table values
sorted_data = [
    {"mutation": "C49U", "dg_star": 14.84, "dg_star_error": 1.02, "dg0": -61.50, "dg0_error": 0.75},
    {"mutation": "F48Y", "dg_star": 14.44, "dg_star_error": 0.64, "dg0": -62.46, "dg0_error": 0.44},
    {"mutation": "T52A", "dg_star": 15.05, "dg_star_error": 1.13, "dg0": -60.46, "dg0_error": 1.28},
    {"mutation": "R99C", "dg_star": 14.27, "dg_star_error": 0.96, "dg0": -61.91, "dg0_error": 1.10},
    {"mutation": "H177Q", "dg_star": 15.52, "dg_star_error": 1.01, "dg0": -56.96, "dg0_error": 2.00},
    {"mutation": "H144Q", "dg_star": 13.46, "dg_star_error": 0.88, "dg0": -63.09, "dg0_error": 0.97},
    {"mutation": "T178A", "dg_star": 14.65, "dg_star_error": 0.89, "dg0": -61.32, "dg0_error": 1.29},
    {"mutation": "A74G", "dg_star": 12.98, "dg_star_error": 0.59, "dg0": -62.57, "dg0_error": 0.81},
    {"mutation": "E143S", "dg_star": 19.17, "dg_star_error": 1.06, "dg0": -55.90, "dg0_error": 3.64},
    {"mutation": "K87T", "dg_star": 18.43, "dg_star_error": 1.47, "dg0": -55.73, "dg0_error": 3.18},
    {"mutation": "P142S", "dg_star": 18.37, "dg_star_error": 1.30, "dg0": -58.76, "dg0_error": 2.26},
    {"mutation": "G102S", "dg_star": 17.74, "dg_star_error": 1.49, "dg0": -59.50, "dg0_error": 2.71},
    {"mutation": "Y104F", "dg_star": 19.56, "dg_star_error": 1.47, "dg0": -57.44, "dg0_error": 2.17},
    {"mutation": "R181S", "dg_star": 13.81, "dg_star_error": 0.79, "dg0": -62.22, "dg0_error": 0.82},
    {"mutation": "S4R", "dg_star": 15.50, "dg_star_error": 0.99, "dg0": -60.91, "dg0_error": 1.24},
    {"mutation": "N107S", "dg_star": 13.08, "dg_star_error": 0.41, "dg0": -63.27, "dg0_error": 0.63},
]

# Rearrange data according to the specified order
ordered_mutations = [
    "C49U", "F48Y", "T52A", "S47A", "R99C", "T54Q", "H177Q", "H144Q", "T178A",
    "A74G", "E143S", "F139L", "K87T", "P142S", "G102S", "Y104F", "L24I", "T60A",
    "R181S", "S4R", "N107S"
]

# Rearranging data based on the specified order
sorted_data = sorted(sorted_data, key=lambda x: ordered_mutations.index(x['mutation']))

# Extract data into lists
mutations = [item['mutation'] for item in sorted_data]
dg_star_values = [item['dg_star'] for item in sorted_data]
dg_star_errors = [item['dg_star_error'] for item in sorted_data]
dg0_values = [item['dg0'] for item in sorted_data]
dg0_errors = [item['dg0_error'] for item in sorted_data]

# Threshold: "C49U" mutation
threshold_mutation = "C49U"
mousecys_dg_star = 14.84  # Replace with the actual value of C49U

# Color scheme: green if dG* < mousecys, blue if dG* > mousecys
colors = ['#2ca02c' if dg_star < mousecys_dg_star else '#1f77b4' for dg_star in dg_star_values]

# Plot the data
fig, ax = plt.subplots(figsize=(20, 10))

x = np.arange(len(mutations))
bar_width = 0.4

# Bar plot for dG*
bars1 = ax.bar(x - bar_width/2, dg_star_values, yerr=dg_star_errors, capsize=5, 
               label="Mean dG*", color=colors, width=bar_width, align='center')

# Bar plot for dG0
bars2 = ax.bar(x + bar_width/2, dg0_values, yerr=dg0_errors, capsize=5,
               color='gray', width=bar_width, align='center', label="Mean dG0")

# Highlight mousecys in red
bars1[mutations.index(threshold_mutation)].set_color('red')

# Annotate threshold
ax.axhline(mousecys_dg_star, color='red', linestyle='--', label=f'Threshold (C49U dG*) = {mousecys_dg_star:.2f} kcal/mol')

# Formatting
ax.set_xticks(x)
ax.set_xticklabels(mutations, rotation=90, ha="center", fontsize=10)
ax.set_xlabel("Mutation", fontsize=12)
ax.set_ylabel("Free Energy (kcal/mol)", fontsize=12)
ax.set_title("Free Energy Changes for Mouse to Human Mutations", fontsize=16)
ax.legend(loc='upper left', fontsize=10, frameon=True)

# Save the figure
output_path = "/home/hp/nayanika/github/GPX6/figures/mousesec_6_barplot.png"
plt.savefig(output_path, dpi=300, bbox_inches='tight')
print(f"Plot saved to {output_path}")

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Plot saved to /home/hp/nayanika/github/GPX6/figures/mousesec_6_barplot.png
