# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from io import StringIO

# Function to read and inspect CSV data
def read_and_inspect_csv(file_path):
    try:
        df = pd.read_csv(file_path)
        required_columns = ['Atom', 'X', 'Y', 'Z']
        missing_columns = [col for col in required_columns if col not in df.columns]
        
        if missing_columns:
            raise ValueError(f"Missing columns: {', '.join(missing_columns)}")
        
        return df
    
    except pd.errors.ParserError as e:
        print(f"Error reading file with default settings: {e}.")
        return None
    except Exception as e:
        print(f"Error reading the file: {e}")
        return None

# Function to calculate dipole moment
def calculate_dipole_moment(df, charges):
    df['Charge'] = df['Atom'].apply(lambda atom: charges.get(atom.strip(), 0))
    mu_x = np.sum(df['Charge'] * df['X'])
    mu_y = np.sum(df['Charge'] * df['Y'])
    mu_z = np.sum(df['Charge'] * df['Z'])
    return np.array([mu_x, mu_y, mu_z])

# Function to automate reading from traj folders and calculating average dipole moments
def automate_dipole_moment_calculation(base_dir):
    charges_reactant = {
        'SG': -0.335, 'HG1': 0.155, 'CB': 0.06, 'HB1': 0.06, 'HB2': 0.06, 
        'NE2': -0.76, 'HE21': 0.38, 'HE22': 0.38, 
        'CD': 0.5, 'OE1': -0.5, 'HB2': 0.06, 'CG': -0.12
    }
    charges_product = {
        'SG': -0.9, 'HG1': 0.418, 'CB': -0.3, 'HB1': 0.1, 'HB2': 0.1, 
        'NE2': -0.4965, 'HE21': 0.48, 'HE22': 0.48, 
        'CD': 0.2858, 'OE1': -0.503, 'HB2': 0.06, 'CG': 0.2157
    }

    total_dipole_reactant = np.zeros(3)
    total_dipole_product = np.zeros(3)
    valid_traj_count = 0
    
    for i in range(100):
        traj_folder = os.path.join(base_dir, f'traj{i:02d}')
        reactant_file = os.path.join(traj_folder, 'reactant_qatoms.csv')
        product_file = os.path.join(traj_folder, 'product_qatoms.csv')
        
        if os.path.exists(reactant_file) and os.path.exists(product_file):
            print(f"Processing: {traj_folder}")
            
            df_reactant = read_and_inspect_csv(reactant_file)
            df_product = read_and_inspect_csv(product_file)
            
            if df_reactant is not None and df_product is not None:
                dipole_reactant = calculate_dipole_moment(df_reactant, charges_reactant)
                dipole_product = calculate_dipole_moment(df_product, charges_product)
                
                total_dipole_reactant += dipole_reactant
                total_dipole_product += dipole_product
                valid_traj_count += 1

                print(f"Reactant Dipole Moment (traj{i:02d}): {dipole_reactant}")
                print(f"Product Dipole Moment (traj{i:02d}): {dipole_product}\n")
            else:
                print(f"Skipping: {traj_folder} due to file read errors.")
        else:
            print(f"Skipping: {traj_folder} due to missing files.")
    
    if valid_traj_count > 0:
        # Calculate average dipole moments
        avg_dipole_reactant = total_dipole_reactant / valid_traj_count
        avg_dipole_product = total_dipole_product / valid_traj_count

        print(f"\nAverage Reactant Dipole Moment: {avg_dipole_reactant}")
        print(f"Average Product Dipole Moment: {avg_dipole_product}")
        
        # Calculate and print the angle between the average dipole moments
        norm_reactant = np.linalg.norm(avg_dipole_reactant)
        norm_product = np.linalg.norm(avg_dipole_product)
        
        dipole_reactant_normalized = avg_dipole_reactant / norm_reactant if norm_reactant != 0 else avg_dipole_reactant
        dipole_product_normalized = avg_dipole_product / norm_product if norm_product != 0 else avg_dipole_product

        dot_product = np.dot(dipole_reactant_normalized, dipole_product_normalized)
        angle_radians = np.arccos(np.clip(dot_product, -1.0, 1.0))
        angle_degrees = np.degrees(angle_radians)

        print(f"Angle Between Average Dipole Moments: {angle_degrees:.2f} degrees\n")
    else:
        print("No valid trajectories found.")

# Base directory containing traj folders
base_dir = "/home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_

#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj40
# Reactant Dipole Moment (traj40): [ 7.41264613  6.23505864 11.86337872]
# Product Dipole Moment (traj40): [ 3.98497465  1.05639355 10.83196742]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj41
# Reactant Dipole Moment (traj41): [ 7.5432713   6.07300804 11.95696531]
# Product Dipole Moment (traj41): [ 3.94847184  1.61744744 10.5057306 ]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj42
# Reactant Dipole Moment (traj42): [ 7.47018731  6.08507645 11.93374956]
# Product Dipole Moment (traj42): [ 4.11980075  1.45504845 10.75595315]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj43
# Reactant Dipole Moment (traj43): [ 7.42818565  6.10096852 12.03578388]
# Product Dipole Moment (traj43): [ 3.88143     0.9981347  10.62249259]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj44
# Reactant Dipole Moment (traj44): [ 7.52939863  6.1670152  11.96573896]
# Product Dipole Moment (traj44): [ 3.96068783  1.1454801  10.84768835]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj45
# Reactant Dipole Moment (traj45): [ 7.48952436  6.10789778 11.89197834]
# Product Dipole Moment (traj45): [ 3.55248683  1.42946153 11.22495011]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj46
# Reactant Dipole Moment (traj46): [ 7.4908576   6.19648069 12.01802005]
# Product Dipole Moment (traj46): [ 4.18951004  1.69690479 10.36616762]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj47
# Reactant Dipole Moment (traj47): [ 7.38735803  6.1210004  11.96260851]
# Product Dipole Moment (traj47): [ 4.38525108  2.84609774 11.21971402]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj48
# Reactant Dipole Moment (traj48): [ 7.37946129  6.09768951 11.97097757]
# Product Dipole Moment (traj48): [ 3.67901185  2.66327836 11.41133119]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj49
# Reactant Dipole Moment (traj49): [ 7.45761132  6.06737639 11.8781327 ]
# Product Dipole Moment (traj49): [ 4.34053469  1.68906392 10.52125819]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj50
# Reactant Dipole Moment (traj50): [ 7.4709029   6.08155322 11.94546228]
# Product Dipole Moment (traj50): [ 3.90760272  2.92758796 11.51701543]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj51
# Reactant Dipole Moment (traj51): [ 7.39942948  6.07662955 11.8674952 ]
# Product Dipole Moment (traj51): [ 4.39768519  1.86608142 10.4262502 ]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj52
# Reactant Dipole Moment (traj52): [ 7.35890445  6.04642431 11.9451483 ]
# Product Dipole Moment (traj52): [ 4.39362713  1.16483804 10.34913612]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj53
# Reactant Dipole Moment (traj53): [ 7.45415344  6.06571607 11.94258298]
# Product Dipole Moment (traj53): [ 4.34174671  1.75209157 10.40958252]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj54
# Reactant Dipole Moment (traj54): [ 7.51344993  6.0336207  11.92661299]
# Product Dipole Moment (traj54): [4.44200924 1.34178645 9.95646731]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj55
# Reactant Dipole Moment (traj55): [ 7.45928274  6.06930163 11.85805476]
# Product Dipole Moment (traj55): [4.79070668 1.58165701 9.59188833]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj56
# Reactant Dipole Moment (traj56): [ 7.38002002  6.05194808 11.82214991]
# Product Dipole Moment (traj56): [ 4.41447485  2.28795319 11.20371025]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj57
# Reactant Dipole Moment (traj57): [ 7.26422038  6.01269792 11.81037163]
# Product Dipole Moment (traj57): [ 4.31386218  1.65391136 10.2433998 ]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj58
# Reactant Dipole Moment (traj58): [ 7.4351602   6.09907511 11.94562929]
# Product Dipole Moment (traj58): [ 4.17809037  1.65098715 10.43065418]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj59
# Reactant Dipole Moment (traj59): [ 7.36979225  6.06067121 11.86570196]
# Product Dipole Moment (traj59): [ 3.99258697  2.68256058 11.58779395]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj60
# Reactant Dipole Moment (traj60): [ 7.40831649  6.01785478 11.9326215 ]
# Product Dipole Moment (traj60): [ 4.99683905  1.97818249 10.03216737]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj61
# Reactant Dipole Moment (traj61): [ 7.41507862  5.96531992 11.94544126]
# Product Dipole Moment (traj61): [5.06250752 1.80930629 9.61850303]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj62
# Reactant Dipole Moment (traj62): [ 7.51145359  6.12168981 11.91336208]
# Product Dipole Moment (traj62): [ 3.26666008  2.47391817 11.6319289 ]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj63
# Reactant Dipole Moment (traj63): [ 7.49686317  6.1137789  11.91682617]
# Product Dipole Moment (traj63): [ 4.36338102  2.55043121 11.32565594]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj64
# Reactant Dipole Moment (traj64): [ 7.44558414  6.06345034 11.87181947]
# Product Dipole Moment (traj64): [ 4.51772388  1.21693131 10.30811851]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj65
# Reactant Dipole Moment (traj65): [ 7.4675269   6.06699045 11.87738606]
# Product Dipole Moment (traj65): [4.71359987 1.2701442  9.88409795]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj66
# Reactant Dipole Moment (traj66): [ 7.53556167  6.14349058 12.07208067]
# Product Dipole Moment (traj66): [ 4.48982065  1.41725414 10.42057806]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj67
# Reactant Dipole Moment (traj67): [ 7.47614822  6.08461655 11.84460777]
# Product Dipole Moment (traj67): [ 3.84399227  2.0321698  10.78195071]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj68
# Reactant Dipole Moment (traj68): [ 7.40629078  6.04528199 11.96125607]
# Product Dipole Moment (traj68): [ 4.45989601  1.70363417 10.46148077]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj69
# Reactant Dipole Moment (traj69): [ 7.51176558  6.10587132 11.89741342]
# Product Dipole Moment (traj69): [ 3.97307682  2.14276848 11.7743639 ]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj70
# Reactant Dipole Moment (traj70): [ 7.36270838  6.01814528 11.87895816]
# Product Dipole Moment (traj70): [ 2.99323075  2.23416249 11.41835348]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj71
# Reactant Dipole Moment (traj71): [ 7.42298109  6.09461351 11.95124358]
# Product Dipole Moment (traj71): [3.30730823 2.38566829 7.86506831]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj72
# Reactant Dipole Moment (traj72): [ 7.50237337  6.06513871 11.87218798]
# Product Dipole Moment (traj72): [ 2.67230428  1.89305715 11.48208688]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj73
# Reactant Dipole Moment (traj73): [ 7.40971464  6.03134986 11.84649777]
# Product Dipole Moment (traj73): [ 3.88103848  1.73406413 10.85182825]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj74
# Reactant Dipole Moment (traj74): [ 7.4793157   6.08784299 11.85048086]
# Product Dipole Moment (traj74): [ 4.10833069  0.9485533  10.46993433]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj75
# Reactant Dipole Moment (traj75): [ 7.44140214  6.09053434 11.95824387]
# Product Dipole Moment (traj75): [ 4.25939053  2.62163679 11.44480344]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj76
# Reactant Dipole Moment (traj76): [ 7.48609752  6.1314213  11.91320885]
# Product Dipole Moment (traj76): [ 3.84047393  1.98902754 10.49644496]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj77
# Reactant Dipole Moment (traj77): [ 7.46178121  6.0300662  11.95074865]
# Product Dipole Moment (traj77): [ 4.69365514  1.35732294 10.14164618]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj78
# Reactant Dipole Moment (traj78): [ 7.43373969  6.07936974 11.89645278]
# Product Dipole Moment (traj78): [4.8839255  0.39425954 8.02279651]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj79
# Reactant Dipole Moment (traj79): [ 7.40449806  6.08854168 11.95260882]
# Product Dipole Moment (traj79): [ 4.42447744  1.38939184 10.21436066]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj80
# Reactant Dipole Moment (traj80): [ 7.42475098  6.01864123 11.93919813]
# Product Dipole Moment (traj80): [ 4.27111849  1.28015985 11.03678524]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj81
# Reactant Dipole Moment (traj81): [ 7.40841287  6.18398134 11.9369161 ]
# Product Dipole Moment (traj81): [ 4.23883266  1.36872351 10.05871705]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj82
# Reactant Dipole Moment (traj82): [ 7.44753491  6.06550238 11.89846058]
# Product Dipole Moment (traj82): [ 4.25463163  1.29563839 10.45108151]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj83
# Reactant Dipole Moment (traj83): [ 7.41048698  6.10663871 11.84270467]
# Product Dipole Moment (traj83): [ 4.27772845  1.98870687 10.56996511]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj84
# Reactant Dipole Moment (traj84): [ 7.48659379  6.11277131 12.05262676]
# Product Dipole Moment (traj84): [ 4.23077825  1.22312307 10.12823953]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj85
# Reactant Dipole Moment (traj85): [ 7.43968957  6.07248343 11.91421794]
# Product Dipole Moment (traj85): [ 3.86175074  1.21070921 10.85785544]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj86
# Reactant Dipole Moment (traj86): [ 7.5452269   6.09227564 12.00958807]
# Product Dipole Moment (traj86): [ 4.31744718  1.60637991 10.48030403]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj87
# Reactant Dipole Moment (traj87): [ 7.45778517  6.12456544 11.96689945]
# Product Dipole Moment (traj87): [ 4.59135138  1.6994558  10.22451931]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj88
# Reactant Dipole Moment (traj88): [ 7.52254078  6.12947903 12.05448119]
# Product Dipole Moment (traj88): [ 3.95943293  1.0634372  10.39262375]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj89
# Reactant Dipole Moment (traj89): [ 7.45689258  6.0416809  11.90024562]
# Product Dipole Moment (traj89): [ 4.39113953  1.57851512 10.50848381]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj90
# Reactant Dipole Moment (traj90): [ 7.4702394   6.16709083 11.93546612]
# Product Dipole Moment (traj90): [ 4.26823698  1.64888267 10.49503455]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj91
# Reactant Dipole Moment (traj91): [ 7.4832065   6.09360181 11.85066903]
# Product Dipole Moment (traj91): [3.08900109 1.81461119 7.61403049]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj92
# Reactant Dipole Moment (traj92): [ 7.36666078  6.07377818 11.86640106]
# Product Dipole Moment (traj92): [ 3.36464786  2.39139328 11.31592633]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj93
# Reactant Dipole Moment (traj93): [ 7.44110531  6.08601557 11.84321664]
# Product Dipole Moment (traj93): [3.78033583 2.14119204 9.9836752 ]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj94
# Reactant Dipole Moment (traj94): [ 7.47227976  6.09384752 11.86825594]
# Product Dipole Moment (traj94): [ 3.58830884  1.26347449 11.47796181]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj95
# Reactant Dipole Moment (traj95): [ 7.48167223  6.14010783 12.05167838]
# Product Dipole Moment (traj95): [ 4.49747865  1.66910163 10.36583989]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj96
# Reactant Dipole Moment (traj96): [ 7.52267676  6.19440032 12.00752141]
# Product Dipole Moment (traj96): [ 3.48938665  1.69960769 11.17447923]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj97
# Reactant Dipole Moment (traj97): [ 7.4515935   6.10614956 11.86232849]
# Product Dipole Moment (traj97): [ 4.15498123  2.54364537 11.36182692]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj98
# Reactant Dipole Moment (traj98): [ 7.43765708  6.11831848 12.06481326]
# Product Dipole Moment (traj98): [ 4.60081709  3.07493667 10.83030519]
#
# Processing: /home/hp/nayanika/github/PhD_Thesis/EVB/protein_stepwise/GPX6MUT/combination_4/mousecys/1-prep/47_48_52_54/traj99
# Reactant Dipole Moment (traj99): [ 7.32905799  6.01560044 11.83773629]
# Product Dipole Moment (traj99): [ 4.22352235  1.68399594 10.3228782 ]
#
#
# Average Reactant Dipole Moment: [ 7.44339262  6.08713782 11.93076749]
# Average Product Dipole Moment: [ 4.07400706  1.70539471 10.57676996]
# Angle Between Average Dipole Moments: 18.15 degrees
