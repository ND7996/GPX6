# %%
import os
import shutil
import subprocess

# Directory containing the PDB and solvation files
input_dir = "/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15"

# Output base directory where results will be saved
base_output_dir = "/home/hp/results/MOUSE/level15"

# Directories for the input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genrelax_dir = "/home/hp/nayanika/github/GPX6/input"
topology_dir = "/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15"
fep_dir = "/home/hp/nayanika/github/GPX6/input/fep"  # Correct FEP directory path

os.makedirs(base_output_dir, exist_ok=True)

# Loop through each file in the input directory
for filename in os.listdir(input_dir):
    print(f"Processing file: {filename}")  # Debugging line
    if filename.endswith("_solvated.pdb") or filename.endswith("_solvated.top"):
        system_name = os.path.splitext(filename)[0]  # Extract base name (without extension)

        # Remove the extra '_solvated' if it appears in the system name
        system_name = system_name.replace("_solvated", "")
        
        # Debugging: print the corrected system_name
        print(f"Extracted system name (after fix): {system_name}")
        
        # Define the solvated PDB and TOP file paths
        solvated_pdb_file = os.path.join(input_dir, f"{system_name}_solvated.pdb")
        solvated_top_file = os.path.join(input_dir, f"{system_name}_solvated.top")

        # Debugging: Check the actual paths being checked
        print(f"Checking solvated PDB file: {solvated_pdb_file}")
        print(f"Checking solvated top file: {solvated_top_file}")

        # Check if the solvated PDB and TOP files exist
        if not os.path.isfile(solvated_pdb_file):
            print(f"No solvated PDB file found for {system_name} at {solvated_pdb_file}")
            continue
        if not os.path.isfile(solvated_top_file):
            print(f"No solvated top file found for {system_name} at {solvated_top_file}")
            continue

        # Create a directory for the system in the output directory
        system_output_dir = os.path.join(base_output_dir, system_name)
        os.makedirs(system_output_dir, exist_ok=True)

        # Copy the solvated PDB and solvated TOP files to the system's directory
        shutil.copy(solvated_pdb_file, system_output_dir)
        shutil.copy(solvated_top_file, system_output_dir)

        # Construct the command to run q_genrelax.py
        command = [
            "q_genrelax.py",
            os.path.join(genrelax_dir, "genrelax.proc"),
            "--top", solvated_top_file,
            "--pdb", solvated_pdb_file,
            "--fep", os.path.join(fep_dir, "GPX6_wtmousesec.fep"),
            "--outdir", os.path.join(system_output_dir, "minim"),
            "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
        ]

        # Run the command
        try:
            subprocess.run(command, check=True)
            print(f"Successfully processed {system_name} with solvated files")
        except subprocess.CalledProcessError as e:
            print(f"Error processing {system_name}: {e}")
# Out:
# Processing file: N107S_solvated.top
# Extracted system name (after fix): N107S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/N107S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/N107S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 171919
# # Generated random seed in step 2: 286194
# # Generated random seed in step 3: 876959
# # Generated random seed in step 4: 546446
# # Generated random seed in step 5: 899022
# # Generated random seed in step 6: 631084
# # Generated random seed in step 7: 434837
# # Generated random seed in step 8: 534218
# # Generated random seed in step 9: 467825
# # Generated random seed in step 10: 405296
# # Generated random seed in step 11: 162177
# # Generated random seed in step 12: 271423
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               171919         1.11
# # 2            0.1        0.1        100     1                                       solvent               286194         1.11
# # 3            0.1        0.1        100     1                                       solvent               876959         1.11
# # 4            0.1        0.1        200     1                                       solvent               546446         1.91
# # 5            0.1        0.1        500     1                                       solvent               899022         4.31
# # 6            0.1        0.5      50000     1                                       solvent               631084         4.46
# # 7            0.1        0.1        100                                             solvent               434837         1.11
# # 8            0.1        0.1        100                                             solvent               534218         1.11
# # 9            0.1        0.1        100                                             solvent               467825         1.11
# # 10           0.1        0.1        200                                             solvent               405296         1.91
# # 11           0.1        0.1        500                                             solvent               162177         4.31
# # 12           0.1        0.5      50000                                             solvent               271423         4.46
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.02 MB (trj: 23.4, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed N107S with solvated files
# Processing file: F48Y_qprep.log
# Processing file: F48Y_solvated.pdb
# Extracted system name (after fix): F48Y
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/F48Y_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/F48Y_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 852256
# # Generated random seed in step 2: 795205
# # Generated random seed in step 3: 89420
# # Generated random seed in step 4: 113254
# # Generated random seed in step 5: 431149
# # Generated random seed in step 6: 334579
# # Generated random seed in step 7: 772077
# # Generated random seed in step 8: 735106
# # Generated random seed in step 9: 804327
# # Generated random seed in step 10: 85128
# # Generated random seed in step 11: 732294
# # Generated random seed in step 12: 351266
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               852256         1.11
# # 2            0.1        0.1        100     1                                       solvent               795205         1.11
# # 3            0.1        0.1        100     1                                       solvent               89420          1.11
# # 4            0.1        0.1        200     1                                       solvent               113254         1.91
# # 5            0.1        0.1        500     1                                       solvent               431149         4.31
# # 6            0.1        0.5      50000     1                                       solvent               334579         4.46
# # 7            0.1        0.1        100                                             solvent               772077         1.11
# # 8            0.1        0.1        100                                             solvent               735106         1.11
# # 9            0.1        0.1        100                                             solvent               804327         1.11
# # 10           0.1        0.1        200                                             solvent               85128          1.91
# # 11           0.1        0.1        500                                             solvent               732294         4.31
# # 12           0.1        0.5      50000                                             solvent               351266         4.46
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.02 MB (trj: 23.4, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed F48Y with solvated files
# Processing file: P142S.inp
# Processing file: N107S.inp
# Processing file: P142S.pdb
# Processing file: G102S.inp
# Processing file: P142S_solvated.top
# Extracted system name (after fix): P142S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/P142S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/P142S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 834516
# # Generated random seed in step 2: 119542
# # Generated random seed in step 3: 263780
# # Generated random seed in step 4: 597248
# # Generated random seed in step 5: 189418
# # Generated random seed in step 6: 950853
# # Generated random seed in step 7: 613055
# # Generated random seed in step 8: 1551
# # Generated random seed in step 9: 72783
# # Generated random seed in step 10: 451402
# # Generated random seed in step 11: 84667
# # Generated random seed in step 12: 985969
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               834516         1.11
# # 2            0.1        0.1        100     1                                       solvent               119542         1.11
# # 3            0.1        0.1        100     1                                       solvent               263780         1.11
# # 4            0.1        0.1        200     1                                       solvent               597248         1.91
# # 5            0.1        0.1        500     1                                       solvent               189418         4.31
# # 6            0.1        0.5      50000     1                                       solvent               950853         4.46
# # 7            0.1        0.1        100                                             solvent               613055         1.11
# # 8            0.1        0.1        100                                             solvent                1551          1.11
# # 9            0.1        0.1        100                                             solvent               72783          1.11
# # 10           0.1        0.1        200                                             solvent               451402         1.91
# # 11           0.1        0.1        500                                             solvent               84667          4.31
# # 12           0.1        0.5      50000                                             solvent               985969         4.46
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.02 MB (trj: 23.4, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed P142S with solvated files
# Processing file: G102S_qprep.log
# Processing file: F48Y_solvated.top
# Extracted system name (after fix): F48Y
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/F48Y_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/F48Y_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level15/F48Y/minim' exists. Please (re)move it or set 'outdir'.
# Error processing F48Y: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/F48Y_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/F48Y_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level15/F48Y/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: N107S_qprep.log
# Processing file: R181S_solvated.top
# Extracted system name (after fix): R181S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/R181S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/R181S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 100193
# # Generated random seed in step 2: 218398
# # Generated random seed in step 3: 969842
# # Generated random seed in step 4: 294854
# # Generated random seed in step 5: 956159
# # Generated random seed in step 6: 374143
# # Generated random seed in step 7: 726344
# # Generated random seed in step 8: 928965
# # Generated random seed in step 9: 405547
# # Generated random seed in step 10: 41075
# # Generated random seed in step 11: 222203
# # Generated random seed in step 12: 464415
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               100193         1.11
# # 2            0.1        0.1        100     1                                       solvent               218398         1.11
# # 3            0.1        0.1        100     1                                       solvent               969842         1.11
# # 4            0.1        0.1        200     1                                       solvent               294854         1.91
# # 5            0.1        0.1        500     1                                       solvent               956159         4.30
# # 6            0.1        0.5      50000     1                                       solvent               374143         4.46
# # 7            0.1        0.1        100                                             solvent               726344         1.11
# # 8            0.1        0.1        100                                             solvent               928965         1.11
# # 9            0.1        0.1        100                                             solvent               405547         1.11
# # 10           0.1        0.1        200                                             solvent               41075          1.91
# # 11           0.1        0.1        500                                             solvent               222203         4.30
# # 12           0.1        0.5      50000                                             solvent               464415         4.46
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.00 MB (trj: 23.3, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed R181S with solvated files
# Processing file: R181S_qprep.log
# Processing file: R181S.pdb
# Processing file: N107S.pdb
# Processing file: E143S_solvated.top
# Extracted system name (after fix): E143S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/E143S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/E143S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 821820
# # Generated random seed in step 2: 820210
# # Generated random seed in step 3: 762754
# # Generated random seed in step 4: 913208
# # Generated random seed in step 5: 783418
# # Generated random seed in step 6: 378583
# # Generated random seed in step 7: 132873
# # Generated random seed in step 8: 349419
# # Generated random seed in step 9: 277724
# # Generated random seed in step 10: 371516
# # Generated random seed in step 11: 415123
# # Generated random seed in step 12: 383551
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               821820         1.11
# # 2            0.1        0.1        100     1                                       solvent               820210         1.11
# # 3            0.1        0.1        100     1                                       solvent               762754         1.11
# # 4            0.1        0.1        200     1                                       solvent               913208         1.91
# # 5            0.1        0.1        500     1                                       solvent               783418         4.31
# # 6            0.1        0.5      50000     1                                       solvent               378583         4.46
# # 7            0.1        0.1        100                                             solvent               132873         1.11
# # 8            0.1        0.1        100                                             solvent               349419         1.11
# # 9            0.1        0.1        100                                             solvent               277724         1.11
# # 10           0.1        0.1        200                                             solvent               371516         1.91
# # 11           0.1        0.1        500                                             solvent               415123         4.31
# # 12           0.1        0.5      50000                                             solvent               383551         4.46
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.01 MB (trj: 23.3, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed E143S with solvated files
# Processing file: P142S_solvated.pdb
# Extracted system name (after fix): P142S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/P142S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/P142S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level15/P142S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing P142S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/P142S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/P142S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level15/P142S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: R181S.inp
# Processing file: F48Y.inp
# Processing file: E143S_solvated.pdb
# Extracted system name (after fix): E143S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/E143S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/E143S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level15/E143S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing E143S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/E143S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/E143S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level15/E143S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: G102S_solvated.top
# Extracted system name (after fix): G102S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/G102S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/G102S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 356462
# # Generated random seed in step 2: 601277
# # Generated random seed in step 3: 641849
# # Generated random seed in step 4: 336276
# # Generated random seed in step 5: 479489
# # Generated random seed in step 6: 336896
# # Generated random seed in step 7: 724374
# # Generated random seed in step 8: 644599
# # Generated random seed in step 9: 510155
# # Generated random seed in step 10: 368969
# # Generated random seed in step 11: 906126
# # Generated random seed in step 12: 730531
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               356462         1.11
# # 2            0.1        0.1        100     1                                       solvent               601277         1.11
# # 3            0.1        0.1        100     1                                       solvent               641849         1.11
# # 4            0.1        0.1        200     1                                       solvent               336276         1.91
# # 5            0.1        0.1        500     1                                       solvent               479489         4.31
# # 6            0.1        0.5      50000     1                                       solvent               336896         4.46
# # 7            0.1        0.1        100                                             solvent               724374         1.11
# # 8            0.1        0.1        100                                             solvent               644599         1.11
# # 9            0.1        0.1        100                                             solvent               510155         1.11
# # 10           0.1        0.1        200                                             solvent               368969         1.91
# # 11           0.1        0.1        500                                             solvent               906126         4.31
# # 12           0.1        0.5      50000                                             solvent               730531         4.46
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.02 MB (trj: 23.4, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed G102S with solvated files
# Processing file: R181S_solvated.pdb
# Extracted system name (after fix): R181S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/R181S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/R181S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level15/R181S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing R181S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/R181S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/R181S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level15/R181S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: E143S_qprep.log
# Processing file: N107S_solvated.pdb
# Extracted system name (after fix): N107S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/N107S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/N107S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level15/N107S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing N107S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/N107S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/N107S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level15/N107S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: solvation_log.txt
# Processing file: F48Y.pdb
# Processing file: P142S_qprep.log
# Processing file: G102S.pdb
# Processing file: E143S.inp
# Processing file: E143S.pdb
# Processing file: G102S_solvated.pdb
# Extracted system name (after fix): G102S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/G102S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/G102S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level15/G102S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing G102S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/G102S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level15/G102S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level15/G102S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
