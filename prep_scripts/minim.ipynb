# %%
import os
import shutil
import subprocess

# Directory containing the PDB and solvation files
input_dir = "/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13"

# Output base directory where results will be saved
base_output_dir = "/home/hp/results/HUMAN/level13"

# Directories for the input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genrelax_dir = "/home/hp/nayanika/github/GPX6/input"
topology_dir = "/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13"
fep_dir = "/home/hp/nayanika/github/GPX6/input/fep"  # Correct FEP directory path

os.makedirs(base_output_dir, exist_ok=True)

# Loop through each file in the input directory
for filename in os.listdir(input_dir):
    print(f"Processing file: {filename}")  # Debugging line
    if filename.endswith("_solvated.pdb") or filename.endswith("_solvated.top"):
        system_name = os.path.splitext(filename)[0]  # Extract base name (without extension)

        # Remove the extra '_solvated' if it appears in the system name
        system_name = system_name.replace("_solvated", "")
        
        # Debugging: print the corrected system_name
        print(f"Extracted system name (after fix): {system_name}")
        
        # Define the solvated PDB and TOP file paths
        solvated_pdb_file = os.path.join(input_dir, f"{system_name}_solvated.pdb")
        solvated_top_file = os.path.join(input_dir, f"{system_name}_solvated.top")

        # Debugging: Check the actual paths being checked
        print(f"Checking solvated PDB file: {solvated_pdb_file}")
        print(f"Checking solvated top file: {solvated_top_file}")

        # Check if the solvated PDB and TOP files exist
        if not os.path.isfile(solvated_pdb_file):
            print(f"No solvated PDB file found for {system_name} at {solvated_pdb_file}")
            continue
        if not os.path.isfile(solvated_top_file):
            print(f"No solvated top file found for {system_name} at {solvated_top_file}")
            continue

        # Create a directory for the system in the output directory
        system_output_dir = os.path.join(base_output_dir, system_name)
        os.makedirs(system_output_dir, exist_ok=True)

        # Copy the solvated PDB and solvated TOP files to the system's directory
        shutil.copy(solvated_pdb_file, system_output_dir)
        shutil.copy(solvated_top_file, system_output_dir)

        # Construct the command to run q_genrelax.py
        command = [
            "q_genrelax.py",
            os.path.join(genrelax_dir, "genrelax.proc"),
            "--top", solvated_top_file,
            "--pdb", solvated_pdb_file,
            "--fep", os.path.join(fep_dir, "GPX6_wthumansec.fep"),
            "--outdir", os.path.join(system_output_dir, "minim"),
            "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
        ]

        # Run the command
        try:
            subprocess.run(command, check=True)
            print(f"Successfully processed {system_name} with solvated files")
        except subprocess.CalledProcessError as e:
            print(f"Error processing {system_name}: {e}")
# Out:
# Processing file: Q177H_solvated.pdb
# Extracted system name (after fix): Q177H
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/Q177H_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/Q177H_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 879516
# # Generated random seed in step 2: 692759
# # Generated random seed in step 3: 298947
# # Generated random seed in step 4: 588028
# # Generated random seed in step 5: 831030
# # Generated random seed in step 6: 679010
# # Generated random seed in step 7: 795413
# # Generated random seed in step 8: 783509
# # Generated random seed in step 9: 488924
# # Generated random seed in step 10: 71296
# # Generated random seed in step 11: 399584
# # Generated random seed in step 12: 385951
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               879516         1.12
# # 2            0.1        0.1        100     1                                       solvent               692759         1.12
# # 3            0.1        0.1        100     1                                       solvent               298947         1.12
# # 4            0.1        0.1        200     1                                       solvent               588028         1.93
# # 5            0.1        0.1        500     1                                       solvent               831030         4.35
# # 6            0.1        0.5      50000     1                                       solvent               679010         4.51
# # 7            0.1        0.1        100                                             solvent               795413         1.12
# # 8            0.1        0.1        100                                             solvent               783509         1.12
# # 9            0.1        0.1        100                                             solvent               488924         1.12
# # 10           0.1        0.1        200                                             solvent               71296          1.93
# # 11           0.1        0.1        500                                             solvent               399584         4.35
# # 12           0.1        0.5      50000                                             solvent               385951         4.51
# # Restraints:
# # 1: 1      3098   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.32 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed Q177H with solvated files
# Processing file: A178T_solvated.top
# Extracted system name (after fix): A178T
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/A178T_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/A178T_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 603331
# # Generated random seed in step 2: 526092
# # Generated random seed in step 3: 6702
# # Generated random seed in step 4: 34538
# # Generated random seed in step 5: 284487
# # Generated random seed in step 6: 371543
# # Generated random seed in step 7: 549310
# # Generated random seed in step 8: 559459
# # Generated random seed in step 9: 650279
# # Generated random seed in step 10: 790998
# # Generated random seed in step 11: 631216
# # Generated random seed in step 12: 245526
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               603331         1.12
# # 2            0.1        0.1        100     1                                       solvent               526092         1.12
# # 3            0.1        0.1        100     1                                       solvent                6702          1.12
# # 4            0.1        0.1        200     1                                       solvent               34538          1.93
# # 5            0.1        0.1        500     1                                       solvent               284487         4.36
# # 6            0.1        0.5      50000     1                                       solvent               371543         4.51
# # 7            0.1        0.1        100                                             solvent               549310         1.12
# # 8            0.1        0.1        100                                             solvent               559459         1.12
# # 9            0.1        0.1        100                                             solvent               650279         1.12
# # 10           0.1        0.1        200                                             solvent               790998         1.93
# # 11           0.1        0.1        500                                             solvent               631216         4.36
# # 12           0.1        0.5      50000                                             solvent               245526         4.51
# # Restraints:
# # 1: 1      3098   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.34 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed A178T with solvated files
# Processing file: A74G_solvated.pdb
# Extracted system name (after fix): A74G
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/A74G_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/A74G_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 15285
# # Generated random seed in step 2: 300645
# # Generated random seed in step 3: 201107
# # Generated random seed in step 4: 135968
# # Generated random seed in step 5: 139431
# # Generated random seed in step 6: 454090
# # Generated random seed in step 7: 336595
# # Generated random seed in step 8: 379316
# # Generated random seed in step 9: 293543
# # Generated random seed in step 10: 769817
# # Generated random seed in step 11: 694335
# # Generated random seed in step 12: 499920
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               15285          1.12
# # 2            0.1        0.1        100     1                                       solvent               300645         1.12
# # 3            0.1        0.1        100     1                                       solvent               201107         1.12
# # 4            0.1        0.1        200     1                                       solvent               135968         1.93
# # 5            0.1        0.1        500     1                                       solvent               139431         4.36
# # 6            0.1        0.5      50000     1                                       solvent               454090         4.51
# # 7            0.1        0.1        100                                             solvent               336595         1.12
# # 8            0.1        0.1        100                                             solvent               379316         1.12
# # 9            0.1        0.1        100                                             solvent               293543         1.12
# # 10           0.1        0.1        200                                             solvent               769817         1.93
# # 11           0.1        0.1        500                                             solvent               694335         4.36
# # 12           0.1        0.5      50000                                             solvent               499920         4.51
# # Restraints:
# # 1: 1      3098   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.33 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed A74G with solvated files
# Processing file: L24I_solvated.pdb
# Extracted system name (after fix): L24I
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/L24I_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/L24I_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 570074
# # Generated random seed in step 2: 755269
# # Generated random seed in step 3: 475589
# # Generated random seed in step 4: 894519
# # Generated random seed in step 5: 629971
# # Generated random seed in step 6: 651137
# # Generated random seed in step 7: 404217
# # Generated random seed in step 8: 996538
# # Generated random seed in step 9: 717235
# # Generated random seed in step 10: 387554
# # Generated random seed in step 11: 923294
# # Generated random seed in step 12: 276314
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               570074         1.12
# # 2            0.1        0.1        100     1                                       solvent               755269         1.12
# # 3            0.1        0.1        100     1                                       solvent               475589         1.12
# # 4            0.1        0.1        200     1                                       solvent               894519         1.93
# # 5            0.1        0.1        500     1                                       solvent               629971         4.36
# # 6            0.1        0.5      50000     1                                       solvent               651137         4.51
# # 7            0.1        0.1        100                                             solvent               404217         1.12
# # 8            0.1        0.1        100                                             solvent               996538         1.12
# # 9            0.1        0.1        100                                             solvent               717235         1.12
# # 10           0.1        0.1        200                                             solvent               387554         1.93
# # 11           0.1        0.1        500                                             solvent               923294         4.36
# # 12           0.1        0.5      50000                                             solvent               276314         4.51
# # Restraints:
# # 1: 1      3098   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.33 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed L24I with solvated files
# Processing file: Q177H.inp
# Processing file: S102G_qprep.log
# Processing file: A74G.pdb
# Processing file: A178T_solvated.pdb
# Extracted system name (after fix): A178T
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/A178T_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/A178T_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level13/A178T/minim' exists. Please (re)move it or set 'outdir'.
# Error processing A178T: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/A178T_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/A178T_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level13/A178T/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: S102G_solvated.pdb
# Extracted system name (after fix): S102G
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/S102G_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/S102G_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 889007
# # Generated random seed in step 2: 539549
# # Generated random seed in step 3: 113114
# # Generated random seed in step 4: 265827
# # Generated random seed in step 5: 416474
# # Generated random seed in step 6: 790122
# # Generated random seed in step 7: 219000
# # Generated random seed in step 8: 657867
# # Generated random seed in step 9: 79995
# # Generated random seed in step 10: 691922
# # Generated random seed in step 11: 430371
# # Generated random seed in step 12: 129973
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               889007         1.12
# # 2            0.1        0.1        100     1                                       solvent               539549         1.12
# # 3            0.1        0.1        100     1                                       solvent               113114         1.12
# # 4            0.1        0.1        200     1                                       solvent               265827         1.93
# # 5            0.1        0.1        500     1                                       solvent               416474         4.36
# # 6            0.1        0.5      50000     1                                       solvent               790122         4.51
# # 7            0.1        0.1        100                                             solvent               219000         1.12
# # 8            0.1        0.1        100                                             solvent               657867         1.12
# # 9            0.1        0.1        100                                             solvent               79995          1.12
# # 10           0.1        0.1        200                                             solvent               691922         1.93
# # 11           0.1        0.1        500                                             solvent               430371         4.36
# # 12           0.1        0.5      50000                                             solvent               129973         4.51
# # Restraints:
# # 1: 1      3098   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.33 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed S102G with solvated files
# Processing file: A178T_qprep.log
# Processing file: N3K_qprep.log
# Processing file: A74G_qprep.log
# Processing file: H173R_solvated.top
# Extracted system name (after fix): H173R
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/H173R_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/H173R_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 977682
# # Generated random seed in step 2: 4157
# # Generated random seed in step 3: 380998
# # Generated random seed in step 4: 659067
# # Generated random seed in step 5: 857969
# # Generated random seed in step 6: 740441
# # Generated random seed in step 7: 431345
# # Generated random seed in step 8: 807336
# # Generated random seed in step 9: 814887
# # Generated random seed in step 10: 297540
# # Generated random seed in step 11: 188158
# # Generated random seed in step 12: 783003
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               977682         1.12
# # 2            0.1        0.1        100     1                                       solvent                4157          1.12
# # 3            0.1        0.1        100     1                                       solvent               380998         1.12
# # 4            0.1        0.1        200     1                                       solvent               659067         1.93
# # 5            0.1        0.1        500     1                                       solvent               857969         4.36
# # 6            0.1        0.5      50000     1                                       solvent               740441         4.51
# # 7            0.1        0.1        100                                             solvent               431345         1.12
# # 8            0.1        0.1        100                                             solvent               807336         1.12
# # 9            0.1        0.1        100                                             solvent               814887         1.12
# # 10           0.1        0.1        200                                             solvent               297540         1.93
# # 11           0.1        0.1        500                                             solvent               188158         4.36
# # 12           0.1        0.5      50000                                             solvent               783003         4.51
# # Restraints:
# # 1: 1      3105   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.36 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed H173R with solvated files
# Processing file: L24I_solvated.top
# Extracted system name (after fix): L24I
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/L24I_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/L24I_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level13/L24I/minim' exists. Please (re)move it or set 'outdir'.
# Error processing L24I: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/L24I_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/L24I_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level13/L24I/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: H173R_solvated.pdb
# Extracted system name (after fix): H173R
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/H173R_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/H173R_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level13/H173R/minim' exists. Please (re)move it or set 'outdir'.
# Error processing H173R: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/H173R_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/H173R_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level13/H173R/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: N3K.inp
# Processing file: Q177H_qprep.log
# Processing file: L24I.pdb
# Processing file: Q177H_solvated.top
# Extracted system name (after fix): Q177H
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/Q177H_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/Q177H_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level13/Q177H/minim' exists. Please (re)move it or set 'outdir'.
# Error processing Q177H: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/Q177H_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/Q177H_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level13/Q177H/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: A74G.inp
# Processing file: S102G.pdb
# Processing file: A178T.inp
# Processing file: S102G.inp
# Processing file: H173R_qprep.log
# Processing file: S102G_solvated.top
# Extracted system name (after fix): S102G
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/S102G_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/S102G_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level13/S102G/minim' exists. Please (re)move it or set 'outdir'.
# Error processing S102G: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/S102G_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/S102G_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level13/S102G/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: N3K_solvated.top
# Extracted system name (after fix): N3K
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/N3K_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/N3K_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 305285
# # Generated random seed in step 2: 701306
# # Generated random seed in step 3: 712118
# # Generated random seed in step 4: 779139
# # Generated random seed in step 5: 578382
# # Generated random seed in step 6: 275840
# # Generated random seed in step 7: 920309
# # Generated random seed in step 8: 22320
# # Generated random seed in step 9: 231506
# # Generated random seed in step 10: 336853
# # Generated random seed in step 11: 149713
# # Generated random seed in step 12: 193079
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               305285         1.12
# # 2            0.1        0.1        100     1                                       solvent               701306         1.12
# # 3            0.1        0.1        100     1                                       solvent               712118         1.12
# # 4            0.1        0.1        200     1                                       solvent               779139         1.93
# # 5            0.1        0.1        500     1                                       solvent               578382         4.36
# # 6            0.1        0.5      50000     1                                       solvent               275840         4.51
# # 7            0.1        0.1        100                                             solvent               920309         1.12
# # 8            0.1        0.1        100                                             solvent               22320          1.12
# # 9            0.1        0.1        100                                             solvent               231506         1.12
# # 10           0.1        0.1        200                                             solvent               336853         1.93
# # 11           0.1        0.1        500                                             solvent               149713         4.36
# # 12           0.1        0.5      50000                                             solvent               193079         4.51
# # Restraints:
# # 1: 1      3098   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.35 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed N3K with solvated files
# Processing file: H173R.inp
# Processing file: N3K.pdb
# Processing file: A74G_solvated.top
# Extracted system name (after fix): A74G
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/A74G_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/A74G_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level13/A74G/minim' exists. Please (re)move it or set 'outdir'.
# Error processing A74G: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/A74G_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/A74G_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level13/A74G/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: Q177H.pdb
# Processing file: L24I.inp
# Processing file: H173R.pdb
# Processing file: A178T.pdb
# Processing file: L24I_qprep.log
# Processing file: solvation_log.txt
# Processing file: N3K_solvated.pdb
# Extracted system name (after fix): N3K
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/N3K_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/N3K_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level13/N3K/minim' exists. Please (re)move it or set 'outdir'.
# Error processing N3K: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/N3K_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level13/N3K_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level13/N3K/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
