# %%
import os
import shutil
import subprocess

# Directory containing the PDB and solvation files
input_dir = "/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14"

# Output base directory where results will be saved
base_output_dir = "/home/hp/results/HUMAN/level14"

# Directories for the input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genrelax_dir = "/home/hp/nayanika/github/GPX6/input"
topology_dir = "/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14"
fep_dir = "/home/hp/nayanika/github/GPX6/input/fep"  # Correct FEP directory path

os.makedirs(base_output_dir, exist_ok=True)

# Loop through each file in the input directory
for filename in os.listdir(input_dir):
    print(f"Processing file: {filename}")  # Debugging line
    if filename.endswith("_solvated.pdb") or filename.endswith("_solvated.top"):
        system_name = os.path.splitext(filename)[0]  # Extract base name (without extension)

        # Remove the extra '_solvated' if it appears in the system name
        system_name = system_name.replace("_solvated", "")
        
        # Debugging: print the corrected system_name
        print(f"Extracted system name (after fix): {system_name}")
        
        # Define the solvated PDB and TOP file paths
        solvated_pdb_file = os.path.join(input_dir, f"{system_name}_solvated.pdb")
        solvated_top_file = os.path.join(input_dir, f"{system_name}_solvated.top")

        # Debugging: Check the actual paths being checked
        print(f"Checking solvated PDB file: {solvated_pdb_file}")
        print(f"Checking solvated top file: {solvated_top_file}")

        # Check if the solvated PDB and TOP files exist
        if not os.path.isfile(solvated_pdb_file):
            print(f"No solvated PDB file found for {system_name} at {solvated_pdb_file}")
            continue
        if not os.path.isfile(solvated_top_file):
            print(f"No solvated top file found for {system_name} at {solvated_top_file}")
            continue

        # Create a directory for the system in the output directory
        system_output_dir = os.path.join(base_output_dir, system_name)
        os.makedirs(system_output_dir, exist_ok=True)

        # Copy the solvated PDB and solvated TOP files to the system's directory
        shutil.copy(solvated_pdb_file, system_output_dir)
        shutil.copy(solvated_top_file, system_output_dir)

        # Construct the command to run q_genrelax.py
        command = [
            "q_genrelax.py",
            os.path.join(genrelax_dir, "genrelax.proc"),
            "--top", solvated_top_file,
            "--pdb", solvated_pdb_file,
            "--fep", os.path.join(fep_dir, "GPX6_wthumansec.fep"),
            "--outdir", os.path.join(system_output_dir, "minim"),
            "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
        ]

        # Run the command
        try:
            subprocess.run(command, check=True)
            print(f"Successfully processed {system_name} with solvated files")
        except subprocess.CalledProcessError as e:
            print(f"Error processing {system_name}: {e}")
# Out:
# Processing file: A178T_solvated.top
# Extracted system name (after fix): A178T
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/A178T_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/A178T_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 422663
# # Generated random seed in step 2: 753163
# # Generated random seed in step 3: 149020
# # Generated random seed in step 4: 329810
# # Generated random seed in step 5: 861419
# # Generated random seed in step 6: 43015
# # Generated random seed in step 7: 988263
# # Generated random seed in step 8: 749966
# # Generated random seed in step 9: 621317
# # Generated random seed in step 10: 12604
# # Generated random seed in step 11: 763260
# # Generated random seed in step 12: 192891
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               422663         1.13
# # 2            0.1        0.1        100     1                                       solvent               753163         1.13
# # 3            0.1        0.1        100     1                                       solvent               149020         1.13
# # 4            0.1        0.1        200     1                                       solvent               329810         1.94
# # 5            0.1        0.1        500     1                                       solvent               861419         4.38
# # 6            0.1        0.5      50000     1                                       solvent               43015          4.53
# # 7            0.1        0.1        100                                             solvent               988263         1.13
# # 8            0.1        0.1        100                                             solvent               749966         1.13
# # 9            0.1        0.1        100                                             solvent               621317         1.13
# # 10           0.1        0.1        200                                             solvent               12604          1.94
# # 11           0.1        0.1        500                                             solvent               763260         4.38
# # 12           0.1        0.5      50000                                             solvent               192891         4.53
# # Restraints:
# # 1: 1      3098   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.46 MB (trj: 23.7, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed A178T with solvated files
# Processing file: A74G_solvated.pdb
# Extracted system name (after fix): A74G
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/A74G_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/A74G_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 394012
# # Generated random seed in step 2: 988542
# # Generated random seed in step 3: 550734
# # Generated random seed in step 4: 183778
# # Generated random seed in step 5: 88936
# # Generated random seed in step 6: 730741
# # Generated random seed in step 7: 995580
# # Generated random seed in step 8: 466462
# # Generated random seed in step 9: 497613
# # Generated random seed in step 10: 401367
# # Generated random seed in step 11: 777464
# # Generated random seed in step 12: 357639
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               394012         1.13
# # 2            0.1        0.1        100     1                                       solvent               988542         1.13
# # 3            0.1        0.1        100     1                                       solvent               550734         1.13
# # 4            0.1        0.1        200     1                                       solvent               183778         1.94
# # 5            0.1        0.1        500     1                                       solvent               88936          4.38
# # 6            0.1        0.5      50000     1                                       solvent               730741         4.53
# # 7            0.1        0.1        100                                             solvent               995580         1.13
# # 8            0.1        0.1        100                                             solvent               466462         1.13
# # 9            0.1        0.1        100                                             solvent               497613         1.13
# # 10           0.1        0.1        200                                             solvent               401367         1.94
# # 11           0.1        0.1        500                                             solvent               777464         4.38
# # 12           0.1        0.5      50000                                             solvent               357639         4.53
# # Restraints:
# # 1: 1      3098   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.46 MB (trj: 23.7, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed A74G with solvated files
# Processing file: L24I_solvated.pdb
# Extracted system name (after fix): L24I
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/L24I_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/L24I_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 27938
# # Generated random seed in step 2: 726228
# # Generated random seed in step 3: 226695
# # Generated random seed in step 4: 178816
# # Generated random seed in step 5: 240968
# # Generated random seed in step 6: 484245
# # Generated random seed in step 7: 126543
# # Generated random seed in step 8: 719337
# # Generated random seed in step 9: 769168
# # Generated random seed in step 10: 408782
# # Generated random seed in step 11: 927678
# # Generated random seed in step 12: 541988
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               27938          1.13
# # 2            0.1        0.1        100     1                                       solvent               726228         1.13
# # 3            0.1        0.1        100     1                                       solvent               226695         1.13
# # 4            0.1        0.1        200     1                                       solvent               178816         1.94
# # 5            0.1        0.1        500     1                                       solvent               240968         4.38
# # 6            0.1        0.5      50000     1                                       solvent               484245         4.53
# # 7            0.1        0.1        100                                             solvent               126543         1.13
# # 8            0.1        0.1        100                                             solvent               719337         1.13
# # 9            0.1        0.1        100                                             solvent               769168         1.13
# # 10           0.1        0.1        200                                             solvent               408782         1.94
# # 11           0.1        0.1        500                                             solvent               927678         4.38
# # 12           0.1        0.5      50000                                             solvent               541988         4.53
# # Restraints:
# # 1: 1      3098   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.46 MB (trj: 23.7, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed L24I with solvated files
# Processing file: S102G_qprep.log
# Processing file: A74G.pdb
# Processing file: A178T_solvated.pdb
# Extracted system name (after fix): A178T
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/A178T_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/A178T_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level14/A178T/minim' exists. Please (re)move it or set 'outdir'.
# Error processing A178T: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/A178T_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/A178T_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level14/A178T/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: S102G_solvated.pdb
# Extracted system name (after fix): S102G
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/S102G_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/S102G_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 692387
# # Generated random seed in step 2: 805458
# # Generated random seed in step 3: 621178
# # Generated random seed in step 4: 363866
# # Generated random seed in step 5: 715314
# # Generated random seed in step 6: 483213
# # Generated random seed in step 7: 337587
# # Generated random seed in step 8: 730570
# # Generated random seed in step 9: 460392
# # Generated random seed in step 10: 861946
# # Generated random seed in step 11: 107260
# # Generated random seed in step 12: 833691
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               692387         1.13
# # 2            0.1        0.1        100     1                                       solvent               805458         1.13
# # 3            0.1        0.1        100     1                                       solvent               621178         1.13
# # 4            0.1        0.1        200     1                                       solvent               363866         1.94
# # 5            0.1        0.1        500     1                                       solvent               715314         4.38
# # 6            0.1        0.5      50000     1                                       solvent               483213         4.53
# # 7            0.1        0.1        100                                             solvent               337587         1.13
# # 8            0.1        0.1        100                                             solvent               730570         1.13
# # 9            0.1        0.1        100                                             solvent               460392         1.13
# # 10           0.1        0.1        200                                             solvent               861946         1.94
# # 11           0.1        0.1        500                                             solvent               107260         4.38
# # 12           0.1        0.5      50000                                             solvent               833691         4.53
# # Restraints:
# # 1: 1      3098   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.46 MB (trj: 23.7, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed S102G with solvated files
# Processing file: A178T_qprep.log
# Processing file: N3K_qprep.log
# Processing file: A74G_qprep.log
# Processing file: H173R_solvated.top
# Extracted system name (after fix): H173R
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/H173R_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/H173R_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 857122
# # Generated random seed in step 2: 484747
# # Generated random seed in step 3: 351557
# # Generated random seed in step 4: 564266
# # Generated random seed in step 5: 312400
# # Generated random seed in step 6: 1767
# # Generated random seed in step 7: 471676
# # Generated random seed in step 8: 344045
# # Generated random seed in step 9: 696888
# # Generated random seed in step 10: 225152
# # Generated random seed in step 11: 489559
# # Generated random seed in step 12: 205812
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               857122         1.13
# # 2            0.1        0.1        100     1                                       solvent               484747         1.13
# # 3            0.1        0.1        100     1                                       solvent               351557         1.13
# # 4            0.1        0.1        200     1                                       solvent               564266         1.94
# # 5            0.1        0.1        500     1                                       solvent               312400         4.38
# # 6            0.1        0.5      50000     1                                       solvent                1767          4.53
# # 7            0.1        0.1        100                                             solvent               471676         1.13
# # 8            0.1        0.1        100                                             solvent               344045         1.13
# # 9            0.1        0.1        100                                             solvent               696888         1.13
# # 10           0.1        0.1        200                                             solvent               225152         1.94
# # 11           0.1        0.1        500                                             solvent               489559         4.38
# # 12           0.1        0.5      50000                                             solvent               205812         4.53
# # Restraints:
# # 1: 1      3105   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.49 MB (trj: 23.8, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed H173R with solvated files
# Processing file: L24I_solvated.top
# Extracted system name (after fix): L24I
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/L24I_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/L24I_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level14/L24I/minim' exists. Please (re)move it or set 'outdir'.
# Error processing L24I: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/L24I_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/L24I_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level14/L24I/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: H173R_solvated.pdb
# Extracted system name (after fix): H173R
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/H173R_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/H173R_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level14/H173R/minim' exists. Please (re)move it or set 'outdir'.
# Error processing H173R: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/H173R_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/H173R_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level14/H173R/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: N3K.inp
# Processing file: L24I.pdb
# Processing file: A74G.inp
# Processing file: S102G.pdb
# Processing file: A178T.inp
# Processing file: S102G.inp
# Processing file: H173R_qprep.log
# Processing file: S102G_solvated.top
# Extracted system name (after fix): S102G
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/S102G_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/S102G_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level14/S102G/minim' exists. Please (re)move it or set 'outdir'.
# Error processing S102G: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/S102G_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/S102G_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level14/S102G/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: N3K_solvated.top
# Extracted system name (after fix): N3K
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/N3K_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/N3K_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 552399
# # Generated random seed in step 2: 794949
# # Generated random seed in step 3: 265113
# # Generated random seed in step 4: 559968
# # Generated random seed in step 5: 970148
# # Generated random seed in step 6: 117380
# # Generated random seed in step 7: 998214
# # Generated random seed in step 8: 251451
# # Generated random seed in step 9: 877358
# # Generated random seed in step 10: 104618
# # Generated random seed in step 11: 830583
# # Generated random seed in step 12: 478293
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               552399         1.13
# # 2            0.1        0.1        100     1                                       solvent               794949         1.13
# # 3            0.1        0.1        100     1                                       solvent               265113         1.13
# # 4            0.1        0.1        200     1                                       solvent               559968         1.94
# # 5            0.1        0.1        500     1                                       solvent               970148         4.38
# # 6            0.1        0.5      50000     1                                       solvent               117380         4.53
# # 7            0.1        0.1        100                                             solvent               998214         1.13
# # 8            0.1        0.1        100                                             solvent               251451         1.13
# # 9            0.1        0.1        100                                             solvent               877358         1.13
# # 10           0.1        0.1        200                                             solvent               104618         1.94
# # 11           0.1        0.1        500                                             solvent               830583         4.38
# # 12           0.1        0.5      50000                                             solvent               478293         4.53
# # Restraints:
# # 1: 1      3098   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.46 MB (trj: 23.7, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed N3K with solvated files
# Processing file: H173R.inp
# Processing file: N3K.pdb
# Processing file: A74G_solvated.top
# Extracted system name (after fix): A74G
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/A74G_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/A74G_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level14/A74G/minim' exists. Please (re)move it or set 'outdir'.
# Error processing A74G: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/A74G_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/A74G_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level14/A74G/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: L24I.inp
# Processing file: H173R.pdb
# Processing file: A178T.pdb
# Processing file: L24I_qprep.log
# Processing file: solvation_log.txt
# Processing file: N3K_solvated.pdb
# Extracted system name (after fix): N3K
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/N3K_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/N3K_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level14/N3K/minim' exists. Please (re)move it or set 'outdir'.
# Error processing N3K: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/N3K_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level14/N3K_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level14/N3K/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
