# %%
import os
import shutil
import subprocess

# Directory containing the PDB and solvation files
input_dir = "/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15"

# Output base directory where results will be saved
base_output_dir = "/home/hp/results/HUMAN/level15"

# Directories for the input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genrelax_dir = "/home/hp/nayanika/github/GPX6/input"
topology_dir = "/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15"
fep_dir = "/home/hp/nayanika/github/GPX6/input/fep"  # Correct FEP directory path

os.makedirs(base_output_dir, exist_ok=True)

# Loop through each file in the input directory
for filename in os.listdir(input_dir):
    print(f"Processing file: {filename}")  # Debugging line
    if filename.endswith("_solvated.pdb") or filename.endswith("_solvated.top"):
        system_name = os.path.splitext(filename)[0]  # Extract base name (without extension)

        # Remove the extra '_solvated' if it appears in the system name
        system_name = system_name.replace("_solvated", "")
        
        # Debugging: print the corrected system_name
        print(f"Extracted system name (after fix): {system_name}")
        
        # Define the solvated PDB and TOP file paths
        solvated_pdb_file = os.path.join(input_dir, f"{system_name}_solvated.pdb")
        solvated_top_file = os.path.join(input_dir, f"{system_name}_solvated.top")

        # Debugging: Check the actual paths being checked
        print(f"Checking solvated PDB file: {solvated_pdb_file}")
        print(f"Checking solvated top file: {solvated_top_file}")

        # Check if the solvated PDB and TOP files exist
        if not os.path.isfile(solvated_pdb_file):
            print(f"No solvated PDB file found for {system_name} at {solvated_pdb_file}")
            continue
        if not os.path.isfile(solvated_top_file):
            print(f"No solvated top file found for {system_name} at {solvated_top_file}")
            continue

        # Create a directory for the system in the output directory
        system_output_dir = os.path.join(base_output_dir, system_name)
        os.makedirs(system_output_dir, exist_ok=True)

        # Copy the solvated PDB and solvated TOP files to the system's directory
        shutil.copy(solvated_pdb_file, system_output_dir)
        shutil.copy(solvated_top_file, system_output_dir)

        # Construct the command to run q_genrelax.py
        command = [
            "q_genrelax.py",
            os.path.join(genrelax_dir, "genrelax.proc"),
            "--top", solvated_top_file,
            "--pdb", solvated_pdb_file,
            "--fep", os.path.join(fep_dir, "GPX6_wthumansec.fep"),
            "--outdir", os.path.join(system_output_dir, "minim"),
            "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
        ]

        # Run the command
        try:
            subprocess.run(command, check=True)
            print(f"Successfully processed {system_name} with solvated files")
        except subprocess.CalledProcessError as e:
            print(f"Error processing {system_name}: {e}")
# Out:
# Processing file: A178T_solvated.top
# Extracted system name (after fix): A178T
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/A178T_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/A178T_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 346114
# # Generated random seed in step 2: 36093
# # Generated random seed in step 3: 370717
# # Generated random seed in step 4: 707893
# # Generated random seed in step 5: 953589
# # Generated random seed in step 6: 179745
# # Generated random seed in step 7: 287704
# # Generated random seed in step 8: 655917
# # Generated random seed in step 9: 672015
# # Generated random seed in step 10: 52724
# # Generated random seed in step 11: 914229
# # Generated random seed in step 12: 641013
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               346114         1.13
# # 2            0.1        0.1        100     1                                       solvent               36093          1.13
# # 3            0.1        0.1        100     1                                       solvent               370717         1.13
# # 4            0.1        0.1        200     1                                       solvent               707893         1.94
# # 5            0.1        0.1        500     1                                       solvent               953589         4.37
# # 6            0.1        0.5      50000     1                                       solvent               179745         4.53
# # 7            0.1        0.1        100                                             solvent               287704         1.13
# # 8            0.1        0.1        100                                             solvent               655917         1.13
# # 9            0.1        0.1        100                                             solvent               672015         1.13
# # 10           0.1        0.1        200                                             solvent               52724          1.94
# # 11           0.1        0.1        500                                             solvent               914229         4.37
# # 12           0.1        0.5      50000                                             solvent               641013         4.53
# # Restraints:
# # 1: 1      3098   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.45 MB (trj: 23.7, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed A178T with solvated files
# Processing file: A74G_solvated.pdb
# Extracted system name (after fix): A74G
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/A74G_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/A74G_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 619288
# # Generated random seed in step 2: 349526
# # Generated random seed in step 3: 205845
# # Generated random seed in step 4: 399022
# # Generated random seed in step 5: 422253
# # Generated random seed in step 6: 967923
# # Generated random seed in step 7: 486483
# # Generated random seed in step 8: 168415
# # Generated random seed in step 9: 564840
# # Generated random seed in step 10: 984630
# # Generated random seed in step 11: 356108
# # Generated random seed in step 12: 172855
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               619288         1.13
# # 2            0.1        0.1        100     1                                       solvent               349526         1.13
# # 3            0.1        0.1        100     1                                       solvent               205845         1.13
# # 4            0.1        0.1        200     1                                       solvent               399022         1.94
# # 5            0.1        0.1        500     1                                       solvent               422253         4.37
# # 6            0.1        0.5      50000     1                                       solvent               967923         4.53
# # 7            0.1        0.1        100                                             solvent               486483         1.13
# # 8            0.1        0.1        100                                             solvent               168415         1.13
# # 9            0.1        0.1        100                                             solvent               564840         1.13
# # 10           0.1        0.1        200                                             solvent               984630         1.94
# # 11           0.1        0.1        500                                             solvent               356108         4.37
# # 12           0.1        0.5      50000                                             solvent               172855         4.53
# # Restraints:
# # 1: 1      3098   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.45 MB (trj: 23.7, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed A74G with solvated files
# Processing file: L24I_solvated.pdb
# Extracted system name (after fix): L24I
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/L24I_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/L24I_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 387861
# # Generated random seed in step 2: 520293
# # Generated random seed in step 3: 517597
# # Generated random seed in step 4: 860315
# # Generated random seed in step 5: 630459
# # Generated random seed in step 6: 725374
# # Generated random seed in step 7: 344074
# # Generated random seed in step 8: 418453
# # Generated random seed in step 9: 253482
# # Generated random seed in step 10: 893272
# # Generated random seed in step 11: 37074
# # Generated random seed in step 12: 810502
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               387861         1.13
# # 2            0.1        0.1        100     1                                       solvent               520293         1.13
# # 3            0.1        0.1        100     1                                       solvent               517597         1.13
# # 4            0.1        0.1        200     1                                       solvent               860315         1.94
# # 5            0.1        0.1        500     1                                       solvent               630459         4.37
# # 6            0.1        0.5      50000     1                                       solvent               725374         4.53
# # 7            0.1        0.1        100                                             solvent               344074         1.13
# # 8            0.1        0.1        100                                             solvent               418453         1.13
# # 9            0.1        0.1        100                                             solvent               253482         1.13
# # 10           0.1        0.1        200                                             solvent               893272         1.94
# # 11           0.1        0.1        500                                             solvent               37074          4.37
# # 12           0.1        0.5      50000                                             solvent               810502         4.53
# # Restraints:
# # 1: 1      3098   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.45 MB (trj: 23.7, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed L24I with solvated files
# Processing file: A74G.pdb
# Processing file: A178T_solvated.pdb
# Extracted system name (after fix): A178T
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/A178T_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/A178T_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level15/A178T/minim' exists. Please (re)move it or set 'outdir'.
# Error processing A178T: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/A178T_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/A178T_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level15/A178T/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: A178T_qprep.log
# Processing file: N3K_qprep.log
# Processing file: A74G_qprep.log
# Processing file: H173R_solvated.top
# Extracted system name (after fix): H173R
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/H173R_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/H173R_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 875244
# # Generated random seed in step 2: 706263
# # Generated random seed in step 3: 209561
# # Generated random seed in step 4: 647772
# # Generated random seed in step 5: 96546
# # Generated random seed in step 6: 876138
# # Generated random seed in step 7: 851974
# # Generated random seed in step 8: 268648
# # Generated random seed in step 9: 8888
# # Generated random seed in step 10: 107692
# # Generated random seed in step 11: 374293
# # Generated random seed in step 12: 407714
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               875244         1.13
# # 2            0.1        0.1        100     1                                       solvent               706263         1.13
# # 3            0.1        0.1        100     1                                       solvent               209561         1.13
# # 4            0.1        0.1        200     1                                       solvent               647772         1.94
# # 5            0.1        0.1        500     1                                       solvent               96546          4.38
# # 6            0.1        0.5      50000     1                                       solvent               876138         4.53
# # 7            0.1        0.1        100                                             solvent               851974         1.13
# # 8            0.1        0.1        100                                             solvent               268648         1.13
# # 9            0.1        0.1        100                                             solvent                8888          1.13
# # 10           0.1        0.1        200                                             solvent               107692         1.94
# # 11           0.1        0.1        500                                             solvent               374293         4.38
# # 12           0.1        0.5      50000                                             solvent               407714         4.53
# # Restraints:
# # 1: 1      3105   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.46 MB (trj: 23.7, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed H173R with solvated files
# Processing file: L24I_solvated.top
# Extracted system name (after fix): L24I
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/L24I_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/L24I_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level15/L24I/minim' exists. Please (re)move it or set 'outdir'.
# Error processing L24I: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/L24I_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/L24I_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level15/L24I/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: H173R_solvated.pdb
# Extracted system name (after fix): H173R
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/H173R_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/H173R_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level15/H173R/minim' exists. Please (re)move it or set 'outdir'.
# Error processing H173R: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/H173R_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/H173R_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level15/H173R/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: N3K.inp
# Processing file: L24I.pdb
# Processing file: A74G.inp
# Processing file: A178T.inp
# Processing file: H173R_qprep.log
# Processing file: N3K_solvated.top
# Extracted system name (after fix): N3K
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/N3K_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/N3K_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 825435
# # Generated random seed in step 2: 753739
# # Generated random seed in step 3: 322212
# # Generated random seed in step 4: 900307
# # Generated random seed in step 5: 350332
# # Generated random seed in step 6: 627222
# # Generated random seed in step 7: 557424
# # Generated random seed in step 8: 624701
# # Generated random seed in step 9: 655733
# # Generated random seed in step 10: 565728
# # Generated random seed in step 11: 942647
# # Generated random seed in step 12: 456929
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               825435         1.13
# # 2            0.1        0.1        100     1                                       solvent               753739         1.13
# # 3            0.1        0.1        100     1                                       solvent               322212         1.13
# # 4            0.1        0.1        200     1                                       solvent               900307         1.94
# # 5            0.1        0.1        500     1                                       solvent               350332         4.37
# # 6            0.1        0.5      50000     1                                       solvent               627222         4.53
# # 7            0.1        0.1        100                                             solvent               557424         1.13
# # 8            0.1        0.1        100                                             solvent               624701         1.13
# # 9            0.1        0.1        100                                             solvent               655733         1.13
# # 10           0.1        0.1        200                                             solvent               565728         1.94
# # 11           0.1        0.1        500                                             solvent               942647         4.37
# # 12           0.1        0.5      50000                                             solvent               456929         4.53
# # Restraints:
# # 1: 1      3098   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.45 MB (trj: 23.7, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed N3K with solvated files
# Processing file: H173R.inp
# Processing file: N3K.pdb
# Processing file: A74G_solvated.top
# Extracted system name (after fix): A74G
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/A74G_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/A74G_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level15/A74G/minim' exists. Please (re)move it or set 'outdir'.
# Error processing A74G: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/A74G_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/A74G_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level15/A74G/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: L24I.inp
# Processing file: H173R.pdb
# Processing file: A178T.pdb
# Processing file: L24I_qprep.log
# Processing file: solvation_log.txt
# Processing file: N3K_solvated.pdb
# Extracted system name (after fix): N3K
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/N3K_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/N3K_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level15/N3K/minim' exists. Please (re)move it or set 'outdir'.
# Error processing N3K: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/N3K_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level15/N3K_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level15/N3K/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
