# %%
import os
import shutil
import subprocess

# Directory containing the PDB and solvation files
input_dir = "/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14"

# Output base directory where results will be saved
base_output_dir = "/home/hp/results/MOUSE/level14"

# Directories for the input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genrelax_dir = "/home/hp/nayanika/github/GPX6/input"
topology_dir = "/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14"
fep_dir = "/home/hp/nayanika/github/GPX6/input/fep"  # Correct FEP directory path

os.makedirs(base_output_dir, exist_ok=True)

# Loop through each file in the input directory
for filename in os.listdir(input_dir):
    print(f"Processing file: {filename}")  # Debugging line
    if filename.endswith("_solvated.pdb") or filename.endswith("_solvated.top"):
        system_name = os.path.splitext(filename)[0]  # Extract base name (without extension)

        # Remove the extra '_solvated' if it appears in the system name
        system_name = system_name.replace("_solvated", "")
        
        # Debugging: print the corrected system_name
        print(f"Extracted system name (after fix): {system_name}")
        
        # Define the solvated PDB and TOP file paths
        solvated_pdb_file = os.path.join(input_dir, f"{system_name}_solvated.pdb")
        solvated_top_file = os.path.join(input_dir, f"{system_name}_solvated.top")

        # Debugging: Check the actual paths being checked
        print(f"Checking solvated PDB file: {solvated_pdb_file}")
        print(f"Checking solvated top file: {solvated_top_file}")

        # Check if the solvated PDB and TOP files exist
        if not os.path.isfile(solvated_pdb_file):
            print(f"No solvated PDB file found for {system_name} at {solvated_pdb_file}")
            continue
        if not os.path.isfile(solvated_top_file):
            print(f"No solvated top file found for {system_name} at {solvated_top_file}")
            continue

        # Create a directory for the system in the output directory
        system_output_dir = os.path.join(base_output_dir, system_name)
        os.makedirs(system_output_dir, exist_ok=True)

        # Copy the solvated PDB and solvated TOP files to the system's directory
        shutil.copy(solvated_pdb_file, system_output_dir)
        shutil.copy(solvated_top_file, system_output_dir)

        # Construct the command to run q_genrelax.py
        command = [
            "q_genrelax.py",
            os.path.join(genrelax_dir, "genrelax.proc"),
            "--top", solvated_top_file,
            "--pdb", solvated_pdb_file,
            "--fep", os.path.join(fep_dir, "GPX6_wtmousesec.fep"),
            "--outdir", os.path.join(system_output_dir, "minim"),
            "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
        ]

        # Run the command
        try:
            subprocess.run(command, check=True)
            print(f"Successfully processed {system_name} with solvated files")
        except subprocess.CalledProcessError as e:
            print(f"Error processing {system_name}: {e}")
# Out:
# Processing file: K87T_solvated.pdb
# Extracted system name (after fix): K87T
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/K87T_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/K87T_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 685664
# # Generated random seed in step 2: 389858
# # Generated random seed in step 3: 836652
# # Generated random seed in step 4: 372716
# # Generated random seed in step 5: 922373
# # Generated random seed in step 6: 388507
# # Generated random seed in step 7: 914787
# # Generated random seed in step 8: 11953
# # Generated random seed in step 9: 894250
# # Generated random seed in step 10: 326905
# # Generated random seed in step 11: 231424
# # Generated random seed in step 12: 803134
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               685664         1.10
# # 2            0.1        0.1        100     1                                       solvent               389858         1.10
# # 3            0.1        0.1        100     1                                       solvent               836652         1.10
# # 4            0.1        0.1        200     1                                       solvent               372716         1.89
# # 5            0.1        0.1        500     1                                       solvent               922373         4.26
# # 6            0.1        0.5      50000     1                                       solvent               388507         4.42
# # 7            0.1        0.1        100                                             solvent               914787         1.10
# # 8            0.1        0.1        100                                             solvent               11953          1.10
# # 9            0.1        0.1        100                                             solvent               894250         1.10
# # 10           0.1        0.1        200                                             solvent               326905         1.89
# # 11           0.1        0.1        500                                             solvent               231424         4.26
# # 12           0.1        0.5      50000                                             solvent               803134         4.42
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 27.74 MB (trj: 23.1, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed K87T with solvated files
# Processing file: K87T.inp
# Processing file: N107S_solvated.top
# Extracted system name (after fix): N107S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/N107S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/N107S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 884107
# # Generated random seed in step 2: 790902
# # Generated random seed in step 3: 447003
# # Generated random seed in step 4: 960271
# # Generated random seed in step 5: 419173
# # Generated random seed in step 6: 535891
# # Generated random seed in step 7: 356408
# # Generated random seed in step 8: 969357
# # Generated random seed in step 9: 525502
# # Generated random seed in step 10: 891358
# # Generated random seed in step 11: 827373
# # Generated random seed in step 12: 460498
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               884107         1.10
# # 2            0.1        0.1        100     1                                       solvent               790902         1.10
# # 3            0.1        0.1        100     1                                       solvent               447003         1.10
# # 4            0.1        0.1        200     1                                       solvent               960271         1.89
# # 5            0.1        0.1        500     1                                       solvent               419173         4.26
# # 6            0.1        0.5      50000     1                                       solvent               535891         4.42
# # 7            0.1        0.1        100                                             solvent               356408         1.10
# # 8            0.1        0.1        100                                             solvent               969357         1.10
# # 9            0.1        0.1        100                                             solvent               525502         1.10
# # 10           0.1        0.1        200                                             solvent               891358         1.89
# # 11           0.1        0.1        500                                             solvent               827373         4.26
# # 12           0.1        0.5      50000                                             solvent               460498         4.42
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 27.74 MB (trj: 23.1, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed N107S with solvated files
# Processing file: F48Y_qprep.log
# Processing file: F48Y_solvated.pdb
# Extracted system name (after fix): F48Y
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/F48Y_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/F48Y_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 574903
# # Generated random seed in step 2: 993350
# # Generated random seed in step 3: 606807
# # Generated random seed in step 4: 368442
# # Generated random seed in step 5: 460328
# # Generated random seed in step 6: 138436
# # Generated random seed in step 7: 851037
# # Generated random seed in step 8: 223327
# # Generated random seed in step 9: 320867
# # Generated random seed in step 10: 205794
# # Generated random seed in step 11: 637063
# # Generated random seed in step 12: 669371
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               574903         1.10
# # 2            0.1        0.1        100     1                                       solvent               993350         1.10
# # 3            0.1        0.1        100     1                                       solvent               606807         1.10
# # 4            0.1        0.1        200     1                                       solvent               368442         1.89
# # 5            0.1        0.1        500     1                                       solvent               460328         4.26
# # 6            0.1        0.5      50000     1                                       solvent               138436         4.42
# # 7            0.1        0.1        100                                             solvent               851037         1.10
# # 8            0.1        0.1        100                                             solvent               223327         1.10
# # 9            0.1        0.1        100                                             solvent               320867         1.10
# # 10           0.1        0.1        200                                             solvent               205794         1.89
# # 11           0.1        0.1        500                                             solvent               637063         4.26
# # 12           0.1        0.5      50000                                             solvent               669371         4.42
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 27.74 MB (trj: 23.1, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed F48Y with solvated files
# Processing file: P142S.inp
# Processing file: N107S.inp
# Processing file: P142S.pdb
# Processing file: G102S.inp
# Processing file: P142S_solvated.top
# Extracted system name (after fix): P142S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/P142S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/P142S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 932455
# # Generated random seed in step 2: 384012
# # Generated random seed in step 3: 386821
# # Generated random seed in step 4: 710528
# # Generated random seed in step 5: 5137
# # Generated random seed in step 6: 440998
# # Generated random seed in step 7: 976204
# # Generated random seed in step 8: 44126
# # Generated random seed in step 9: 748800
# # Generated random seed in step 10: 319536
# # Generated random seed in step 11: 197928
# # Generated random seed in step 12: 263153
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               932455         1.10
# # 2            0.1        0.1        100     1                                       solvent               384012         1.10
# # 3            0.1        0.1        100     1                                       solvent               386821         1.10
# # 4            0.1        0.1        200     1                                       solvent               710528         1.89
# # 5            0.1        0.1        500     1                                       solvent                5137          4.26
# # 6            0.1        0.5      50000     1                                       solvent               440998         4.41
# # 7            0.1        0.1        100                                             solvent               976204         1.10
# # 8            0.1        0.1        100                                             solvent               44126          1.10
# # 9            0.1        0.1        100                                             solvent               748800         1.10
# # 10           0.1        0.1        200                                             solvent               319536         1.89
# # 11           0.1        0.1        500                                             solvent               197928         4.26
# # 12           0.1        0.5      50000                                             solvent               263153         4.41
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 27.72 MB (trj: 23.1, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed P142S with solvated files
# Processing file: G102S_qprep.log
# Processing file: F48Y_solvated.top
# Extracted system name (after fix): F48Y
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/F48Y_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/F48Y_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level14/F48Y/minim' exists. Please (re)move it or set 'outdir'.
# Error processing F48Y: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/F48Y_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/F48Y_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level14/F48Y/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: N107S_qprep.log
# Processing file: R181S_solvated.top
# Extracted system name (after fix): R181S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/R181S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/R181S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 763899
# # Generated random seed in step 2: 533807
# # Generated random seed in step 3: 420339
# # Generated random seed in step 4: 51943
# # Generated random seed in step 5: 521446
# # Generated random seed in step 6: 589093
# # Generated random seed in step 7: 637007
# # Generated random seed in step 8: 802285
# # Generated random seed in step 9: 111523
# # Generated random seed in step 10: 923216
# # Generated random seed in step 11: 34364
# # Generated random seed in step 12: 747799
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               763899         1.10
# # 2            0.1        0.1        100     1                                       solvent               533807         1.10
# # 3            0.1        0.1        100     1                                       solvent               420339         1.10
# # 4            0.1        0.1        200     1                                       solvent               51943          1.89
# # 5            0.1        0.1        500     1                                       solvent               521446         4.26
# # 6            0.1        0.5      50000     1                                       solvent               589093         4.42
# # 7            0.1        0.1        100                                             solvent               637007         1.10
# # 8            0.1        0.1        100                                             solvent               802285         1.10
# # 9            0.1        0.1        100                                             solvent               111523         1.10
# # 10           0.1        0.1        200                                             solvent               923216         1.89
# # 11           0.1        0.1        500                                             solvent               34364          4.26
# # 12           0.1        0.5      50000                                             solvent               747799         4.42
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 27.74 MB (trj: 23.1, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed R181S with solvated files
# Processing file: K87T_qprep.log
# Processing file: R181S_qprep.log
# Processing file: R181S.pdb
# Processing file: N107S.pdb
# Processing file: E143S_solvated.top
# Extracted system name (after fix): E143S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/E143S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/E143S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 952929
# # Generated random seed in step 2: 474456
# # Generated random seed in step 3: 167495
# # Generated random seed in step 4: 805268
# # Generated random seed in step 5: 926369
# # Generated random seed in step 6: 685261
# # Generated random seed in step 7: 632829
# # Generated random seed in step 8: 686832
# # Generated random seed in step 9: 903973
# # Generated random seed in step 10: 689812
# # Generated random seed in step 11: 959164
# # Generated random seed in step 12: 919646
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               952929         1.10
# # 2            0.1        0.1        100     1                                       solvent               474456         1.10
# # 3            0.1        0.1        100     1                                       solvent               167495         1.10
# # 4            0.1        0.1        200     1                                       solvent               805268         1.89
# # 5            0.1        0.1        500     1                                       solvent               926369         4.26
# # 6            0.1        0.5      50000     1                                       solvent               685261         4.42
# # 7            0.1        0.1        100                                             solvent               632829         1.10
# # 8            0.1        0.1        100                                             solvent               686832         1.10
# # 9            0.1        0.1        100                                             solvent               903973         1.10
# # 10           0.1        0.1        200                                             solvent               689812         1.89
# # 11           0.1        0.1        500                                             solvent               959164         4.26
# # 12           0.1        0.5      50000                                             solvent               919646         4.42
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 27.74 MB (trj: 23.1, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed E143S with solvated files
# Processing file: P142S_solvated.pdb
# Extracted system name (after fix): P142S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/P142S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/P142S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level14/P142S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing P142S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/P142S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/P142S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level14/P142S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: R181S.inp
# Processing file: F48Y.inp
# Processing file: E143S_solvated.pdb
# Extracted system name (after fix): E143S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/E143S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/E143S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level14/E143S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing E143S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/E143S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/E143S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level14/E143S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: G102S_solvated.top
# Extracted system name (after fix): G102S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/G102S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/G102S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 790883
# # Generated random seed in step 2: 468049
# # Generated random seed in step 3: 179432
# # Generated random seed in step 4: 790775
# # Generated random seed in step 5: 699273
# # Generated random seed in step 6: 945002
# # Generated random seed in step 7: 410053
# # Generated random seed in step 8: 989089
# # Generated random seed in step 9: 232263
# # Generated random seed in step 10: 409611
# # Generated random seed in step 11: 328669
# # Generated random seed in step 12: 993545
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               790883         1.10
# # 2            0.1        0.1        100     1                                       solvent               468049         1.10
# # 3            0.1        0.1        100     1                                       solvent               179432         1.10
# # 4            0.1        0.1        200     1                                       solvent               790775         1.89
# # 5            0.1        0.1        500     1                                       solvent               699273         4.26
# # 6            0.1        0.5      50000     1                                       solvent               945002         4.42
# # 7            0.1        0.1        100                                             solvent               410053         1.10
# # 8            0.1        0.1        100                                             solvent               989089         1.10
# # 9            0.1        0.1        100                                             solvent               232263         1.10
# # 10           0.1        0.1        200                                             solvent               409611         1.89
# # 11           0.1        0.1        500                                             solvent               328669         4.26
# # 12           0.1        0.5      50000                                             solvent               993545         4.42
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 27.74 MB (trj: 23.1, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed G102S with solvated files
# Processing file: R181S_solvated.pdb
# Extracted system name (after fix): R181S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/R181S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/R181S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level14/R181S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing R181S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/R181S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/R181S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level14/R181S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: E143S_qprep.log
# Processing file: N107S_solvated.pdb
# Extracted system name (after fix): N107S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/N107S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/N107S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level14/N107S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing N107S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/N107S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/N107S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level14/N107S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: K87T.pdb
# Processing file: solvation_log.txt
# Processing file: F48Y.pdb
# Processing file: P142S_qprep.log
# Processing file: G102S.pdb
# Processing file: E143S.inp
# Processing file: E143S.pdb
# Processing file: G102S_solvated.pdb
# Extracted system name (after fix): G102S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/G102S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/G102S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level14/G102S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing G102S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/G102S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/G102S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level14/G102S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: K87T_solvated.top
# Extracted system name (after fix): K87T
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/K87T_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/K87T_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level14/K87T/minim' exists. Please (re)move it or set 'outdir'.
# Error processing K87T: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/K87T_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level14/K87T_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level14/K87T/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
