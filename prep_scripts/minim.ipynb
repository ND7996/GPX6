# %%
import os
import shutil
import subprocess

# Directory containing the PDB and solvation files
input_dir = "/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13"

# Output base directory where results will be saved
base_output_dir = "/home/hp/results/MOUSE/level13"

# Directories for the input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genrelax_dir = "/home/hp/nayanika/github/GPX6/input"
topology_dir = "/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13"
fep_dir = "/home/hp/nayanika/github/GPX6/input/fep"  # Correct FEP directory path

os.makedirs(base_output_dir, exist_ok=True)

# Loop through each file in the input directory
for filename in os.listdir(input_dir):
    print(f"Processing file: {filename}")  # Debugging line
    if filename.endswith("_solvated.pdb") or filename.endswith("_solvated.top"):
        system_name = os.path.splitext(filename)[0]  # Extract base name (without extension)

        # Remove the extra '_solvated' if it appears in the system name
        system_name = system_name.replace("_solvated", "")
        
        # Debugging: print the corrected system_name
        print(f"Extracted system name (after fix): {system_name}")
        
        # Define the solvated PDB and TOP file paths
        solvated_pdb_file = os.path.join(input_dir, f"{system_name}_solvated.pdb")
        solvated_top_file = os.path.join(input_dir, f"{system_name}_solvated.top")

        # Debugging: Check the actual paths being checked
        print(f"Checking solvated PDB file: {solvated_pdb_file}")
        print(f"Checking solvated top file: {solvated_top_file}")

        # Check if the solvated PDB and TOP files exist
        if not os.path.isfile(solvated_pdb_file):
            print(f"No solvated PDB file found for {system_name} at {solvated_pdb_file}")
            continue
        if not os.path.isfile(solvated_top_file):
            print(f"No solvated top file found for {system_name} at {solvated_top_file}")
            continue

        # Create a directory for the system in the output directory
        system_output_dir = os.path.join(base_output_dir, system_name)
        os.makedirs(system_output_dir, exist_ok=True)

        # Copy the solvated PDB and solvated TOP files to the system's directory
        shutil.copy(solvated_pdb_file, system_output_dir)
        shutil.copy(solvated_top_file, system_output_dir)

        # Construct the command to run q_genrelax.py
        command = [
            "q_genrelax.py",
            os.path.join(genrelax_dir, "genrelax.proc"),
            "--top", solvated_top_file,
            "--pdb", solvated_pdb_file,
            "--fep", os.path.join(fep_dir, "GPX6_wtmousesec.fep"),
            "--outdir", os.path.join(system_output_dir, "minim"),
            "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
        ]

        # Run the command
        try:
            subprocess.run(command, check=True)
            print(f"Successfully processed {system_name} with solvated files")
        except subprocess.CalledProcessError as e:
            print(f"Error processing {system_name}: {e}")
# Out:
# Processing file: K87T_solvated.pdb
# Extracted system name (after fix): K87T
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/K87T_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/K87T_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 890186
# # Generated random seed in step 2: 788046
# # Generated random seed in step 3: 855361
# # Generated random seed in step 4: 819326
# # Generated random seed in step 5: 861825
# # Generated random seed in step 6: 168422
# # Generated random seed in step 7: 740141
# # Generated random seed in step 8: 453322
# # Generated random seed in step 9: 701707
# # Generated random seed in step 10: 22260
# # Generated random seed in step 11: 929615
# # Generated random seed in step 12: 564507
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               890186         1.12
# # 2            0.1        0.1        100     1                                       solvent               788046         1.12
# # 3            0.1        0.1        100     1                                       solvent               855361         1.12
# # 4            0.1        0.1        200     1                                       solvent               819326         1.93
# # 5            0.1        0.1        500     1                                       solvent               861825         4.35
# # 6            0.1        0.5      50000     1                                       solvent               168422         4.50
# # 7            0.1        0.1        100                                             solvent               740141         1.12
# # 8            0.1        0.1        100                                             solvent               453322         1.12
# # 9            0.1        0.1        100                                             solvent               701707         1.12
# # 10           0.1        0.1        200                                             solvent               22260          1.93
# # 11           0.1        0.1        500                                             solvent               929615         4.35
# # 12           0.1        0.5      50000                                             solvent               564507         4.50
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.29 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed K87T with solvated files
# Processing file: K87T.inp
# Processing file: T52A.pdb
# Processing file: T52A_qprep.log
# Processing file: N107S_solvated.top
# Extracted system name (after fix): N107S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/N107S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/N107S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 560450
# # Generated random seed in step 2: 968788
# # Generated random seed in step 3: 726099
# # Generated random seed in step 4: 518875
# # Generated random seed in step 5: 803116
# # Generated random seed in step 6: 48113
# # Generated random seed in step 7: 583598
# # Generated random seed in step 8: 7306
# # Generated random seed in step 9: 509249
# # Generated random seed in step 10: 459574
# # Generated random seed in step 11: 874436
# # Generated random seed in step 12: 502601
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               560450         1.12
# # 2            0.1        0.1        100     1                                       solvent               968788         1.12
# # 3            0.1        0.1        100     1                                       solvent               726099         1.12
# # 4            0.1        0.1        200     1                                       solvent               518875         1.93
# # 5            0.1        0.1        500     1                                       solvent               803116         4.35
# # 6            0.1        0.5      50000     1                                       solvent               48113          4.50
# # 7            0.1        0.1        100                                             solvent               583598         1.12
# # 8            0.1        0.1        100                                             solvent                7306          1.12
# # 9            0.1        0.1        100                                             solvent               509249         1.12
# # 10           0.1        0.1        200                                             solvent               459574         1.93
# # 11           0.1        0.1        500                                             solvent               874436         4.35
# # 12           0.1        0.5      50000                                             solvent               502601         4.50
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.27 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed N107S with solvated files
# Processing file: F48Y_qprep.log
# Processing file: T52A_solvated.pdb
# Extracted system name (after fix): T52A
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/T52A_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/T52A_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 551635
# # Generated random seed in step 2: 117753
# # Generated random seed in step 3: 974565
# # Generated random seed in step 4: 367574
# # Generated random seed in step 5: 188
# # Generated random seed in step 6: 326196
# # Generated random seed in step 7: 25217
# # Generated random seed in step 8: 676990
# # Generated random seed in step 9: 306055
# # Generated random seed in step 10: 485546
# # Generated random seed in step 11: 53867
# # Generated random seed in step 12: 131998
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               551635         1.12
# # 2            0.1        0.1        100     1                                       solvent               117753         1.12
# # 3            0.1        0.1        100     1                                       solvent               974565         1.12
# # 4            0.1        0.1        200     1                                       solvent               367574         1.93
# # 5            0.1        0.1        500     1                                       solvent                188           4.35
# # 6            0.1        0.5      50000     1                                       solvent               326196         4.50
# # 7            0.1        0.1        100                                             solvent               25217          1.12
# # 8            0.1        0.1        100                                             solvent               676990         1.12
# # 9            0.1        0.1        100                                             solvent               306055         1.12
# # 10           0.1        0.1        200                                             solvent               485546         1.93
# # 11           0.1        0.1        500                                             solvent               53867          4.35
# # 12           0.1        0.5      50000                                             solvent               131998         4.50
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.29 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed T52A with solvated files
# Processing file: F48Y_solvated.pdb
# Extracted system name (after fix): F48Y
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/F48Y_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/F48Y_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 686707
# # Generated random seed in step 2: 706438
# # Generated random seed in step 3: 45919
# # Generated random seed in step 4: 824757
# # Generated random seed in step 5: 487853
# # Generated random seed in step 6: 669618
# # Generated random seed in step 7: 792910
# # Generated random seed in step 8: 927159
# # Generated random seed in step 9: 736214
# # Generated random seed in step 10: 337653
# # Generated random seed in step 11: 932858
# # Generated random seed in step 12: 441246
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               686707         1.12
# # 2            0.1        0.1        100     1                                       solvent               706438         1.12
# # 3            0.1        0.1        100     1                                       solvent               45919          1.12
# # 4            0.1        0.1        200     1                                       solvent               824757         1.93
# # 5            0.1        0.1        500     1                                       solvent               487853         4.35
# # 6            0.1        0.5      50000     1                                       solvent               669618         4.50
# # 7            0.1        0.1        100                                             solvent               792910         1.12
# # 8            0.1        0.1        100                                             solvent               927159         1.12
# # 9            0.1        0.1        100                                             solvent               736214         1.12
# # 10           0.1        0.1        200                                             solvent               337653         1.93
# # 11           0.1        0.1        500                                             solvent               932858         4.35
# # 12           0.1        0.5      50000                                             solvent               441246         4.50
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.29 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed F48Y with solvated files
# Processing file: P142S.inp
# Processing file: N107S.inp
# Processing file: P142S.pdb
# Processing file: G102S.inp
# Processing file: P142S_solvated.top
# Extracted system name (after fix): P142S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/P142S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/P142S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 879828
# # Generated random seed in step 2: 894839
# # Generated random seed in step 3: 311130
# # Generated random seed in step 4: 650208
# # Generated random seed in step 5: 357959
# # Generated random seed in step 6: 751012
# # Generated random seed in step 7: 796765
# # Generated random seed in step 8: 611299
# # Generated random seed in step 9: 515038
# # Generated random seed in step 10: 526745
# # Generated random seed in step 11: 251111
# # Generated random seed in step 12: 225169
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               879828         1.12
# # 2            0.1        0.1        100     1                                       solvent               894839         1.12
# # 3            0.1        0.1        100     1                                       solvent               311130         1.12
# # 4            0.1        0.1        200     1                                       solvent               650208         1.93
# # 5            0.1        0.1        500     1                                       solvent               357959         4.35
# # 6            0.1        0.5      50000     1                                       solvent               751012         4.50
# # 7            0.1        0.1        100                                             solvent               796765         1.12
# # 8            0.1        0.1        100                                             solvent               611299         1.12
# # 9            0.1        0.1        100                                             solvent               515038         1.12
# # 10           0.1        0.1        200                                             solvent               526745         1.93
# # 11           0.1        0.1        500                                             solvent               251111         4.35
# # 12           0.1        0.5      50000                                             solvent               225169         4.50
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.29 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed P142S with solvated files
# Processing file: G102S_qprep.log
# Processing file: F48Y_solvated.top
# Extracted system name (after fix): F48Y
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/F48Y_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/F48Y_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level13/F48Y/minim' exists. Please (re)move it or set 'outdir'.
# Error processing F48Y: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/F48Y_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/F48Y_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level13/F48Y/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: N107S_qprep.log
# Processing file: R181S_solvated.top
# Extracted system name (after fix): R181S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/R181S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/R181S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 787611
# # Generated random seed in step 2: 76670
# # Generated random seed in step 3: 997652
# # Generated random seed in step 4: 111203
# # Generated random seed in step 5: 110060
# # Generated random seed in step 6: 491136
# # Generated random seed in step 7: 685848
# # Generated random seed in step 8: 9954
# # Generated random seed in step 9: 385576
# # Generated random seed in step 10: 277518
# # Generated random seed in step 11: 476025
# # Generated random seed in step 12: 973891
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               787611         1.12
# # 2            0.1        0.1        100     1                                       solvent               76670          1.12
# # 3            0.1        0.1        100     1                                       solvent               997652         1.12
# # 4            0.1        0.1        200     1                                       solvent               111203         1.93
# # 5            0.1        0.1        500     1                                       solvent               110060         4.35
# # 6            0.1        0.5      50000     1                                       solvent               491136         4.50
# # 7            0.1        0.1        100                                             solvent               685848         1.12
# # 8            0.1        0.1        100                                             solvent                9954          1.12
# # 9            0.1        0.1        100                                             solvent               385576         1.12
# # 10           0.1        0.1        200                                             solvent               277518         1.93
# # 11           0.1        0.1        500                                             solvent               476025         4.35
# # 12           0.1        0.5      50000                                             solvent               973891         4.50
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.29 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed R181S with solvated files
# Processing file: K87T_qprep.log
# Processing file: R181S_qprep.log
# Processing file: R181S.pdb
# Processing file: N107S.pdb
# Processing file: E143S_solvated.top
# Extracted system name (after fix): E143S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/E143S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/E143S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 142614
# # Generated random seed in step 2: 428877
# # Generated random seed in step 3: 504792
# # Generated random seed in step 4: 196911
# # Generated random seed in step 5: 286381
# # Generated random seed in step 6: 448199
# # Generated random seed in step 7: 436400
# # Generated random seed in step 8: 419748
# # Generated random seed in step 9: 819686
# # Generated random seed in step 10: 204045
# # Generated random seed in step 11: 306077
# # Generated random seed in step 12: 156649
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               142614         1.12
# # 2            0.1        0.1        100     1                                       solvent               428877         1.12
# # 3            0.1        0.1        100     1                                       solvent               504792         1.12
# # 4            0.1        0.1        200     1                                       solvent               196911         1.93
# # 5            0.1        0.1        500     1                                       solvent               286381         4.35
# # 6            0.1        0.5      50000     1                                       solvent               448199         4.50
# # 7            0.1        0.1        100                                             solvent               436400         1.12
# # 8            0.1        0.1        100                                             solvent               419748         1.12
# # 9            0.1        0.1        100                                             solvent               819686         1.12
# # 10           0.1        0.1        200                                             solvent               204045         1.93
# # 11           0.1        0.1        500                                             solvent               306077         4.35
# # 12           0.1        0.5      50000                                             solvent               156649         4.50
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.26 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed E143S with solvated files
# Processing file: P142S_solvated.pdb
# Extracted system name (after fix): P142S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/P142S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/P142S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level13/P142S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing P142S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/P142S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/P142S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level13/P142S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: R181S.inp
# Processing file: F48Y.inp
# Processing file: E143S_solvated.pdb
# Extracted system name (after fix): E143S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/E143S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/E143S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level13/E143S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing E143S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/E143S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/E143S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level13/E143S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: T52A.inp
# Processing file: G102S_solvated.top
# Extracted system name (after fix): G102S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/G102S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/G102S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 715539
# # Generated random seed in step 2: 166958
# # Generated random seed in step 3: 123590
# # Generated random seed in step 4: 116962
# # Generated random seed in step 5: 814956
# # Generated random seed in step 6: 41381
# # Generated random seed in step 7: 301641
# # Generated random seed in step 8: 739960
# # Generated random seed in step 9: 717227
# # Generated random seed in step 10: 211302
# # Generated random seed in step 11: 379598
# # Generated random seed in step 12: 207223
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               715539         1.12
# # 2            0.1        0.1        100     1                                       solvent               166958         1.12
# # 3            0.1        0.1        100     1                                       solvent               123590         1.12
# # 4            0.1        0.1        200     1                                       solvent               116962         1.93
# # 5            0.1        0.1        500     1                                       solvent               814956         4.35
# # 6            0.1        0.5      50000     1                                       solvent               41381          4.50
# # 7            0.1        0.1        100                                             solvent               301641         1.12
# # 8            0.1        0.1        100                                             solvent               739960         1.12
# # 9            0.1        0.1        100                                             solvent               717227         1.12
# # 10           0.1        0.1        200                                             solvent               211302         1.93
# # 11           0.1        0.1        500                                             solvent               379598         4.35
# # 12           0.1        0.5      50000                                             solvent               207223         4.50
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.27 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed G102S with solvated files
# Processing file: R181S_solvated.pdb
# Extracted system name (after fix): R181S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/R181S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/R181S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level13/R181S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing R181S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/R181S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/R181S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level13/R181S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: E143S_qprep.log
# Processing file: T52A_solvated.top
# Extracted system name (after fix): T52A
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/T52A_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/T52A_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level13/T52A/minim' exists. Please (re)move it or set 'outdir'.
# Error processing T52A: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/T52A_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/T52A_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level13/T52A/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: N107S_solvated.pdb
# Extracted system name (after fix): N107S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/N107S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/N107S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level13/N107S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing N107S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/N107S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/N107S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level13/N107S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: K87T.pdb
# Processing file: solvation_log.txt
# Processing file: F48Y.pdb
# Processing file: P142S_qprep.log
# Processing file: G102S.pdb
# Processing file: E143S.inp
# Processing file: E143S.pdb
# Processing file: G102S_solvated.pdb
# Extracted system name (after fix): G102S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/G102S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/G102S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level13/G102S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing G102S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/G102S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/G102S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level13/G102S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: K87T_solvated.top
# Extracted system name (after fix): K87T
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/K87T_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/K87T_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level13/K87T/minim' exists. Please (re)move it or set 'outdir'.
# Error processing K87T: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/K87T_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level13/K87T_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level13/K87T/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
