# %%
import os
import shutil
import subprocess

# Directory containing the PDB and solvation files
input_dir = "/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17"

# Output base directory where results will be saved
base_output_dir = "/home/hp/results/MOUSE/level17"

# Directories for the input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genrelax_dir = "/home/hp/nayanika/github/GPX6/input"
topology_dir = "/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17"
fep_dir = "/home/hp/nayanika/github/GPX6/input/fep"  # Correct FEP directory path

os.makedirs(base_output_dir, exist_ok=True)

# Loop through each file in the input directory
for filename in os.listdir(input_dir):
    print(f"Processing file: {filename}")  # Debugging line
    if filename.endswith("_solvated.pdb") or filename.endswith("_solvated.top"):
        system_name = os.path.splitext(filename)[0]  # Extract base name (without extension)

        # Remove the extra '_solvated' if it appears in the system name
        system_name = system_name.replace("_solvated", "")
        
        # Debugging: print the corrected system_name
        print(f"Extracted system name (after fix): {system_name}")
        
        # Define the solvated PDB and TOP file paths
        solvated_pdb_file = os.path.join(input_dir, f"{system_name}_solvated.pdb")
        solvated_top_file = os.path.join(input_dir, f"{system_name}_solvated.top")

        # Debugging: Check the actual paths being checked
        print(f"Checking solvated PDB file: {solvated_pdb_file}")
        print(f"Checking solvated top file: {solvated_top_file}")

        # Check if the solvated PDB and TOP files exist
        if not os.path.isfile(solvated_pdb_file):
            print(f"No solvated PDB file found for {system_name} at {solvated_pdb_file}")
            continue
        if not os.path.isfile(solvated_top_file):
            print(f"No solvated top file found for {system_name} at {solvated_top_file}")
            continue

        # Create a directory for the system in the output directory
        system_output_dir = os.path.join(base_output_dir, system_name)
        os.makedirs(system_output_dir, exist_ok=True)

        # Copy the solvated PDB and solvated TOP files to the system's directory
        shutil.copy(solvated_pdb_file, system_output_dir)
        shutil.copy(solvated_top_file, system_output_dir)

        # Construct the command to run q_genrelax.py
        command = [
            "q_genrelax.py",
            os.path.join(genrelax_dir, "genrelax.proc"),
            "--top", solvated_top_file,
            "--pdb", solvated_pdb_file,
            "--fep", os.path.join(fep_dir, "GPX6_wtmousesec.fep"),
            "--outdir", os.path.join(system_output_dir, "minim"),
            "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
        ]

        # Run the command
        try:
            subprocess.run(command, check=True)
            print(f"Successfully processed {system_name} with solvated files")
        except subprocess.CalledProcessError as e:
            print(f"Error processing {system_name}: {e}")
# Out:
# Processing file: F48Y_qprep.log
# Processing file: F48Y_solvated.pdb
# Extracted system name (after fix): F48Y
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/F48Y_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/F48Y_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 158617
# # Generated random seed in step 2: 540240
# # Generated random seed in step 3: 367341
# # Generated random seed in step 4: 87798
# # Generated random seed in step 5: 362605
# # Generated random seed in step 6: 43653
# # Generated random seed in step 7: 722626
# # Generated random seed in step 8: 681945
# # Generated random seed in step 9: 470526
# # Generated random seed in step 10: 752502
# # Generated random seed in step 11: 936506
# # Generated random seed in step 12: 649643
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               158617         1.11
# # 2            0.1        0.1        100     1                                       solvent               540240         1.11
# # 3            0.1        0.1        100     1                                       solvent               367341         1.11
# # 4            0.1        0.1        200     1                                       solvent               87798          1.91
# # 5            0.1        0.1        500     1                                       solvent               362605         4.31
# # 6            0.1        0.5      50000     1                                       solvent               43653          4.46
# # 7            0.1        0.1        100                                             solvent               722626         1.11
# # 8            0.1        0.1        100                                             solvent               681945         1.11
# # 9            0.1        0.1        100                                             solvent               470526         1.11
# # 10           0.1        0.1        200                                             solvent               752502         1.91
# # 11           0.1        0.1        500                                             solvent               936506         4.31
# # 12           0.1        0.5      50000                                             solvent               649643         4.46
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.03 MB (trj: 23.4, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed F48Y with solvated files
# Processing file: P142S.inp
# Processing file: P142S.pdb
# Processing file: P142S_solvated.top
# Extracted system name (after fix): P142S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/P142S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/P142S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 297673
# # Generated random seed in step 2: 570534
# # Generated random seed in step 3: 636158
# # Generated random seed in step 4: 786008
# # Generated random seed in step 5: 716256
# # Generated random seed in step 6: 402460
# # Generated random seed in step 7: 963700
# # Generated random seed in step 8: 594812
# # Generated random seed in step 9: 405911
# # Generated random seed in step 10: 545592
# # Generated random seed in step 11: 528014
# # Generated random seed in step 12: 255127
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               297673         1.11
# # 2            0.1        0.1        100     1                                       solvent               570534         1.11
# # 3            0.1        0.1        100     1                                       solvent               636158         1.11
# # 4            0.1        0.1        200     1                                       solvent               786008         1.91
# # 5            0.1        0.1        500     1                                       solvent               716256         4.31
# # 6            0.1        0.5      50000     1                                       solvent               402460         4.46
# # 7            0.1        0.1        100                                             solvent               963700         1.11
# # 8            0.1        0.1        100                                             solvent               594812         1.11
# # 9            0.1        0.1        100                                             solvent               405911         1.11
# # 10           0.1        0.1        200                                             solvent               545592         1.91
# # 11           0.1        0.1        500                                             solvent               528014         4.31
# # 12           0.1        0.5      50000                                             solvent               255127         4.46
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.02 MB (trj: 23.4, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed P142S with solvated files
# Processing file: F48Y_solvated.top
# Extracted system name (after fix): F48Y
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/F48Y_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/F48Y_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level17/F48Y/minim' exists. Please (re)move it or set 'outdir'.
# Error processing F48Y: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/F48Y_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/F48Y_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level17/F48Y/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: R181S_solvated.top
# Extracted system name (after fix): R181S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/R181S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/R181S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 108313
# # Generated random seed in step 2: 743803
# # Generated random seed in step 3: 592931
# # Generated random seed in step 4: 147421
# # Generated random seed in step 5: 613074
# # Generated random seed in step 6: 434881
# # Generated random seed in step 7: 75870
# # Generated random seed in step 8: 133706
# # Generated random seed in step 9: 593854
# # Generated random seed in step 10: 959544
# # Generated random seed in step 11: 756148
# # Generated random seed in step 12: 406364
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               108313         1.11
# # 2            0.1        0.1        100     1                                       solvent               743803         1.11
# # 3            0.1        0.1        100     1                                       solvent               592931         1.11
# # 4            0.1        0.1        200     1                                       solvent               147421         1.91
# # 5            0.1        0.1        500     1                                       solvent               613074         4.31
# # 6            0.1        0.5      50000     1                                       solvent               434881         4.46
# # 7            0.1        0.1        100                                             solvent               75870          1.11
# # 8            0.1        0.1        100                                             solvent               133706         1.11
# # 9            0.1        0.1        100                                             solvent               593854         1.11
# # 10           0.1        0.1        200                                             solvent               959544         1.91
# # 11           0.1        0.1        500                                             solvent               756148         4.31
# # 12           0.1        0.5      50000                                             solvent               406364         4.46
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.03 MB (trj: 23.4, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed R181S with solvated files
# Processing file: R181S_qprep.log
# Processing file: R181S.pdb
# Processing file: E143S_solvated.top
# Extracted system name (after fix): E143S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/E143S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/E143S_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 845457
# # Generated random seed in step 2: 387280
# # Generated random seed in step 3: 444733
# # Generated random seed in step 4: 705584
# # Generated random seed in step 5: 957694
# # Generated random seed in step 6: 750366
# # Generated random seed in step 7: 767239
# # Generated random seed in step 8: 477159
# # Generated random seed in step 9: 215915
# # Generated random seed in step 10: 704091
# # Generated random seed in step 11: 225627
# # Generated random seed in step 12: 635503
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               845457         1.11
# # 2            0.1        0.1        100     1                                       solvent               387280         1.11
# # 3            0.1        0.1        100     1                                       solvent               444733         1.11
# # 4            0.1        0.1        200     1                                       solvent               705584         1.91
# # 5            0.1        0.1        500     1                                       solvent               957694         4.31
# # 6            0.1        0.5      50000     1                                       solvent               750366         4.46
# # 7            0.1        0.1        100                                             solvent               767239         1.11
# # 8            0.1        0.1        100                                             solvent               477159         1.11
# # 9            0.1        0.1        100                                             solvent               215915         1.11
# # 10           0.1        0.1        200                                             solvent               704091         1.91
# # 11           0.1        0.1        500                                             solvent               225627         4.31
# # 12           0.1        0.5      50000                                             solvent               635503         4.46
# # Restraints:
# # 1: 1      3010   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.02 MB (trj: 23.4, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed E143S with solvated files
# Processing file: P142S_solvated.pdb
# Extracted system name (after fix): P142S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/P142S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/P142S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level17/P142S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing P142S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/P142S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/P142S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level17/P142S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: R181S.inp
# Processing file: F48Y.inp
# Processing file: E143S_solvated.pdb
# Extracted system name (after fix): E143S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/E143S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/E143S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level17/E143S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing E143S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/E143S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/E143S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level17/E143S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: R181S_solvated.pdb
# Extracted system name (after fix): R181S
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/R181S_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/R181S_solvated.top
# ERROR: Directory '/home/hp/results/MOUSE/level17/R181S/minim' exists. Please (re)move it or set 'outdir'.
# Error processing R181S: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/R181S_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/MOUSE/level17/R181S_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wtmousesec.fep', '--outdir', '/home/hp/results/MOUSE/level17/R181S/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: E143S_qprep.log
# Processing file: solvation_log.txt
# Processing file: F48Y.pdb
# Processing file: P142S_qprep.log
# Processing file: E143S.inp
# Processing file: E143S.pdb
