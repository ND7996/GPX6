# %%
import os
import shutil
import subprocess

# Directory containing the PDB and solvation files
input_dir = "/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5"

# Output base directory where results will be saved
base_output_dir = "/home/hp/results/HUMAN/level5"

# Directories for the input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genrelax_dir = "/home/hp/nayanika/github/GPX6/input"
topology_dir = "/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5"
fep_dir = "/home/hp/nayanika/github/GPX6/input/fep"  # Correct FEP directory path

os.makedirs(base_output_dir, exist_ok=True)

# Loop through each file in the input directory
for filename in os.listdir(input_dir):
    print(f"Processing file: {filename}")  # Debugging line
    if filename.endswith("_solvated.pdb") or filename.endswith("_solvated.top"):
        system_name = os.path.splitext(filename)[0]  # Extract base name (without extension)

        # Remove the extra '_solvated' if it appears in the system name
        system_name = system_name.replace("_solvated", "")
        
        # Debugging: print the corrected system_name
        print(f"Extracted system name (after fix): {system_name}")
        
        # Define the solvated PDB and TOP file paths
        solvated_pdb_file = os.path.join(input_dir, f"{system_name}_solvated.pdb")
        solvated_top_file = os.path.join(input_dir, f"{system_name}_solvated.top")

        # Debugging: Check the actual paths being checked
        print(f"Checking solvated PDB file: {solvated_pdb_file}")
        print(f"Checking solvated top file: {solvated_top_file}")

        # Check if the solvated PDB and TOP files exist
        if not os.path.isfile(solvated_pdb_file):
            print(f"No solvated PDB file found for {system_name} at {solvated_pdb_file}")
            continue
        if not os.path.isfile(solvated_top_file):
            print(f"No solvated top file found for {system_name} at {solvated_top_file}")
            continue

        # Create a directory for the system in the output directory
        system_output_dir = os.path.join(base_output_dir, system_name)
        os.makedirs(system_output_dir, exist_ok=True)

        # Copy the solvated PDB and solvated TOP files to the system's directory
        shutil.copy(solvated_pdb_file, system_output_dir)
        shutil.copy(solvated_top_file, system_output_dir)

        # Construct the command to run q_genrelax.py
        command = [
            "q_genrelax.py",
            os.path.join(genrelax_dir, "genrelax.proc"),
            "--top", solvated_top_file,
            "--pdb", solvated_pdb_file,
            "--fep", os.path.join(fep_dir, "GPX6_wthumansec.fep"),
            "--outdir", os.path.join(system_output_dir, "minim"),
            "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
        ]

        # Run the command
        try:
            subprocess.run(command, check=True)
            print(f"Successfully processed {system_name} with solvated files")
        except subprocess.CalledProcessError as e:
            print(f"Error processing {system_name}: {e}")
# Out:
# Processing file: Q177H_solvated.pdb
# Extracted system name (after fix): Q177H
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q177H_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q177H_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 494033
# # Generated random seed in step 2: 371804
# # Generated random seed in step 3: 635857
# # Generated random seed in step 4: 158622
# # Generated random seed in step 5: 523234
# # Generated random seed in step 6: 562711
# # Generated random seed in step 7: 498264
# # Generated random seed in step 8: 682785
# # Generated random seed in step 9: 281251
# # Generated random seed in step 10: 627476
# # Generated random seed in step 11: 476075
# # Generated random seed in step 12: 327983
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               494033         1.12
# # 2            0.1        0.1        100     1                                       solvent               371804         1.12
# # 3            0.1        0.1        100     1                                       solvent               635857         1.12
# # 4            0.1        0.1        200     1                                       solvent               158622         1.93
# # 5            0.1        0.1        500     1                                       solvent               523234         4.36
# # 6            0.1        0.5      50000     1                                       solvent               562711         4.51
# # 7            0.1        0.1        100                                             solvent               498264         1.12
# # 8            0.1        0.1        100                                             solvent               682785         1.12
# # 9            0.1        0.1        100                                             solvent               281251         1.12
# # 10           0.1        0.1        200                                             solvent               627476         1.93
# # 11           0.1        0.1        500                                             solvent               476075         4.36
# # 12           0.1        0.5      50000                                             solvent               327983         4.51
# # Restraints:
# # 1: 1      3080   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.34 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed Q177H with solvated files
# Processing file: Q54T_solvated.pdb
# Extracted system name (after fix): Q54T
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q54T_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q54T_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 977145
# # Generated random seed in step 2: 812598
# # Generated random seed in step 3: 549870
# # Generated random seed in step 4: 936263
# # Generated random seed in step 5: 861721
# # Generated random seed in step 6: 898233
# # Generated random seed in step 7: 346061
# # Generated random seed in step 8: 555932
# # Generated random seed in step 9: 635703
# # Generated random seed in step 10: 374796
# # Generated random seed in step 11: 935995
# # Generated random seed in step 12: 941929
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               977145         1.12
# # 2            0.1        0.1        100     1                                       solvent               812598         1.12
# # 3            0.1        0.1        100     1                                       solvent               549870         1.12
# # 4            0.1        0.1        200     1                                       solvent               936263         1.93
# # 5            0.1        0.1        500     1                                       solvent               861721         4.36
# # 6            0.1        0.5      50000     1                                       solvent               898233         4.51
# # 7            0.1        0.1        100                                             solvent               346061         1.12
# # 8            0.1        0.1        100                                             solvent               555932         1.12
# # 9            0.1        0.1        100                                             solvent               635703         1.12
# # 10           0.1        0.1        200                                             solvent               374796         1.93
# # 11           0.1        0.1        500                                             solvent               935995         4.36
# # 12           0.1        0.5      50000                                             solvent               941929         4.51
# # Restraints:
# # 1: 1      3083   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.37 MB (trj: 23.7, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed Q54T with solvated files
# Processing file: Q54T.inp
# Processing file: S181R_qprep.log
# Processing file: Q54T_qprep.log
# Processing file: A178T_solvated.top
# Extracted system name (after fix): A178T
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A178T_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A178T_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 486990
# # Generated random seed in step 2: 226384
# # Generated random seed in step 3: 344737
# # Generated random seed in step 4: 288795
# # Generated random seed in step 5: 480766
# # Generated random seed in step 6: 668091
# # Generated random seed in step 7: 981346
# # Generated random seed in step 8: 920879
# # Generated random seed in step 9: 42908
# # Generated random seed in step 10: 24996
# # Generated random seed in step 11: 124145
# # Generated random seed in step 12: 400807
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               486990         1.12
# # 2            0.1        0.1        100     1                                       solvent               226384         1.12
# # 3            0.1        0.1        100     1                                       solvent               344737         1.12
# # 4            0.1        0.1        200     1                                       solvent               288795         1.93
# # 5            0.1        0.1        500     1                                       solvent               480766         4.36
# # 6            0.1        0.5      50000     1                                       solvent               668091         4.51
# # 7            0.1        0.1        100                                             solvent               981346         1.12
# # 8            0.1        0.1        100                                             solvent               920879         1.12
# # 9            0.1        0.1        100                                             solvent               42908          1.12
# # 10           0.1        0.1        200                                             solvent               24996          1.93
# # 11           0.1        0.1        500                                             solvent               124145         4.36
# # 12           0.1        0.5      50000                                             solvent               400807         4.51
# # Restraints:
# # 1: 1      3084   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.36 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed A178T with solvated files
# Processing file: A74G_solvated.pdb
# Extracted system name (after fix): A74G
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A74G_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A74G_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 527076
# # Generated random seed in step 2: 664889
# # Generated random seed in step 3: 766172
# # Generated random seed in step 4: 578236
# # Generated random seed in step 5: 680735
# # Generated random seed in step 6: 373107
# # Generated random seed in step 7: 303090
# # Generated random seed in step 8: 607103
# # Generated random seed in step 9: 510056
# # Generated random seed in step 10: 116993
# # Generated random seed in step 11: 582421
# # Generated random seed in step 12: 628692
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               527076         1.12
# # 2            0.1        0.1        100     1                                       solvent               664889         1.12
# # 3            0.1        0.1        100     1                                       solvent               766172         1.12
# # 4            0.1        0.1        200     1                                       solvent               578236         1.93
# # 5            0.1        0.1        500     1                                       solvent               680735         4.35
# # 6            0.1        0.5      50000     1                                       solvent               373107         4.51
# # 7            0.1        0.1        100                                             solvent               303090         1.12
# # 8            0.1        0.1        100                                             solvent               607103         1.12
# # 9            0.1        0.1        100                                             solvent               510056         1.12
# # 10           0.1        0.1        200                                             solvent               116993         1.93
# # 11           0.1        0.1        500                                             solvent               582421         4.35
# # 12           0.1        0.5      50000                                             solvent               628692         4.51
# # Restraints:
# # 1: 1      3080   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.32 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed A74G with solvated files
# Processing file: L24I_solvated.pdb
# Extracted system name (after fix): L24I
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/L24I_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/L24I_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 65646
# # Generated random seed in step 2: 97692
# # Generated random seed in step 3: 262114
# # Generated random seed in step 4: 657458
# # Generated random seed in step 5: 626271
# # Generated random seed in step 6: 699741
# # Generated random seed in step 7: 349844
# # Generated random seed in step 8: 307272
# # Generated random seed in step 9: 228682
# # Generated random seed in step 10: 987399
# # Generated random seed in step 11: 18848
# # Generated random seed in step 12: 759813
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               65646          1.13
# # 2            0.1        0.1        100     1                                       solvent               97692          1.13
# # 3            0.1        0.1        100     1                                       solvent               262114         1.13
# # 4            0.1        0.1        200     1                                       solvent               657458         1.93
# # 5            0.1        0.1        500     1                                       solvent               626271         4.36
# # 6            0.1        0.5      50000     1                                       solvent               699741         4.51
# # 7            0.1        0.1        100                                             solvent               349844         1.13
# # 8            0.1        0.1        100                                             solvent               307272         1.13
# # 9            0.1        0.1        100                                             solvent               228682         1.13
# # 10           0.1        0.1        200                                             solvent               987399         1.93
# # 11           0.1        0.1        500                                             solvent               18848          4.36
# # 12           0.1        0.5      50000                                             solvent               759813         4.51
# # Restraints:
# # 1: 1      3083   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.38 MB (trj: 23.7, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed L24I with solvated files
# Processing file: Q177H.inp
# Processing file: Q144H.pdb
# Processing file: S102G_qprep.log
# Processing file: A74G.pdb
# Processing file: A178T_solvated.pdb
# Extracted system name (after fix): A178T
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A178T_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A178T_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level5/A178T/minim' exists. Please (re)move it or set 'outdir'.
# Error processing A178T: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A178T_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A178T_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level5/A178T/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: Y48F_solvated.pdb
# Extracted system name (after fix): Y48F
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Y48F_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Y48F_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 239483
# # Generated random seed in step 2: 374340
# # Generated random seed in step 3: 382810
# # Generated random seed in step 4: 251636
# # Generated random seed in step 5: 973767
# # Generated random seed in step 6: 182249
# # Generated random seed in step 7: 490822
# # Generated random seed in step 8: 464309
# # Generated random seed in step 9: 592133
# # Generated random seed in step 10: 121682
# # Generated random seed in step 11: 857902
# # Generated random seed in step 12: 302858
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               239483         1.13
# # 2            0.1        0.1        100     1                                       solvent               374340         1.13
# # 3            0.1        0.1        100     1                                       solvent               382810         1.13
# # 4            0.1        0.1        200     1                                       solvent               251636         1.93
# # 5            0.1        0.1        500     1                                       solvent               973767         4.36
# # 6            0.1        0.5      50000     1                                       solvent               182249         4.51
# # 7            0.1        0.1        100                                             solvent               490822         1.13
# # 8            0.1        0.1        100                                             solvent               464309         1.13
# # 9            0.1        0.1        100                                             solvent               592133         1.13
# # 10           0.1        0.1        200                                             solvent               121682         1.93
# # 11           0.1        0.1        500                                             solvent               857902         4.36
# # 12           0.1        0.5      50000                                             solvent               302858         4.51
# # Restraints:
# # 1: 1      3083   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.38 MB (trj: 23.7, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed Y48F with solvated files
# Processing file: Y48F.inp
# Processing file: Q144H.inp
# Processing file: A52T.inp
# Processing file: S102G_solvated.pdb
# Extracted system name (after fix): S102G
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S102G_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S102G_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 571975
# # Generated random seed in step 2: 144898
# # Generated random seed in step 3: 723584
# # Generated random seed in step 4: 549963
# # Generated random seed in step 5: 178591
# # Generated random seed in step 6: 364421
# # Generated random seed in step 7: 188861
# # Generated random seed in step 8: 974815
# # Generated random seed in step 9: 657593
# # Generated random seed in step 10: 145970
# # Generated random seed in step 11: 672006
# # Generated random seed in step 12: 365504
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               571975         1.12
# # 2            0.1        0.1        100     1                                       solvent               144898         1.12
# # 3            0.1        0.1        100     1                                       solvent               723584         1.12
# # 4            0.1        0.1        200     1                                       solvent               549963         1.93
# # 5            0.1        0.1        500     1                                       solvent               178591         4.36
# # 6            0.1        0.5      50000     1                                       solvent               364421         4.51
# # 7            0.1        0.1        100                                             solvent               188861         1.12
# # 8            0.1        0.1        100                                             solvent               974815         1.12
# # 9            0.1        0.1        100                                             solvent               657593         1.12
# # 10           0.1        0.1        200                                             solvent               145970         1.93
# # 11           0.1        0.1        500                                             solvent               672006         4.36
# # 12           0.1        0.5      50000                                             solvent               365504         4.51
# # Restraints:
# # 1: 1      3083   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.37 MB (trj: 23.7, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed S102G with solvated files
# Processing file: A52T_solvated.pdb
# Extracted system name (after fix): A52T
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A52T_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A52T_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 283402
# # Generated random seed in step 2: 591038
# # Generated random seed in step 3: 997288
# # Generated random seed in step 4: 488144
# # Generated random seed in step 5: 791522
# # Generated random seed in step 6: 583669
# # Generated random seed in step 7: 280306
# # Generated random seed in step 8: 378800
# # Generated random seed in step 9: 76533
# # Generated random seed in step 10: 104670
# # Generated random seed in step 11: 731350
# # Generated random seed in step 12: 204950
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               283402         1.12
# # 2            0.1        0.1        100     1                                       solvent               591038         1.12
# # 3            0.1        0.1        100     1                                       solvent               997288         1.12
# # 4            0.1        0.1        200     1                                       solvent               488144         1.93
# # 5            0.1        0.1        500     1                                       solvent               791522         4.36
# # 6            0.1        0.5      50000     1                                       solvent               583669         4.51
# # 7            0.1        0.1        100                                             solvent               280306         1.12
# # 8            0.1        0.1        100                                             solvent               378800         1.12
# # 9            0.1        0.1        100                                             solvent               76533          1.12
# # 10           0.1        0.1        200                                             solvent               104670         1.93
# # 11           0.1        0.1        500                                             solvent               731350         4.36
# # 12           0.1        0.5      50000                                             solvent               204950         4.51
# # Restraints:
# # 1: 1      3083   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.37 MB (trj: 23.7, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed A52T with solvated files
# Processing file: Y48F_solvated.top
# Extracted system name (after fix): Y48F
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Y48F_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Y48F_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level5/Y48F/minim' exists. Please (re)move it or set 'outdir'.
# Error processing Y48F: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Y48F_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Y48F_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level5/Y48F/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: A178T_qprep.log
# Processing file: N3K_qprep.log
# Processing file: A74G_qprep.log
# Processing file: S142P.pdb
# Processing file: S181R.inp
# Processing file: H173R_solvated.top
# Extracted system name (after fix): H173R
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/H173R_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/H173R_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 959620
# # Generated random seed in step 2: 734789
# # Generated random seed in step 3: 672765
# # Generated random seed in step 4: 364699
# # Generated random seed in step 5: 772596
# # Generated random seed in step 6: 322816
# # Generated random seed in step 7: 448097
# # Generated random seed in step 8: 81205
# # Generated random seed in step 9: 287285
# # Generated random seed in step 10: 946795
# # Generated random seed in step 11: 238646
# # Generated random seed in step 12: 312676
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               959620         1.12
# # 2            0.1        0.1        100     1                                       solvent               734789         1.12
# # 3            0.1        0.1        100     1                                       solvent               672765         1.12
# # 4            0.1        0.1        200     1                                       solvent               364699         1.93
# # 5            0.1        0.1        500     1                                       solvent               772596         4.36
# # 6            0.1        0.5      50000     1                                       solvent               322816         4.51
# # 7            0.1        0.1        100                                             solvent               448097         1.12
# # 8            0.1        0.1        100                                             solvent               81205          1.12
# # 9            0.1        0.1        100                                             solvent               287285         1.12
# # 10           0.1        0.1        200                                             solvent               946795         1.93
# # 11           0.1        0.1        500                                             solvent               238646         4.36
# # 12           0.1        0.5      50000                                             solvent               312676         4.51
# # Restraints:
# # 1: 1      3105   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.35 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed H173R with solvated files
# Processing file: L24I_solvated.top
# Extracted system name (after fix): L24I
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/L24I_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/L24I_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level5/L24I/minim' exists. Please (re)move it or set 'outdir'.
# Error processing L24I: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/L24I_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/L24I_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level5/L24I/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: F104Y_solvated.top
# Extracted system name (after fix): F104Y
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/F104Y_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/F104Y_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 827341
# # Generated random seed in step 2: 259148
# # Generated random seed in step 3: 961131
# # Generated random seed in step 4: 801073
# # Generated random seed in step 5: 365579
# # Generated random seed in step 6: 773823
# # Generated random seed in step 7: 859236
# # Generated random seed in step 8: 645935
# # Generated random seed in step 9: 27617
# # Generated random seed in step 10: 280518
# # Generated random seed in step 11: 555201
# # Generated random seed in step 12: 6388
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               827341         1.12
# # 2            0.1        0.1        100     1                                       solvent               259148         1.12
# # 3            0.1        0.1        100     1                                       solvent               961131         1.12
# # 4            0.1        0.1        200     1                                       solvent               801073         1.93
# # 5            0.1        0.1        500     1                                       solvent               365579         4.36
# # 6            0.1        0.5      50000     1                                       solvent               773823         4.51
# # 7            0.1        0.1        100                                             solvent               859236         1.12
# # 8            0.1        0.1        100                                             solvent               645935         1.12
# # 9            0.1        0.1        100                                             solvent               27617          1.12
# # 10           0.1        0.1        200                                             solvent               280518         1.93
# # 11           0.1        0.1        500                                             solvent               555201         4.36
# # 12           0.1        0.5      50000                                             solvent                6388          4.51
# # Restraints:
# # 1: 1      3083   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.35 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed F104Y with solvated files
# Processing file: S181R_solvated.top
# Extracted system name (after fix): S181R
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S181R_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S181R_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 589360
# # Generated random seed in step 2: 502858
# # Generated random seed in step 3: 95637
# # Generated random seed in step 4: 78208
# # Generated random seed in step 5: 100598
# # Generated random seed in step 6: 265725
# # Generated random seed in step 7: 604235
# # Generated random seed in step 8: 249057
# # Generated random seed in step 9: 351205
# # Generated random seed in step 10: 207624
# # Generated random seed in step 11: 216483
# # Generated random seed in step 12: 498608
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               589360         1.12
# # 2            0.1        0.1        100     1                                       solvent               502858         1.12
# # 3            0.1        0.1        100     1                                       solvent               95637          1.12
# # 4            0.1        0.1        200     1                                       solvent               78208          1.93
# # 5            0.1        0.1        500     1                                       solvent               100598         4.35
# # 6            0.1        0.5      50000     1                                       solvent               265725         4.51
# # 7            0.1        0.1        100                                             solvent               604235         1.12
# # 8            0.1        0.1        100                                             solvent               249057         1.12
# # 9            0.1        0.1        100                                             solvent               351205         1.12
# # 10           0.1        0.1        200                                             solvent               207624         1.93
# # 11           0.1        0.1        500                                             solvent               216483         4.35
# # 12           0.1        0.5      50000                                             solvent               498608         4.51
# # Restraints:
# # 1: 1      3098   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.32 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed S181R with solvated files
# Processing file: Q144H_solvated.top
# Extracted system name (after fix): Q144H
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q144H_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q144H_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 917697
# # Generated random seed in step 2: 911253
# # Generated random seed in step 3: 747882
# # Generated random seed in step 4: 703652
# # Generated random seed in step 5: 666434
# # Generated random seed in step 6: 477461
# # Generated random seed in step 7: 85447
# # Generated random seed in step 8: 371354
# # Generated random seed in step 9: 799681
# # Generated random seed in step 10: 283941
# # Generated random seed in step 11: 221151
# # Generated random seed in step 12: 197064
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               917697         1.12
# # 2            0.1        0.1        100     1                                       solvent               911253         1.12
# # 3            0.1        0.1        100     1                                       solvent               747882         1.12
# # 4            0.1        0.1        200     1                                       solvent               703652         1.93
# # 5            0.1        0.1        500     1                                       solvent               666434         4.36
# # 6            0.1        0.5      50000     1                                       solvent               477461         4.51
# # 7            0.1        0.1        100                                             solvent               85447          1.12
# # 8            0.1        0.1        100                                             solvent               371354         1.12
# # 9            0.1        0.1        100                                             solvent               799681         1.12
# # 10           0.1        0.1        200                                             solvent               283941         1.93
# # 11           0.1        0.1        500                                             solvent               221151         4.36
# # 12           0.1        0.5      50000                                             solvent               197064         4.51
# # Restraints:
# # 1: 1      3083   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.33 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed Q144H with solvated files
# Processing file: L139F_solvated.pdb
# Extracted system name (after fix): L139F
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/L139F_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/L139F_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 214822
# # Generated random seed in step 2: 13105
# # Generated random seed in step 3: 620240
# # Generated random seed in step 4: 986894
# # Generated random seed in step 5: 255556
# # Generated random seed in step 6: 123037
# # Generated random seed in step 7: 927188
# # Generated random seed in step 8: 775723
# # Generated random seed in step 9: 730995
# # Generated random seed in step 10: 430654
# # Generated random seed in step 11: 447326
# # Generated random seed in step 12: 22841
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               214822         1.12
# # 2            0.1        0.1        100     1                                       solvent               13105          1.12
# # 3            0.1        0.1        100     1                                       solvent               620240         1.12
# # 4            0.1        0.1        200     1                                       solvent               986894         1.93
# # 5            0.1        0.1        500     1                                       solvent               255556         4.35
# # 6            0.1        0.5      50000     1                                       solvent               123037         4.50
# # 7            0.1        0.1        100                                             solvent               927188         1.12
# # 8            0.1        0.1        100                                             solvent               775723         1.12
# # 9            0.1        0.1        100                                             solvent               730995         1.12
# # 10           0.1        0.1        200                                             solvent               430654         1.93
# # 11           0.1        0.1        500                                             solvent               447326         4.35
# # 12           0.1        0.5      50000                                             solvent               22841          4.50
# # Restraints:
# # 1: 1      3085   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.31 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed L139F with solvated files
# Processing file: H173R_solvated.pdb
# Extracted system name (after fix): H173R
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/H173R_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/H173R_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level5/H173R/minim' exists. Please (re)move it or set 'outdir'.
# Error processing H173R: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/H173R_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/H173R_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level5/H173R/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: N3K.inp
# Processing file: Q177H_qprep.log
# Processing file: F104Y.pdb
# Processing file: Q54T.pdb
# Processing file: L24I.pdb
# Processing file: Q177H_solvated.top
# Extracted system name (after fix): Q177H
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q177H_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q177H_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level5/Q177H/minim' exists. Please (re)move it or set 'outdir'.
# Error processing Q177H: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q177H_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q177H_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level5/Q177H/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: A74G.inp
# Processing file: S142P_solvated.top
# Extracted system name (after fix): S142P
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S142P_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S142P_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 505731
# # Generated random seed in step 2: 343689
# # Generated random seed in step 3: 539037
# # Generated random seed in step 4: 878546
# # Generated random seed in step 5: 499083
# # Generated random seed in step 6: 540260
# # Generated random seed in step 7: 949256
# # Generated random seed in step 8: 35116
# # Generated random seed in step 9: 727119
# # Generated random seed in step 10: 884835
# # Generated random seed in step 11: 254215
# # Generated random seed in step 12: 274881
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               505731         1.12
# # 2            0.1        0.1        100     1                                       solvent               343689         1.12
# # 3            0.1        0.1        100     1                                       solvent               539037         1.12
# # 4            0.1        0.1        200     1                                       solvent               878546         1.93
# # 5            0.1        0.1        500     1                                       solvent               499083         4.36
# # 6            0.1        0.5      50000     1                                       solvent               540260         4.51
# # 7            0.1        0.1        100                                             solvent               949256         1.12
# # 8            0.1        0.1        100                                             solvent               35116          1.12
# # 9            0.1        0.1        100                                             solvent               727119         1.12
# # 10           0.1        0.1        200                                             solvent               884835         1.93
# # 11           0.1        0.1        500                                             solvent               254215         4.36
# # 12           0.1        0.5      50000                                             solvent               274881         4.51
# # Restraints:
# # 1: 1      3083   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.35 MB (trj: 23.6, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed S142P with solvated files
# Processing file: S102G.pdb
# Processing file: A178T.inp
# Processing file: F104Y.inp
# Processing file: S102G.inp
# Processing file: H173R_qprep.log
# Processing file: L139F_solvated.top
# Extracted system name (after fix): L139F
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/L139F_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/L139F_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level5/L139F/minim' exists. Please (re)move it or set 'outdir'.
# Error processing L139F: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/L139F_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/L139F_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level5/L139F/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: S102G_solvated.top
# Extracted system name (after fix): S102G
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S102G_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S102G_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level5/S102G/minim' exists. Please (re)move it or set 'outdir'.
# Error processing S102G: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S102G_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S102G_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level5/S102G/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: S181R_solvated.pdb
# Extracted system name (after fix): S181R
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S181R_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S181R_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level5/S181R/minim' exists. Please (re)move it or set 'outdir'.
# Error processing S181R: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S181R_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S181R_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level5/S181R/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: N3K_solvated.top
# Extracted system name (after fix): N3K
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/N3K_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/N3K_solvated.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 506207
# # Generated random seed in step 2: 117650
# # Generated random seed in step 3: 696779
# # Generated random seed in step 4: 826871
# # Generated random seed in step 5: 52280
# # Generated random seed in step 6: 141877
# # Generated random seed in step 7: 107329
# # Generated random seed in step 8: 406205
# # Generated random seed in step 9: 377671
# # Generated random seed in step 10: 820891
# # Generated random seed in step 11: 857297
# # Generated random seed in step 12: 93773
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1                                       solvent               506207         1.13
# # 2            0.1        0.1        100     1                                       solvent               117650         1.13
# # 3            0.1        0.1        100     1                                       solvent               696779         1.13
# # 4            0.1        0.1        200     1                                       solvent               826871         1.93
# # 5            0.1        0.1        500     1                                       solvent               52280          4.36
# # 6            0.1        0.5      50000     1                                       solvent               141877         4.51
# # 7            0.1        0.1        100                                             solvent               107329         1.13
# # 8            0.1        0.1        100                                             solvent               406205         1.13
# # 9            0.1        0.1        100                                             solvent               377671         1.13
# # 10           0.1        0.1        200                                             solvent               820891         1.93
# # 11           0.1        0.1        500                                             solvent               857297         4.36
# # 12           0.1        0.5      50000                                             solvent               93773          4.51
# # Restraints:
# # 1: 1      3083   20.0   0      0      0
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.38 MB (trj: 23.7, log: 0.9, en: 0.0, rest: 3.8)
# #
# Successfully processed N3K with solvated files
# Processing file: S142P_solvated.pdb
# Extracted system name (after fix): S142P
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S142P_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S142P_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level5/S142P/minim' exists. Please (re)move it or set 'outdir'.
# Error processing S142P: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S142P_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/S142P_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level5/S142P/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: H173R.inp
# Processing file: N3K.pdb
# Processing file: A74G_solvated.top
# Extracted system name (after fix): A74G
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A74G_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A74G_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level5/A74G/minim' exists. Please (re)move it or set 'outdir'.
# Error processing A74G: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A74G_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A74G_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level5/A74G/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: Q177H.pdb
# Processing file: L24I.inp
# Processing file: A52T_qprep.log
# Processing file: L139F.pdb
# Processing file: S142P.inp
# Processing file: H173R.pdb
# Processing file: F104Y_solvated.pdb
# Extracted system name (after fix): F104Y
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/F104Y_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/F104Y_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level5/F104Y/minim' exists. Please (re)move it or set 'outdir'.
# Error processing F104Y: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/F104Y_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/F104Y_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level5/F104Y/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: A178T.pdb
# Processing file: Y48F_qprep.log
# Processing file: S142P_qprep.log
# Processing file: L139F.inp
# Processing file: Q54T_solvated.top
# Extracted system name (after fix): Q54T
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q54T_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q54T_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level5/Q54T/minim' exists. Please (re)move it or set 'outdir'.
# Error processing Q54T: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q54T_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q54T_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level5/Q54T/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: A52T_solvated.top
# Extracted system name (after fix): A52T
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A52T_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A52T_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level5/A52T/minim' exists. Please (re)move it or set 'outdir'.
# Error processing A52T: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A52T_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/A52T_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level5/A52T/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: Q144H_qprep.log
# Processing file: L24I_qprep.log
# Processing file: Y48F.pdb
# Processing file: L139F_qprep.log
# Processing file: solvation_log.txt
# Processing file: A52T.pdb
# Processing file: S181R.pdb
# Processing file: N3K_solvated.pdb
# Extracted system name (after fix): N3K
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/N3K_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/N3K_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level5/N3K/minim' exists. Please (re)move it or set 'outdir'.
# Error processing N3K: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/N3K_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/N3K_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level5/N3K/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: Q144H_solvated.pdb
# Extracted system name (after fix): Q144H
# Checking solvated PDB file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q144H_solvated.pdb
# Checking solvated top file: /home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q144H_solvated.top
# ERROR: Directory '/home/hp/results/HUMAN/level5/Q144H/minim' exists. Please (re)move it or set 'outdir'.
# Error processing Q144H: Command '['q_genrelax.py', '/home/hp/nayanika/github/GPX6/input/genrelax.proc', '--top', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q144H_solvated.top', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/HUMAN/level5/Q144H_solvated.pdb', '--fep', '/home/hp/nayanika/github/GPX6/input/fep/GPX6_wthumansec.fep', '--outdir', '/home/hp/results/HUMAN/level5/Q144H/minim', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing file: F104Y_qprep.log
