# %%
import os
import subprocess

# Base directory containing mutation folders
base_scr_dir = "/home/hp/results/MOUSE/level3"

# Directories for input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genfep_dir = "/home/hp/nayanika/github/GPX6/input"

# Iterate over each mutation folder within the base directory
for mutation_name in os.listdir(base_scr_dir):
    mutation_dir = os.path.join(base_scr_dir, mutation_name)
    minim_dir = os.path.join(mutation_dir, "minim")
    
    # Ensure the minim directory exists
    if not os.path.isdir(minim_dir):
        print(f"Skipping {mutation_dir} as minim directory does not exist.")
        continue

    # Define the required file paths
    pdb_file = os.path.join(minim_dir, "minim.pdb")
    relax_input_path = os.path.join(minim_dir, "relax_012.inp")
    
    # Check if the required files exist
    if not os.path.isfile(pdb_file):
        print(f"No minim PDB file found for {mutation_name} at {pdb_file}")
        continue
    if not os.path.isfile(relax_input_path):
        print(f"Error: Relax input file '{relax_input_path}' doesn't exist for {mutation_name}.")
        continue

    # Construct the command to run q_genfeps.py
    command = [
        "q_genfeps.py",
        os.path.join(genfep_dir, "selgenfeps.proc"),
        "--pdb", pdb_file,
        relax_input_path,
        "inp",
        "--repeats", "30",
        "--frames", "51",
        "--fromlambda", "1.0",
        "--prefix", os.path.join(mutation_dir, "replica"),
        "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
    ]

    # Run the command
    try:
        subprocess.run(command, check=True)
        print(f"Successfully processed {mutation_name} with q_genfeps.py.")
    except subprocess.CalledProcessError as e:
        print(f"Error processing {mutation_name}: {e}")

print("Processing completed for all mutation systems.")
# Out:
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level3/H144Q/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level3/H144Q/minim/H144Q_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level3/H144Q/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H144Q/replica029'.
# # Your runs will waste approx. 8086.93 MB of storage. Per replica: 269.56 MB (trj: 171.0, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed H144Q with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level3/R99C/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level3/R99C/minim/R99C_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level3/R99C/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/R99C/replica029'.
# # Your runs will waste approx. 8090.26 MB of storage. Per replica: 269.68 MB (trj: 171.1, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed R99C with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level3/T178A/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level3/T178A/minim/T178A_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level3/T178A/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T178A/replica029'.
# # Your runs will waste approx. 8081.12 MB of storage. Per replica: 269.37 MB (trj: 170.8, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed T178A with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level3/S4R/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level3/S4R/minim/S4R_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level3/S4R/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S4R/replica029'.
# # Your runs will waste approx. 8091.09 MB of storage. Per replica: 269.70 MB (trj: 171.1, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed S4R with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level3/F48Y/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level3/F48Y/minim/F48Y_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level3/F48Y/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F48Y/replica029'.
# # Your runs will waste approx. 8096.07 MB of storage. Per replica: 269.87 MB (trj: 171.3, log: 7.8, en: 72.0, rest: 18.9)
# Successfully processed F48Y with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level3/N107S/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level3/N107S/minim/N107S_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level3/N107S/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/N107S/replica029'.
# # Your runs will waste approx. 8082.78 MB of storage. Per replica: 269.43 MB (trj: 170.9, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed N107S with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level3/S47A/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level3/S47A/minim/S47A_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level3/S47A/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/S47A/replica029'.
# # Your runs will waste approx. 8091.09 MB of storage. Per replica: 269.70 MB (trj: 171.1, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed S47A with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level3/T60A/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level3/T60A/minim/T60A_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level3/T60A/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/T60A/replica029'.
# # Your runs will waste approx. 8096.07 MB of storage. Per replica: 269.87 MB (trj: 171.3, log: 7.8, en: 72.0, rest: 18.9)
# Successfully processed T60A with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level3/H177Q/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level3/H177Q/minim/H177Q_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level3/H177Q/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/H177Q/replica029'.
# # Your runs will waste approx. 8084.44 MB of storage. Per replica: 269.48 MB (trj: 170.9, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed H177Q with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level3/F139L/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level3/F139L/minim/F139L_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level3/F139L/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/F139L/replica029'.
# # Your runs will waste approx. 8080.29 MB of storage. Per replica: 269.34 MB (trj: 170.8, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed F139L with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level3/P142S/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level3/P142S/minim/P142S_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level3/P142S/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level3/P142S/replica029'.
# # Your runs will waste approx. 8085.27 MB of storage. Per replica: 269.51 MB (trj: 170.9, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed P142S with q_genfeps.py.
# Processing completed for all mutation systems.
