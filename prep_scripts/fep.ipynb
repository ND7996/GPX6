# %%
import os
import subprocess
import shutil
import glob

# Base directory containing mutation folders
base_scr_dir = "./prep_structures/HUMAN/level19"

# Directories for input files
run_dir = "./cluster_scripts"
genfep_dir = "./input"

# Iterate over each mutation folder within the base directory
for mutation_name in os.listdir(base_scr_dir):
    mutation_dir = os.path.join(base_scr_dir, mutation_name)
    minim_dir = os.path.join(mutation_dir, "minim")
    
    # Ensure the minim directory exists
    if not os.path.isdir(minim_dir):
        print(f"Skipping {mutation_dir} as minim directory does not exist.")
        continue

    # Define the required file paths
    pdb_file = os.path.join(minim_dir, "minim.pdb")
    relax_input_path = os.path.join(minim_dir, "relax_012.inp")
    
    # Check if the required files exist
    if not os.path.isfile(pdb_file):
        print(f"No minim PDB file found for {mutation_name} at {pdb_file}")
        continue
    if not os.path.isfile(relax_input_path):
        print(f"Error: Relax input file '{relax_input_path}' doesn't exist for {mutation_name}.")
        continue
        
    # Remove any existing replica folders if they exist
    # This uses glob to find all directories/files starting with "replica"
    replica_pattern = os.path.join(mutation_dir, "replica*")
    replica_matches = glob.glob(replica_pattern)
    
    if replica_matches:
        print(f"Found {len(replica_matches)} replica items in {mutation_dir}")
        for replica_item in replica_matches:
            if os.path.isdir(replica_item):
                print(f"Removing directory: {replica_item}")
                shutil.rmtree(replica_item)
            elif os.path.isfile(replica_item):
                print(f"Removing file: {replica_item}")
                os.remove(replica_item)

    # Construct the command to run q_genfeps.py
    command = [
        "q_genfeps.py",
        os.path.join(genfep_dir, "humanselgenfeps.proc"),
        "--pdb", pdb_file,
        relax_input_path,
        "inp",
        "--repeats", "30",
        "--frames", "51",
        "--fromlambda", "1.0",
        "--prefix", os.path.join(mutation_dir, "replica"),
        "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
    ]

    # Run the command
    try:
        subprocess.run(command, check=True)
        print(f"Successfully processed {mutation_name} with q_genfeps.py.")
    except subprocess.CalledProcessError as e:
        print(f"Error processing {mutation_name}: {e}")

print("Processing completed for all mutation systems.")
# Out:
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level19/A74G/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level19/A74G/minim/A74G_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level19/A74G/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica000'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica001'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica002'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica003'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica004'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica005'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica006'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica007'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica008'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica009'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica010'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica011'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica012'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica013'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica014'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica015'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica016'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica017'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica018'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica019'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica020'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica021'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica022'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica023'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica024'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica025'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica026'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica027'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica028'.
# # Created inputs for repeat/replica './prep_structures/HUMAN/level19/A74G/replica029'.
# # Your runs will waste approx. 8139.28 MB of storage. Per replica: 271.31 MB (trj: 172.6, log: 7.8, en: 72.0, rest: 19.0)
# Successfully processed A74G with q_genfeps.py.
# Processing completed for all mutation systems.
