# %%
import os
import subprocess
import shutil
import glob

# Base directory containing mutation folders
base_scr_dir = "/home/hp/results/MOUSE/level13"

# Directories for input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genfep_dir = "/home/hp/nayanika/github/GPX6/input"

# Iterate over each mutation folder within the base directory
for mutation_name in os.listdir(base_scr_dir):
    mutation_dir = os.path.join(base_scr_dir, mutation_name)
    minim_dir = os.path.join(mutation_dir, "minim")
    
    # Ensure the minim directory exists
    if not os.path.isdir(minim_dir):
        print(f"Skipping {mutation_dir} as minim directory does not exist.")
        continue

    # Define the required file paths
    pdb_file = os.path.join(minim_dir, "minim.pdb")
    relax_input_path = os.path.join(minim_dir, "relax_012.inp")
    
    # Check if the required files exist
    if not os.path.isfile(pdb_file):
        print(f"No minim PDB file found for {mutation_name} at {pdb_file}")
        continue
    if not os.path.isfile(relax_input_path):
        print(f"Error: Relax input file '{relax_input_path}' doesn't exist for {mutation_name}.")
        continue
        
    # Remove any existing replica folders if they exist
    # This uses glob to find all directories/files starting with "replica"
    replica_pattern = os.path.join(mutation_dir, "replica*")
    replica_matches = glob.glob(replica_pattern)
    
    if replica_matches:
        print(f"Found {len(replica_matches)} replica items in {mutation_dir}")
        for replica_item in replica_matches:
            if os.path.isdir(replica_item):
                print(f"Removing directory: {replica_item}")
                shutil.rmtree(replica_item)
            elif os.path.isfile(replica_item):
                print(f"Removing file: {replica_item}")
                os.remove(replica_item)

    # Construct the command to run q_genfeps.py
    command = [
        "q_genfeps.py",
        os.path.join(genfep_dir, "selgenfeps.proc"),
        "--pdb", pdb_file,
        relax_input_path,
        "inp",
        "--repeats", "30",
        "--frames", "51",
        "--fromlambda", "1.0",
        "--prefix", os.path.join(mutation_dir, "replica"),
        "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
    ]

    # Run the command
    try:
        subprocess.run(command, check=True)
        print(f"Successfully processed {mutation_name} with q_genfeps.py.")
    except subprocess.CalledProcessError as e:
        print(f"Error processing {mutation_name}: {e}")

print("Processing completed for all mutation systems.")
# Out:
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level13/R181S/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level13/R181S/minim/R181S_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level13/R181S/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/R181S/replica029'.
# # Your runs will waste approx. 8099.40 MB of storage. Per replica: 269.98 MB (trj: 171.4, log: 7.8, en: 72.0, rest: 18.9)
# Successfully processed R181S with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level13/T52A/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level13/T52A/minim/T52A_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level13/T52A/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/T52A/replica029'.
# # Your runs will waste approx. 8099.40 MB of storage. Per replica: 269.98 MB (trj: 171.4, log: 7.8, en: 72.0, rest: 18.9)
# Successfully processed T52A with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level13/G102S/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level13/G102S/minim/G102S_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level13/G102S/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/G102S/replica029'.
# # Your runs will waste approx. 8096.90 MB of storage. Per replica: 269.90 MB (trj: 171.3, log: 7.8, en: 72.0, rest: 18.9)
# Successfully processed G102S with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level13/F48Y/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level13/F48Y/minim/F48Y_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level13/F48Y/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/F48Y/replica029'.
# # Your runs will waste approx. 8099.40 MB of storage. Per replica: 269.98 MB (trj: 171.4, log: 7.8, en: 72.0, rest: 18.9)
# Successfully processed F48Y with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level13/E143S/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level13/E143S/minim/E143S_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level13/E143S/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/E143S/replica029'.
# # Your runs will waste approx. 8094.41 MB of storage. Per replica: 269.81 MB (trj: 171.2, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed E143S with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level13/N107S/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level13/N107S/minim/N107S_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level13/N107S/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/N107S/replica029'.
# # Your runs will waste approx. 8096.90 MB of storage. Per replica: 269.90 MB (trj: 171.3, log: 7.8, en: 72.0, rest: 18.9)
# Successfully processed N107S with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level13/K87T/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level13/K87T/minim/K87T_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level13/K87T/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/K87T/replica029'.
# # Your runs will waste approx. 8099.40 MB of storage. Per replica: 269.98 MB (trj: 171.4, log: 7.8, en: 72.0, rest: 18.9)
# Successfully processed K87T with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level13/P142S/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level13/P142S/minim/P142S_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level13/P142S/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level13/P142S/replica029'.
# # Your runs will waste approx. 8099.40 MB of storage. Per replica: 269.98 MB (trj: 171.4, log: 7.8, en: 72.0, rest: 18.9)
# Successfully processed P142S with q_genfeps.py.
# Processing completed for all mutation systems.
