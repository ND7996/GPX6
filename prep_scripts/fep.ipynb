# %%
import os
import subprocess
import shutil
import glob

# Base directory containing mutation folders
base_scr_dir = "/home/hp/results/HUMAN/level13"

# Directories for input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genfep_dir = "/home/hp/nayanika/github/GPX6/input"

# Iterate over each mutation folder within the base directory
for mutation_name in os.listdir(base_scr_dir):
    mutation_dir = os.path.join(base_scr_dir, mutation_name)
    minim_dir = os.path.join(mutation_dir, "minim")
    
    # Ensure the minim directory exists
    if not os.path.isdir(minim_dir):
        print(f"Skipping {mutation_dir} as minim directory does not exist.")
        continue

    # Define the required file paths
    pdb_file = os.path.join(minim_dir, "minim.pdb")
    relax_input_path = os.path.join(minim_dir, "relax_012.inp")
    
    # Check if the required files exist
    if not os.path.isfile(pdb_file):
        print(f"No minim PDB file found for {mutation_name} at {pdb_file}")
        continue
    if not os.path.isfile(relax_input_path):
        print(f"Error: Relax input file '{relax_input_path}' doesn't exist for {mutation_name}.")
        continue
        
    # Remove any existing replica folders if they exist
    # This uses glob to find all directories/files starting with "replica"
    replica_pattern = os.path.join(mutation_dir, "replica*")
    replica_matches = glob.glob(replica_pattern)
    
    if replica_matches:
        print(f"Found {len(replica_matches)} replica items in {mutation_dir}")
        for replica_item in replica_matches:
            if os.path.isdir(replica_item):
                print(f"Removing directory: {replica_item}")
                shutil.rmtree(replica_item)
            elif os.path.isfile(replica_item):
                print(f"Removing file: {replica_item}")
                os.remove(replica_item)

    # Construct the command to run q_genfeps.py
    command = [
        "q_genfeps.py",
        os.path.join(genfep_dir, "humanselgenfeps.proc"),
        "--pdb", pdb_file,
        relax_input_path,
        "inp",
        "--repeats", "30",
        "--frames", "51",
        "--fromlambda", "1.0",
        "--prefix", os.path.join(mutation_dir, "replica"),
        "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
    ]

    # Run the command
    try:
        subprocess.run(command, check=True)
        print(f"Successfully processed {mutation_name} with q_genfeps.py.")
    except subprocess.CalledProcessError as e:
        print(f"Error processing {mutation_name}: {e}")

print("Processing completed for all mutation systems.")
# Out:
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level13/L24I/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level13/L24I/minim/L24I_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level13/L24I/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/L24I/replica029'.
# # Your runs will waste approx. 8108.54 MB of storage. Per replica: 270.28 MB (trj: 171.6, log: 7.8, en: 72.0, rest: 18.9)
# Successfully processed L24I with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level13/A74G/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level13/A74G/minim/A74G_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level13/A74G/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A74G/replica029'.
# # Your runs will waste approx. 8108.54 MB of storage. Per replica: 270.28 MB (trj: 171.6, log: 7.8, en: 72.0, rest: 18.9)
# Successfully processed A74G with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level13/S102G/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level13/S102G/minim/S102G_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level13/S102G/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/S102G/replica029'.
# # Your runs will waste approx. 8108.54 MB of storage. Per replica: 270.28 MB (trj: 171.6, log: 7.8, en: 72.0, rest: 18.9)
# Successfully processed S102G with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level13/A178T/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level13/A178T/minim/A178T_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level13/A178T/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/A178T/replica029'.
# # Your runs will waste approx. 8111.03 MB of storage. Per replica: 270.37 MB (trj: 171.7, log: 7.8, en: 72.0, rest: 18.9)
# Successfully processed A178T with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level13/Q177H/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level13/Q177H/minim/Q177H_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level13/Q177H/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/Q177H/replica029'.
# # Your runs will waste approx. 8106.04 MB of storage. Per replica: 270.20 MB (trj: 171.6, log: 7.8, en: 72.0, rest: 18.9)
# Successfully processed Q177H with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level13/N3K/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level13/N3K/minim/N3K_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level13/N3K/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/N3K/replica029'.
# # Your runs will waste approx. 8113.52 MB of storage. Per replica: 270.45 MB (trj: 171.8, log: 7.8, en: 72.0, rest: 18.9)
# Successfully processed N3K with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level13/H173R/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level13/H173R/minim/H173R_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level13/H173R/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level13/H173R/replica029'.
# # Your runs will waste approx. 8114.35 MB of storage. Per replica: 270.48 MB (trj: 171.8, log: 7.8, en: 72.0, rest: 18.9)
# Successfully processed H173R with q_genfeps.py.
# Processing completed for all mutation systems.
