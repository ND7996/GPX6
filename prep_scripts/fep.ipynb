# %%
import os
import subprocess
import shutil
import glob

# Base directory containing mutation folders
base_scr_dir = "/home/hp/results/MOUSE/level8"

# Directories for input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genfep_dir = "/home/hp/nayanika/github/GPX6/input"

# Iterate over each mutation folder within the base directory
for mutation_name in os.listdir(base_scr_dir):
    mutation_dir = os.path.join(base_scr_dir, mutation_name)
    minim_dir = os.path.join(mutation_dir, "minim")
    
    # Ensure the minim directory exists
    if not os.path.isdir(minim_dir):
        print(f"Skipping {mutation_dir} as minim directory does not exist.")
        continue

    # Define the required file paths
    pdb_file = os.path.join(minim_dir, "minim.pdb")
    relax_input_path = os.path.join(minim_dir, "relax_012.inp")
    
    # Check if the required files exist
    if not os.path.isfile(pdb_file):
        print(f"No minim PDB file found for {mutation_name} at {pdb_file}")
        continue
    if not os.path.isfile(relax_input_path):
        print(f"Error: Relax input file '{relax_input_path}' doesn't exist for {mutation_name}.")
        continue
        
    # Remove any existing replica folders if they exist
    # This uses glob to find all directories/files starting with "replica"
    replica_pattern = os.path.join(mutation_dir, "replica*")
    replica_matches = glob.glob(replica_pattern)
    
    if replica_matches:
        print(f"Found {len(replica_matches)} replica items in {mutation_dir}")
        for replica_item in replica_matches:
            if os.path.isdir(replica_item):
                print(f"Removing directory: {replica_item}")
                shutil.rmtree(replica_item)
            elif os.path.isfile(replica_item):
                print(f"Removing file: {replica_item}")
                os.remove(replica_item)

    # Construct the command to run q_genfeps.py
    command = [
        "q_genfeps.py",
        os.path.join(genfep_dir, "selgenfeps.proc"),
        "--pdb", pdb_file,
        relax_input_path,
        "inp",
        "--repeats", "30",
        "--frames", "51",
        "--fromlambda", "1.0",
        "--prefix", os.path.join(mutation_dir, "replica"),
        "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
    ]

    # Run the command
    try:
        subprocess.run(command, check=True)
        print(f"Successfully processed {mutation_name} with q_genfeps.py.")
    except subprocess.CalledProcessError as e:
        print(f"Error processing {mutation_name}: {e}")

print("Processing completed for all mutation systems.")
# Out:
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level8/R99C/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level8/R99C/minim/R99C_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level8/R99C/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R99C/replica029'.
# # Your runs will waste approx. 8064.50 MB of storage. Per replica: 268.82 MB (trj: 170.3, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed R99C with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level8/R181S/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level8/R181S/minim/R181S_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level8/R181S/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/R181S/replica029'.
# # Your runs will waste approx. 8059.52 MB of storage. Per replica: 268.65 MB (trj: 170.2, log: 7.8, en: 72.0, rest: 18.7)
# Successfully processed R181S with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level8/T52A/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level8/T52A/minim/T52A_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level8/T52A/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T52A/replica029'.
# # Your runs will waste approx. 8064.50 MB of storage. Per replica: 268.82 MB (trj: 170.3, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed T52A with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level8/Y104F/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level8/Y104F/minim/Y104F_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level8/Y104F/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/Y104F/replica029'.
# # Your runs will waste approx. 8062.01 MB of storage. Per replica: 268.73 MB (trj: 170.2, log: 7.8, en: 72.0, rest: 18.7)
# Successfully processed Y104F with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level8/T178A/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level8/T178A/minim/T178A_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level8/T178A/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/T178A/replica029'.
# # Your runs will waste approx. 8059.52 MB of storage. Per replica: 268.65 MB (trj: 170.2, log: 7.8, en: 72.0, rest: 18.7)
# Successfully processed T178A with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level8/G102S/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level8/G102S/minim/G102S_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level8/G102S/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/G102S/replica029'.
# # Your runs will waste approx. 8062.01 MB of storage. Per replica: 268.73 MB (trj: 170.2, log: 7.8, en: 72.0, rest: 18.7)
# Successfully processed G102S with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level8/S4R/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level8/S4R/minim/S4R_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level8/S4R/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/S4R/replica029'.
# # Your runs will waste approx. 8062.01 MB of storage. Per replica: 268.73 MB (trj: 170.2, log: 7.8, en: 72.0, rest: 18.7)
# Successfully processed S4R with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level8/F48Y/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level8/F48Y/minim/F48Y_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level8/F48Y/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/F48Y/replica029'.
# # Your runs will waste approx. 8064.50 MB of storage. Per replica: 268.82 MB (trj: 170.3, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed F48Y with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level8/E143S/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level8/E143S/minim/E143S_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level8/E143S/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/E143S/replica029'.
# # Your runs will waste approx. 8059.52 MB of storage. Per replica: 268.65 MB (trj: 170.2, log: 7.8, en: 72.0, rest: 18.7)
# Successfully processed E143S with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level8/N107S/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level8/N107S/minim/N107S_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level8/N107S/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/N107S/replica029'.
# # Your runs will waste approx. 8062.01 MB of storage. Per replica: 268.73 MB (trj: 170.2, log: 7.8, en: 72.0, rest: 18.7)
# Successfully processed N107S with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level8/K87T/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level8/K87T/minim/K87T_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level8/K87T/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/K87T/replica029'.
# # Your runs will waste approx. 8064.50 MB of storage. Per replica: 268.82 MB (trj: 170.3, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed K87T with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level8/H177Q/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level8/H177Q/minim/H177Q_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level8/H177Q/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/H177Q/replica029'.
# # Your runs will waste approx. 8059.52 MB of storage. Per replica: 268.65 MB (trj: 170.2, log: 7.8, en: 72.0, rest: 18.7)
# Successfully processed H177Q with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$, $49.SE$, $196.O1$, $83.OE1$, $196.O1$, $49.SE$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level8/P142S/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level8/P142S/minim/P142S_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level8/P142S/minim/GPX6_wtmousesec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level8/P142S/replica029'.
# # Your runs will waste approx. 8059.52 MB of storage. Per replica: 268.65 MB (trj: 170.2, log: 7.8, en: 72.0, rest: 18.7)
# Successfully processed P142S with q_genfeps.py.
# Processing completed for all mutation systems.
