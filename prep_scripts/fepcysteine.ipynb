# %%
import os
import subprocess

# Base directory containing mutation folders
base_scr_dir = "/home/hp/results/HUMAN/humansec"

# Directories for input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genfep_dir = "/home/hp/nayanika/github/GPX6/input"

# Iterate over each mutation folder within the base directory
for mutation_name in os.listdir(base_scr_dir):
    mutation_dir = os.path.join(base_scr_dir, mutation_name)
    minim_dir = os.path.join(mutation_dir, "minim")
    
    # Ensure the minim directory exists
    if not os.path.isdir(minim_dir):
        print(f"Skipping {mutation_dir} as minim directory does not exist.")
        continue

    # Define the required file paths
    pdb_file = os.path.join(minim_dir, "minim.pdb")
    relax_input_path = os.path.join(minim_dir, "relax_012.inp")
    
    # Check if the required files exist
    if not os.path.isfile(pdb_file):
        print(f"No minim PDB file found for {mutation_name} at {pdb_file}")
        continue
    if not os.path.isfile(relax_input_path):
        print(f"Error: Relax input file '{relax_input_path}' doesn't exist for {mutation_name}.")
        continue

    # Construct the command to run q_genfeps.py
    command = [
        "q_genfeps.py",
        os.path.join(genfep_dir, "humanselgenfeps.proc"),
        "--pdb", pdb_file,
        relax_input_path,
        "inp",
        "--repeats", "30",
        "--frames", "51",
        "--fromlambda", "1.0",
        "--prefix", os.path.join(mutation_dir, "replica"),
        "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
    ]

    # Run the command
    try:
        subprocess.run(command, check=True)
        print(f"Successfully processed {mutation_name} with q_genfeps.py.")
    except subprocess.CalledProcessError as e:
        print(f"Error processing {mutation_name}: {e}")

print("Processing completed for all mutation systems.")
# Out:
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/humansec/S143E/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/humansec/S143E/minim/S143E.top
# # Using FEP file: ../../../../results/HUMAN/humansec/S143E/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S143E/replica029'.
# # Your runs will waste approx. 8086.10 MB of storage. Per replica: 269.54 MB (trj: 171.0, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed S143E with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/humansec/A60T/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/humansec/A60T/minim/A60T.top
# # Using FEP file: ../../../../results/HUMAN/humansec/A60T/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A60T/replica029'.
# # Your runs will waste approx. 8083.61 MB of storage. Per replica: 269.45 MB (trj: 170.9, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed A60T with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/humansec/L24I/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/humansec/L24I/minim/L24I.top
# # Using FEP file: ../../../../results/HUMAN/humansec/L24I/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L24I/replica029'.
# # Your runs will waste approx. 8087.76 MB of storage. Per replica: 269.59 MB (trj: 171.0, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed L24I with q_genfeps.py.
# Skipping /home/hp/results/HUMAN/humansec/change_line.sh as minim directory does not exist.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/humansec/Q54T/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/humansec/Q54T/minim/Q54T.top
# # Using FEP file: ../../../../results/HUMAN/humansec/Q54T/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q54T/replica029'.
# # Your runs will waste approx. 8085.27 MB of storage. Per replica: 269.51 MB (trj: 170.9, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed Q54T with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/humansec/S102G/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/humansec/S102G/minim/S102G.top
# # Using FEP file: ../../../../results/HUMAN/humansec/S102G/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S102G/replica029'.
# # Your runs will waste approx. 8091.92 MB of storage. Per replica: 269.73 MB (trj: 171.1, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed S102G with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/humansec/A178T/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/humansec/A178T/minim/A178T.top
# # Using FEP file: ../../../../results/HUMAN/humansec/A178T/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A178T/replica029'.
# # Your runs will waste approx. 8091.09 MB of storage. Per replica: 269.70 MB (trj: 171.1, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed A178T with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/humansec/S142P/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/humansec/S142P/minim/S142P.top
# # Using FEP file: ../../../../results/HUMAN/humansec/S142P/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S142P/replica029'.
# # Your runs will waste approx. 8092.75 MB of storage. Per replica: 269.76 MB (trj: 171.2, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed S142P with q_genfeps.py.
# Skipping /home/hp/results/HUMAN/humansec/run_fep.sh as minim directory does not exist.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/humansec/Y48F/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/humansec/Y48F/minim/Y48F.top
# # Using FEP file: ../../../../results/HUMAN/humansec/Y48F/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Y48F/replica029'.
# # Your runs will waste approx. 8086.93 MB of storage. Per replica: 269.56 MB (trj: 171.0, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed Y48F with q_genfeps.py.
# Skipping /home/hp/results/HUMAN/humansec/copy_energy.sh as minim directory does not exist.
# Skipping /home/hp/results/HUMAN/humansec/copy_dcd.sh as minim directory does not exist.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/humansec/L139F/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/humansec/L139F/minim/L139F.top
# # Using FEP file: ../../../../results/HUMAN/humansec/L139F/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/L139F/replica029'.
# # Your runs will waste approx. 8086.10 MB of storage. Per replica: 269.54 MB (trj: 171.0, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed L139F with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/humansec/Q177H/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/humansec/Q177H/minim/Q177H.top
# # Using FEP file: ../../../../results/HUMAN/humansec/Q177H/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/Q177H/replica029'.
# # Your runs will waste approx. 8087.76 MB of storage. Per replica: 269.59 MB (trj: 171.0, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed Q177H with q_genfeps.py.
# Skipping /home/hp/results/HUMAN/humansec/slurm-9927.out as minim directory does not exist.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/humansec/A47S/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/humansec/A47S/minim/A47S.top
# # Using FEP file: ../../../../results/HUMAN/humansec/A47S/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A47S/replica020'.
# ...
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/S107N/replica029'.
# # Your runs will waste approx. 8082.78 MB of storage. Per replica: 269.43 MB (trj: 170.9, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed S107N with q_genfeps.py.
# Skipping /home/hp/results/HUMAN/humansec/change_line2.sh as minim directory does not exist.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/humansec/A52T/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/humansec/A52T/minim/A52T.top
# # Using FEP file: ../../../../results/HUMAN/humansec/A52T/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/A52T/replica029'.
# # Your runs will waste approx. 8091.09 MB of storage. Per replica: 269.70 MB (trj: 171.1, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed A52T with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/humansec/E148D/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/humansec/E148D/minim/E148D.top
# # Using FEP file: ../../../../results/HUMAN/humansec/E148D/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/E148D/replica029'.
# # Your runs will waste approx. 8087.76 MB of storage. Per replica: 269.59 MB (trj: 171.0, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed E148D with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/humansec/R4S/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/humansec/R4S/minim/R4S.top
# # Using FEP file: ../../../../results/HUMAN/humansec/R4S/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/humansec/R4S/replica029'.
# # Your runs will waste approx. 8084.44 MB of storage. Per replica: 269.48 MB (trj: 170.9, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed R4S with q_genfeps.py.
# Skipping /home/hp/results/HUMAN/humansec/run_minim.sh as minim directory does not exist.
# Processing completed for all mutation systems.
