# %%
import os
import subprocess

# Base directory where minim folders are located
base_scr_dir = "/home/hp/results/mousecys"

# Directories for input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genfep_dir = "/home/hp/nayanika/github/GPX6/input"
topology_dir = "/home/hp/nayanika/github/GPX6/prep_structures/mousecys"
fep_dir = "/home/hp/nayanika/github/GPX6/input/fep"

# Iterate over each system folder within the base directory
for system_name in os.listdir(base_scr_dir):
    system_dir = os.path.join(base_scr_dir, system_name)
    minim_dir = os.path.join(system_dir, "minim")
    
    # Ensure the minim directory exists
    if not os.path.isdir(minim_dir):
        print(f"Skipping {system_dir} as minim directory does not exist.")
        continue

    # Define the paths for the required files
    pdb_file = os.path.join(topology_dir, f"{system_name}.pdb")
    topology_file = os.path.join(topology_dir, f"{system_name}.top")
    relax_input_path = os.path.join(minim_dir, "relax_012.inp")
    
    # Check if the required files exist
    if not os.path.isfile(pdb_file):
        print(f"No .pdb file found for {system_name} at {pdb_file}")
        continue
    if not os.path.isfile(topology_file):
        print(f"No topology file found for {system_name} at {topology_file}")
        continue
    if not os.path.isfile(relax_input_path):
        print(f"Error: Relax input file '{relax_input_path}' doesn't exist for {system_name}.")
        continue

    # Construct the command to run q_genfeps.py
    command = [
        "q_genfeps.py",
        os.path.join(genfep_dir, "genfeps.proc"),
        "--pdb", pdb_file,
        relax_input_path,  # Use the system-specific relax input file path
        "relax",
        "--repeats", "100",
        "--frames", "51",
        "--fromlambda", "1.0",
        "--prefix", os.path.join(system_dir, "replica"),
        "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
    ]

    # Run the command
    try:
        subprocess.run(command, check=True)
        print(f"Successfully processed {system_name} with q_genfeps.py.")
    except subprocess.CalledProcessError as e:
        print(f"Error processing {system_name}: {e}")

print("Processing completed for all systems.")
# Out:
# Skipping /home/hp/results/mousecys/S47A_T52A_T54Q_R99C as minim directory does not exist.
# Skipping /home/hp/results/mousecys/run_qdyn_5.sh as minim directory does not exist.
# Skipping /home/hp/results/mousecys/test.out as minim directory does not exist.
# Skipping /home/hp/results/mousecys/R99C as minim directory does not exist.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# ERROR: Failed to replace placeholders: Atom '$49.HG1$' does not exist in the pdb structure.
# Error processing G74A: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/genfeps.proc', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/mousecys/G74A.pdb', '/home/hp/results/mousecys/G74A/minim/relax_012.inp', 'relax', '--repeats', '100', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/mousecys/G74A/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Skipping /home/hp/results/mousecys/T52A as minim directory does not exist.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/mousecys/Y104F/minim/relax_012.re
# # Using topology file: ../../../../results/mousecys/Y104F/minim/Y104F.top
# # Using FEP file: ../../../../results/mousecys/Y104F/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
# ERROR: Directory '/home/hp/results/mousecys/Y104F/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing Y104F: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/genfeps.proc', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/mousecys/Y104F.pdb', '/home/hp/results/mousecys/Y104F/minim/relax_012.inp', 'relax', '--repeats', '100', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/mousecys/Y104F/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Skipping /home/hp/results/mousecys/copy_energy.sh as minim directory does not exist.
# Skipping /home/hp/results/mousecys/copy_dcd.sh as minim directory does not exist.
# Skipping /home/hp/results/mousecys/S47A_F48Y_T52A_T54Q_R99C as minim directory does not exist.
# Skipping /home/hp/results/mousecys/C49U as minim directory does not exist.
# Skipping /home/hp/results/mousecys/F48Y_T52A_T54Q_R99C as minim directory does not exist.
# Skipping /home/hp/results/mousecys/A47S as minim directory does not exist.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/mousecys/T178A/minim/relax_012.re
# # Using topology file: ../../../../results/mousecys/T178A/minim/T178A.top
# # Using FEP file: ../../../../results/mousecys/T178A/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
# ERROR: Directory '/home/hp/results/mousecys/T178A/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing T178A: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/genfeps.proc', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/mousecys/T178A.pdb', '/home/hp/results/mousecys/T178A/minim/relax_012.inp', 'relax', '--repeats', '100', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/mousecys/T178A/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Skipping /home/hp/results/mousecys/WT as minim directory does not exist.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/mousecys/G102S/minim/relax_012.re
# # Using topology file: ../../../../results/mousecys/G102S/minim/G102S.top
# # Using FEP file: ../../../../results/mousecys/G102S/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
# ERROR: Directory '/home/hp/results/mousecys/G102S/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing G102S: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/genfeps.proc', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/mousecys/G102S.pdb', '/home/hp/results/mousecys/G102S/minim/relax_012.inp', 'relax', '--repeats', '100', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/mousecys/G102S/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Skipping /home/hp/results/mousecys/F48Y as minim directory does not exist.
# Skipping /home/hp/results/mousecys/S47A_F48Y_T52A_T54Q as minim directory does not exist.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/mousecys/E143S/minim/relax_012.re
# # Using topology file: ../../../../results/mousecys/E143S/minim/E143S.top
# # Using FEP file: ../../../../results/mousecys/E143S/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
# ERROR: Directory '/home/hp/results/mousecys/E143S/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing E143S: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/genfeps.proc', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/mousecys/E143S.pdb', '/home/hp/results/mousecys/E143S/minim/relax_012.inp', 'relax', '--repeats', '100', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/mousecys/E143S/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# No .pdb file found for S47A_F48Y at /home/hp/nayanika/github/GPX6/prep_structures/mousecys/S47A_F48Y.pdb
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/mousecys/D148E/minim/relax_012.re
# # Using topology file: ../../../../results/mousecys/D148E/minim/D148E.top
# # Using FEP file: ../../../../results/mousecys/D148E/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
# ERROR: Directory '/home/hp/results/mousecys/D148E/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing D148E: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/genfeps.proc', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/mousecys/D148E.pdb', '/home/hp/results/mousecys/D148E/minim/relax_012.inp', 'relax', '--repeats', '100', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/mousecys/D148E/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Skipping /home/hp/results/mousecys/run_replica.sh as minim directory does not exist.
# Skipping /home/hp/results/mousecys/stats_output.txt as minim directory does not exist.
# Skipping /home/hp/results/mousecys/statistics_table.sh as minim directory does not exist.
# Skipping /home/hp/results/mousecys/C99R as minim directory does not exist.
# Skipping /home/hp/results/mousecys/S47A_F48Y_T54Q_R99C as minim directory does not exist.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# ERROR: Failed to replace placeholders: Atom '$49.HG1$' does not exist in the pdb structure.
# Error processing K87T: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/genfeps.proc', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/mousecys/K87T.pdb', '/home/hp/results/mousecys/K87T/minim/relax_012.inp', 'relax', '--repeats', '100', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/mousecys/K87T/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Skipping /home/hp/results/mousecys/S47A as minim directory does not exist.
# Skipping /home/hp/results/mousecys/q_mapper.log as minim directory does not exist.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# ERROR: When parsing the input, found this filename '/home/hp/results/mousecys/D25N/minim/relax_012.re' next to the 'final' command. Unfortunately, the file doesnt exist...
# Error processing D25N: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/genfeps.proc', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/mousecys/D25N.pdb', '/home/hp/results/mousecys/D25N/minim/relax_012.inp', 'relax', '--repeats', '100', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/mousecys/D25N/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# ERROR: When parsing the input, found this filename '/home/hp/results/mousecys/G27E/minim/relax_012.re' next to the 'final' command. Unfortunately, the file doesnt exist...
# Error processing G27E: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/genfeps.proc', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/mousecys/G27E.pdb', '/home/hp/results/mousecys/G27E/minim/relax_012.inp', 'relax', '--repeats', '100', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/mousecys/G27E/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# ERROR: Failed to replace placeholders: Atom '$49.HG1$' does not exist in the pdb structure.
# Error processing F139L: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/genfeps.proc', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/mousecys/F139L.pdb', '/home/hp/results/mousecys/F139L/minim/relax_012.inp', 'relax', '--repeats', '100', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/mousecys/F139L/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Skipping /home/hp/results/mousecys/S47A_F48Y_T52A_R99C as minim directory does not exist.
# Skipping /home/hp/results/mousecys/latex_table.tex as minim directory does not exist.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/mousecys/P142S/minim/relax_012.re
# # Using topology file: ../../../../results/mousecys/P142S/minim/P142S.top
# # Using FEP file: ../../../../results/mousecys/P142S/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
# ERROR: Directory '/home/hp/results/mousecys/P142S/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing P142S: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/genfeps.proc', '--pdb', '/home/hp/nayanika/github/GPX6/prep_structures/mousecys/P142S.pdb', '/home/hp/results/mousecys/P142S/minim/relax_012.inp', 'relax', '--repeats', '100', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/mousecys/P142S/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Skipping /home/hp/results/mousecys/preprestart.inp as minim directory does not exist.
# Skipping /home/hp/results/mousecys/T54Q as minim directory does not exist.
# Processing completed for all systems.
