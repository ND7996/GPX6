# %%
import os
import subprocess

# Base directory containing mutation folders
base_scr_dir = "/home/hp/results/MOUSE/level0"

# Directories for input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genfep_dir = "/home/hp/nayanika/github/GPX6/input"

# Iterate over each mutation folder within the base directory
for mutation_name in os.listdir(base_scr_dir):
    mutation_dir = os.path.join(base_scr_dir, mutation_name)
    minim_dir = os.path.join(mutation_dir, "minim")
    
    # Ensure the minim directory exists
    if not os.path.isdir(minim_dir):
        print(f"Skipping {mutation_dir} as minim directory does not exist.")
        continue

    # Define the required file paths
    pdb_file = os.path.join(minim_dir, "minim.pdb")
    relax_input_path = os.path.join(minim_dir, "relax_012.inp")
    
    # Check if the required files exist
    if not os.path.isfile(pdb_file):
        print(f"No minim PDB file found for {mutation_name} at {pdb_file}")
        continue
    if not os.path.isfile(relax_input_path):
        print(f"Error: Relax input file '{relax_input_path}' doesn't exist for {mutation_name}.")
        continue

    # Construct the command to run q_genfeps.py
    command = [
        "q_genfeps.py",
        os.path.join(genfep_dir, "genfeps.proc"),
        "--pdb", pdb_file,
        relax_input_path,
        "relax",
        "--repeats", "20",
        "--frames", "51",
        "--fromlambda", "1.0",
        "--prefix", os.path.join(mutation_dir, "replica"),
        "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
    ]

    # Run the command
    try:
        subprocess.run(command, check=True)
        print(f"Successfully processed {mutation_name} with q_genfeps.py.")
    except subprocess.CalledProcessError as e:
        print(f"Error processing {mutation_name}: {e}")

print("Processing completed for all mutation systems.")
# Out:
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/H144Q/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/H144Q/minim/H144Q_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/H144Q/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H144Q/replica019'.
# # Your runs will waste approx. 6940.09 MB of storage. Per replica: 347.00 MB (trj: 245.2, log: 11.3, en: 72.0, rest: 18.6)
# Successfully processed H144Q with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/R99C/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/R99C/minim/R99C_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/R99C/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R99C/replica019'.
# # Your runs will waste approx. 6947.87 MB of storage. Per replica: 347.39 MB (trj: 245.5, log: 11.3, en: 72.0, rest: 18.6)
# Successfully processed R99C with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/R181S/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/R181S/minim/R181S_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/R181S/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/R181S/replica019'.
# # Your runs will waste approx. 6942.42 MB of storage. Per replica: 347.12 MB (trj: 245.3, log: 11.3, en: 72.0, rest: 18.6)
# Successfully processed R181S with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/T52A/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/T52A/minim/T52A_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/T52A/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T52A/replica019'.
# # Your runs will waste approx. 6950.21 MB of storage. Per replica: 347.51 MB (trj: 245.6, log: 11.3, en: 72.0, rest: 18.7)
# Successfully processed T52A with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/Y104F/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/Y104F/minim/Y104F_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/Y104F/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/Y104F/replica019'.
# # Your runs will waste approx. 6940.87 MB of storage. Per replica: 347.04 MB (trj: 245.2, log: 11.3, en: 72.0, rest: 18.6)
# Successfully processed Y104F with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/T178A/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/T178A/minim/T178A_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/T178A/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T178A/replica019'.
# # Your runs will waste approx. 6941.65 MB of storage. Per replica: 347.08 MB (trj: 245.2, log: 11.3, en: 72.0, rest: 18.6)
# Successfully processed T178A with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/G102S/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/G102S/minim/G102S_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/G102S/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/G102S/replica019'.
# # Your runs will waste approx. 6943.98 MB of storage. Per replica: 347.20 MB (trj: 245.3, log: 11.3, en: 72.0, rest: 18.6)
# Successfully processed G102S with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/S4R/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/S4R/minim/S4R_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/S4R/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S4R/replica019'.
# # Your runs will waste approx. 6958.77 MB of storage. Per replica: 347.94 MB (trj: 246.0, log: 11.3, en: 72.0, rest: 18.7)
# Successfully processed S4R with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/F48Y/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/F48Y/minim/F48Y_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/F48Y/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F48Y/replica019'.
# # Your runs will waste approx. 6954.10 MB of storage. Per replica: 347.70 MB (trj: 245.8, log: 11.3, en: 72.0, rest: 18.7)
# Successfully processed F48Y with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/E143S/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/E143S/minim/E143S_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/E143S/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/E143S/replica019'.
# # Your runs will waste approx. 6940.09 MB of storage. Per replica: 347.00 MB (trj: 245.2, log: 11.3, en: 72.0, rest: 18.6)
# Successfully processed E143S with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/D148E/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/D148E/minim/D148E_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/D148E/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/D148E/replica019'.
# # Your runs will waste approx. 6942.42 MB of storage. Per replica: 347.12 MB (trj: 245.3, log: 11.3, en: 72.0, rest: 18.6)
# Successfully processed D148E with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/I24L/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/I24L/minim/I24L_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/I24L/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/I24L/replica019'.
# # Your runs will waste approx. 6953.32 MB of storage. Per replica: 347.67 MB (trj: 245.8, log: 11.3, en: 72.0, rest: 18.7)
# Successfully processed I24L with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/N107S/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/N107S/minim/N107S_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/N107S/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/N107S/replica019'.
# # Your runs will waste approx. 6938.53 MB of storage. Per replica: 346.93 MB (trj: 245.1, log: 11.3, en: 72.0, rest: 18.6)
# Successfully processed N107S with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/K87T/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/K87T/minim/K87T_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/K87T/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/K87T/replica019'.
# # Your runs will waste approx. 6948.65 MB of storage. Per replica: 347.43 MB (trj: 245.5, log: 11.3, en: 72.0, rest: 18.6)
# Successfully processed K87T with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/S47A/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/S47A/minim/S47A_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/S47A/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/S47A/replica019'.
# # Your runs will waste approx. 6957.99 MB of storage. Per replica: 347.90 MB (trj: 246.0, log: 11.3, en: 72.0, rest: 18.7)
# Successfully processed S47A with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/T60A/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/T60A/minim/T60A_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/T60A/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T60A/replica019'.
# # Your runs will waste approx. 6953.32 MB of storage. Per replica: 347.67 MB (trj: 245.8, log: 11.3, en: 72.0, rest: 18.7)
# Successfully processed T60A with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/H177Q/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/H177Q/minim/H177Q_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/H177Q/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/H177Q/replica019'.
# # Your runs will waste approx. 6942.42 MB of storage. Per replica: 347.12 MB (trj: 245.3, log: 11.3, en: 72.0, rest: 18.6)
# Successfully processed H177Q with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/F139L/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/F139L/minim/F139L_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/F139L/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/F139L/replica019'.
# # Your runs will waste approx. 6940.87 MB of storage. Per replica: 347.04 MB (trj: 245.2, log: 11.3, en: 72.0, rest: 18.6)
# Successfully processed F139L with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/P142S/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/P142S/minim/P142S_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/P142S/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/P142S/replica019'.
# # Your runs will waste approx. 6938.53 MB of storage. Per replica: 346.93 MB (trj: 245.1, log: 11.3, en: 72.0, rest: 18.6)
# Successfully processed P142S with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Using restart file: ../../../../results/MOUSE/level0/T54Q/minim/relax_012.re
# # Using topology file: ../../../../results/MOUSE/level0/T54Q/minim/T54Q_solvated.top
# # Using FEP file: ../../../../results/MOUSE/level0/T54Q/minim/GPX6_wtmousecys.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: relaxation
#
# WARNING: Generating random seeds in FEP inputs. Are you sure this is ok?
#
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/MOUSE/level0/T54Q/replica019'.
# # Your runs will waste approx. 6954.87 MB of storage. Per replica: 347.74 MB (trj: 245.8, log: 11.3, en: 72.0, rest: 18.7)
# Successfully processed T54Q with q_genfeps.py.
# Processing completed for all mutation systems.
