# %%
import os
import subprocess

# Base directory containing mutation folders
base_scr_dir = "/home/hp/results/HUMAN/level1"

# Directories for input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genfep_dir = "/home/hp/nayanika/github/GPX6/input"

# Iterate over each mutation folder within the base directory
for mutation_name in os.listdir(base_scr_dir):
    mutation_dir = os.path.join(base_scr_dir, mutation_name)
    minim_dir = os.path.join(mutation_dir, "minim")
    
    # Ensure the minim directory exists
    if not os.path.isdir(minim_dir):
        print(f"Skipping {mutation_dir} as minim directory does not exist.")
        continue

    # Define the required file paths
    pdb_file = os.path.join(minim_dir, "minim.pdb")
    relax_input_path = os.path.join(minim_dir, "relax_012.inp")
    
    # Check if the required files exist
    if not os.path.isfile(pdb_file):
        print(f"No minim PDB file found for {mutation_name} at {pdb_file}")
        continue
    if not os.path.isfile(relax_input_path):
        print(f"Error: Relax input file '{relax_input_path}' doesn't exist for {mutation_name}.")
        continue

    # Construct the command to run q_genfeps.py
    command = [
        "q_genfeps.py",
        os.path.join(genfep_dir, "humanselgenfeps.proc"),
        "--pdb", pdb_file,
        relax_input_path,
        "inp",
        "--repeats", "30",
        "--frames", "51",
        "--fromlambda", "1.0",
        "--prefix", os.path.join(mutation_dir, "replica"),
        "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
    ]

    # Run the command
    try:
        subprocess.run(command, check=True)
        print(f"Successfully processed {mutation_name} with q_genfeps.py.")
    except subprocess.CalledProcessError as e:
        print(f"Error processing {mutation_name}: {e}")

print("Processing completed for all mutation systems.")
# Out:
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/S143E/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/S143E/minim/S143E_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/S143E/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/S143E/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing S143E: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/S143E/minim/minim.pdb', '/home/hp/results/HUMAN/level1/S143E/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/S143E/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/A60T/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/A60T/minim/A60T_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/A60T/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/A60T/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing A60T: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/A60T/minim/minim.pdb', '/home/hp/results/HUMAN/level1/A60T/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/A60T/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/L24I/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/L24I/minim/L24I_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/L24I/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/L24I/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing L24I: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/L24I/minim/minim.pdb', '/home/hp/results/HUMAN/level1/L24I/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/L24I/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/Q54T/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/Q54T/minim/Q54T_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/Q54T/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/Q54T/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing Q54T: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/Q54T/minim/minim.pdb', '/home/hp/results/HUMAN/level1/Q54T/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/Q54T/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/S102G/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/S102G/minim/S102G_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/S102G/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/S102G/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing S102G: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/S102G/minim/minim.pdb', '/home/hp/results/HUMAN/level1/S102G/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/S102G/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/A178T/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/A178T/minim/A178T_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/A178T/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica000'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica001'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica002'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica003'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica004'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica005'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica006'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica007'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica008'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica009'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica010'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica011'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica012'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica013'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica014'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica015'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica016'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica017'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica018'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica019'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica020'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica021'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica022'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica023'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica024'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica025'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica026'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica027'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica028'.
# # Created inputs for repeat/replica '/home/hp/results/HUMAN/level1/A178T/replica029'.
# # Your runs will waste approx. 8082.78 MB of storage. Per replica: 269.43 MB (trj: 170.9, log: 7.8, en: 72.0, rest: 18.8)
# Successfully processed A178T with q_genfeps.py.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/S142P/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/S142P/minim/S142P_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/S142P/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/S142P/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing S142P: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/S142P/minim/minim.pdb', '/home/hp/results/HUMAN/level1/S142P/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/S142P/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/Y48F/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/Y48F/minim/Y48F_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/Y48F/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/Y48F/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing Y48F: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/Y48F/minim/minim.pdb', '/home/hp/results/HUMAN/level1/Y48F/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/Y48F/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/L139F/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/L139F/minim/L139F_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/L139F/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/L139F/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing L139F: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/L139F/minim/minim.pdb', '/home/hp/results/HUMAN/level1/L139F/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/L139F/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/Q177H/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/Q177H/minim/Q177H_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/Q177H/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/Q177H/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing Q177H: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/Q177H/minim/minim.pdb', '/home/hp/results/HUMAN/level1/Q177H/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/Q177H/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/A47S/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/A47S/minim/A47S_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/A47S/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/A47S/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing A47S: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/A47S/minim/minim.pdb', '/home/hp/results/HUMAN/level1/A47S/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/A47S/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/Q144H/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/Q144H/minim/Q144H_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/Q144H/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/Q144H/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing Q144H: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/Q144H/minim/minim.pdb', '/home/hp/results/HUMAN/level1/Q144H/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/Q144H/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/S181R/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/S181R/minim/S181R_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/S181R/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/S181R/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing S181R: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/S181R/minim/minim.pdb', '/home/hp/results/HUMAN/level1/S181R/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/S181R/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/C99R/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/C99R/minim/C99R_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/C99R/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/C99R/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing C99R: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/C99R/minim/minim.pdb', '/home/hp/results/HUMAN/level1/C99R/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/C99R/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/F104Y/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/F104Y/minim/F104Y_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/F104Y/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/F104Y/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing F104Y: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/F104Y/minim/minim.pdb', '/home/hp/results/HUMAN/level1/F104Y/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/F104Y/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/S107N/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/S107N/minim/S107N_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/S107N/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/S107N/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing S107N: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/S107N/minim/minim.pdb', '/home/hp/results/HUMAN/level1/S107N/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/S107N/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/A52T/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/A52T/minim/A52T_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/A52T/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/A52T/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing A52T: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/A52T/minim/minim.pdb', '/home/hp/results/HUMAN/level1/A52T/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/A52T/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/E148D/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/E148D/minim/E148D_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/E148D/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/E148D/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing E148D: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/E148D/minim/minim.pdb', '/home/hp/results/HUMAN/level1/E148D/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/E148D/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$, $49.SE$, $198.O1$, $83.OE1$, $198.O1$, $49.SE$, $49.HG1$, $198.O1$, $198.H1$, $83.OE1$, $198.H1$, $198.O1$, $49.HG1$
# # Using restart file: ../../../../results/HUMAN/level1/R4S/minim/relax_012.re
# # Using topology file: ../../../../results/HUMAN/level1/R4S/minim/R4S_solvated.top
# # Using FEP file: ../../../../results/HUMAN/level1/R4S/minim/GPX6_wthumansec.fep
# # Starting from lambda value (state 1): 1.0
# # Number of FEP frames: 51
# # Restraining to: topology (from input)
# ERROR: Directory '/home/hp/results/HUMAN/level1/R4S/replica000' exists. Please (re)move it or change the prefix with --prefix.
# Error processing R4S: Command '['q_genfeps.py', '/home/hp/nayanika/github/GPX6/input/humanselgenfeps.proc', '--pdb', '/home/hp/results/HUMAN/level1/R4S/minim/minim.pdb', '/home/hp/results/HUMAN/level1/R4S/minim/relax_012.inp', 'inp', '--repeats', '30', '--frames', '51', '--fromlambda', '1.0', '--prefix', '/home/hp/results/HUMAN/level1/R4S/replica', '--rs', '/home/hp/nayanika/github/GPX6/cluster_scripts/run_qdyn_5.sh']' returned non-zero exit status 1.
# Processing completed for all mutation systems.
