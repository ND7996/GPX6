# %%
import os
import shutil
import subprocess

# List of PDB files to process
pdb_files = [
    "/home/hp/nayanika/github/GPX6/prep_structures/mousecys/D25N.pdb",
    "/home/hp/nayanika/github/GPX6/prep_structures/mousecys/G27E.pdb",
    # Add more PDB files as needed
]

# Base directory where you want to create folders
base_scr_dir = "/home/hp/results/mousecys"

# Directories for the input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genrelax_dir = "/home/hp/nayanika/github/GPX6/input"
topology_dir = "/home/hp/nayanika/github/GPX6/prep_structures/mousecys"
fep_dir = "/home/hp/nayanika/github/GPX6/input/fep"  # Correct FEP directory path

# Create the mousecys directory if it does not exist
os.makedirs(base_scr_dir, exist_ok=True)

# Loop through each PDB file
for pdb_file in pdb_files:
    # Extract the system name from the PDB file (removing the extension)
    system_name = os.path.basename(pdb_file).replace(".pdb", "")

    # Define the topology file path
    topology_file = os.path.join(topology_dir, f"{system_name}.top")
    
    # Check if the topology file exists
    if not os.path.isfile(topology_file):
        print(f"No topology file found for {system_name} at {topology_file}")
        continue

    # Create a directory for the system in the base output directory
    system_dir = os.path.join(base_scr_dir, system_name)
    os.makedirs(system_dir, exist_ok=True)

    # Remove any existing replicas for a clean start (uncomment if needed)
    # os.system(f"rm -rf {os.path.join(system_dir, 'replica*')}")

    # Check if the .pdb file exists
    if os.path.isfile(pdb_file):
        # Copy the .pdb file to the respective system directory
        shutil.copy(pdb_file, system_dir)
        
        # Construct the command to run q_genrelax.py
        command = [
            "q_genrelax.py", 
            os.path.join(genrelax_dir, "genrelax.proc"),
            "--top", topology_file,
            "--pdb", pdb_file,
            "--fep", os.path.join(fep_dir, "GPX6_wtmousecys.fep"),
            "--outdir", os.path.join(system_dir, "minim"),
            "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
        ]
        
        # Run the command
        try:
            subprocess.run(command, check=True)
            print(f"Successfully processed {pdb_file} with topology {topology_file}")
        except subprocess.CalledProcessError as e:
            print(f"Error processing {pdb_file}: {e}")
    else:
        print(f"No .pdb file found at {pdb_file}")
# Out:
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 605821
# # Generated random seed in step 2: 510593
# # Generated random seed in step 3: 515481
# # Generated random seed in step 4: 919371
# # Generated random seed in step 5: 11939
# # Generated random seed in step 6: 539493
# # Generated random seed in step 7: 593494
# # Generated random seed in step 8: 775618
# # Generated random seed in step 9: 134111
# # Generated random seed in step 10: 116084
# # Generated random seed in step 11: 896713
# # Generated random seed in step 12: 319193
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               605821         1.11
# # 2            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               510593         1.11
# # 3            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               515481         1.11
# # 4            0.1        0.1        200     1      2,3,4,5,6,7                       solvent               919371         1.91
# # 5            0.1        0.1        500     1      2,3,4,5,6,7                       solvent               11939          4.31
# # 6            0.1        0.5      50000     1      2,3,4,5,6,7                       solvent               539493         4.46
# # 7            0.1        0.1        100            2,3,4,5,6,7                       solvent               593494         1.11
# # 8            0.1        0.1        100            2,3,4,5,6,7                       solvent               775618         1.11
# # 9            0.1        0.1        100            2,3,4,5,6,7                       solvent               134111         1.11
# # 10           0.1        0.1        200            2,3,4,5,6,7                       solvent               116084         1.91
# # 11           0.1        0.1        500            2,3,4,5,6,7                       solvent               896713         4.31
# # 12           0.1        0.5      50000            2,3,4,5,6,7                       solvent               319193         4.46
# # Restraints:
# # 1: 1      3053   20.0   0      0      0
# # 2: 732    3054   0.0    3.2    10.    0
# # 3: 1260   3054   0.0    3.2    10.    0
# # 4: 732    733    0.0    1.5    5.     1
# # 5: 3054   3056   0.0    1.5    5.     1
# # 6: 1260   3056   0.0    1.5    5.     2
# # 7: 3054   733    0.0    1.5    5.     2
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.03 MB (trj: 23.4, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed /home/hp/nayanika/github/GPX6/prep_structures/mousecys/D25N.pdb with topology /home/hp/nayanika/github/GPX6/prep_structures/mousecys/D25N.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 711263
# # Generated random seed in step 2: 554640
# # Generated random seed in step 3: 842236
# # Generated random seed in step 4: 252204
# # Generated random seed in step 5: 274667
# # Generated random seed in step 6: 42925
# # Generated random seed in step 7: 262381
# # Generated random seed in step 8: 152556
# # Generated random seed in step 9: 291803
# # Generated random seed in step 10: 851379
# # Generated random seed in step 11: 308833
# # Generated random seed in step 12: 147805
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               711263         1.11
# # 2            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               554640         1.11
# # 3            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               842236         1.11
# # 4            0.1        0.1        200     1      2,3,4,5,6,7                       solvent               252204         1.91
# # 5            0.1        0.1        500     1      2,3,4,5,6,7                       solvent               274667         4.31
# # 6            0.1        0.5      50000     1      2,3,4,5,6,7                       solvent               42925          4.47
# # 7            0.1        0.1        100            2,3,4,5,6,7                       solvent               262381         1.11
# # 8            0.1        0.1        100            2,3,4,5,6,7                       solvent               152556         1.11
# # 9            0.1        0.1        100            2,3,4,5,6,7                       solvent               291803         1.11
# # 10           0.1        0.1        200            2,3,4,5,6,7                       solvent               851379         1.91
# # 11           0.1        0.1        500            2,3,4,5,6,7                       solvent               308833         4.31
# # 12           0.1        0.5      50000            2,3,4,5,6,7                       solvent               147805         4.47
# # Restraints:
# # 1: 1      3059   20.0   0      0      0
# # 2: 738    3060   0.0    3.2    10.    0
# # 3: 1266   3060   0.0    3.2    10.    0
# # 4: 738    739    0.0    1.5    5.     1
# # 5: 3060   3062   0.0    1.5    5.     1
# # 6: 1266   3062   0.0    1.5    5.     2
# # 7: 3060   739    0.0    1.5    5.     2
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.06 MB (trj: 23.4, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed /home/hp/nayanika/github/GPX6/prep_structures/mousecys/G27E.pdb with topology /home/hp/nayanika/github/GPX6/prep_structures/mousecys/G27E.top
