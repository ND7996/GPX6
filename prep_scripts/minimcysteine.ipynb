# %%
import os
import shutil
import subprocess

# List of PDB files to process
pdb_files = [
    "/home/hp/nayanika/github/GPX6/prep_structures/mousecys/D25N.pdb",
    "/home/hp/nayanika/github/GPX6/prep_structures/mousecys/G27E.pdb",
]

# Base directory where you want to create folders
base_scr_dir = "/home/hp/results/mousecys"

# Directories for the input files
run_dir = "/home/hp/nayanika/github/GPX6/cluster_scripts"
genrelax_dir = "/home/hp/nayanika/github/GPX6/input"
topology_dir = "/home/hp/nayanika/github/GPX6/prep_structures/mousecys"
fep_dir = "/home/hp/nayanika/github/GPX6/input/fep"  # Correct FEP directory path

# Create the mousecys directory if it does not exist
os.makedirs(base_scr_dir, exist_ok=True)

# Loop through each PDB file
for pdb_file in pdb_files:
    # Extract the system name from the PDB file (removing the extension)
    system_name = os.path.basename(pdb_file).replace(".pdb", "")

    # Define the topology file path
    topology_file = os.path.join(topology_dir, f"{system_name}.top")
    
    # Check if the topology file exists
    if not os.path.isfile(topology_file):
        print(f"No topology file found for {system_name} at {topology_file}")
        continue

    # Create a directory for the system in the base output directory
    system_dir = os.path.join(base_scr_dir, system_name)
    os.makedirs(system_dir, exist_ok=True)

    # Remove any existing replicas for a clean start (uncomment if needed)
    # os.system(f"rm -rf {os.path.join(system_dir, 'replica*')}")

    # Check if the .pdb file exists
    if os.path.isfile(pdb_file):
        # Copy the .pdb file to the respective system directory
        shutil.copy(pdb_file, system_dir)
        
        # Construct the command to run q_genrelax.py
        command = [
            "q_genrelax.py", 
            os.path.join(genrelax_dir, "genrelax.proc"),
            "--top", topology_file,
            "--pdb", pdb_file,
            "--fep", os.path.join(fep_dir, "GPX6_wtmousecys.fep"),
            "--outdir", os.path.join(system_dir, "minim"),
            "--rs", os.path.join(run_dir, "run_qdyn_5.sh")
        ]
        
        # Run the command
        try:
            subprocess.run(command, check=True)
            print(f"Successfully processed {pdb_file} with topology {topology_file}")
        except subprocess.CalledProcessError as e:
            print(f"Error processing {pdb_file}: {e}")
    else:
        print(f"No .pdb file found at {pdb_file}")
# Out:
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 209179
# # Generated random seed in step 2: 851590
# # Generated random seed in step 3: 503202
# # Generated random seed in step 4: 722441
# # Generated random seed in step 5: 163881
# # Generated random seed in step 6: 322403
# # Generated random seed in step 7: 372239
# # Generated random seed in step 8: 735628
# # Generated random seed in step 9: 609065
# # Generated random seed in step 10: 186792
# # Generated random seed in step 11: 752232
# # Generated random seed in step 12: 765889
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               209179         1.11
# # 2            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               851590         1.11
# # 3            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               503202         1.11
# # 4            0.1        0.1        200     1      2,3,4,5,6,7                       solvent               722441         1.91
# # 5            0.1        0.1        500     1      2,3,4,5,6,7                       solvent               163881         4.31
# # 6            0.1        0.5      50000     1      2,3,4,5,6,7                       solvent               322403         4.46
# # 7            0.1        0.1        100            2,3,4,5,6,7                       solvent               372239         1.11
# # 8            0.1        0.1        100            2,3,4,5,6,7                       solvent               735628         1.11
# # 9            0.1        0.1        100            2,3,4,5,6,7                       solvent               609065         1.11
# # 10           0.1        0.1        200            2,3,4,5,6,7                       solvent               186792         1.91
# # 11           0.1        0.1        500            2,3,4,5,6,7                       solvent               752232         4.31
# # 12           0.1        0.5      50000            2,3,4,5,6,7                       solvent               765889         4.46
# # Restraints:
# # 1: 1      3064   20.0   0      0      0
# # 2: 743    3065   0.0    3.2    10.    0
# # 3: 1271   3065   0.0    3.2    10.    0
# # 4: 743    744    0.0    1.5    5.     1
# # 5: 3065   3067   0.0    1.5    5.     1
# # 6: 1271   3067   0.0    1.5    5.     2
# # 7: 3065   744    0.0    1.5    5.     2
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.02 MB (trj: 23.4, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed /home/hp/nayanika/github/GPX6/prep_structures/mousecys/S4R.pdb with topology /home/hp/nayanika/github/GPX6/prep_structures/mousecys/S4R.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 749122
# # Generated random seed in step 2: 697254
# # Generated random seed in step 3: 638534
# # Generated random seed in step 4: 487345
# # Generated random seed in step 5: 518273
# # Generated random seed in step 6: 476870
# # Generated random seed in step 7: 337200
# # Generated random seed in step 8: 255891
# # Generated random seed in step 9: 975360
# # Generated random seed in step 10: 833669
# # Generated random seed in step 11: 865009
# # Generated random seed in step 12: 543211
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               749122         1.11
# # 2            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               697254         1.11
# # 3            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               638534         1.11
# # 4            0.1        0.1        200     1      2,3,4,5,6,7                       solvent               487345         1.91
# # 5            0.1        0.1        500     1      2,3,4,5,6,7                       solvent               518273         4.30
# # 6            0.1        0.5      50000     1      2,3,4,5,6,7                       solvent               476870         4.46
# # 7            0.1        0.1        100            2,3,4,5,6,7                       solvent               337200         1.11
# # 8            0.1        0.1        100            2,3,4,5,6,7                       solvent               255891         1.11
# # 9            0.1        0.1        100            2,3,4,5,6,7                       solvent               975360         1.11
# # 10           0.1        0.1        200            2,3,4,5,6,7                       solvent               833669         1.91
# # 11           0.1        0.1        500            2,3,4,5,6,7                       solvent               865009         4.30
# # 12           0.1        0.5      50000            2,3,4,5,6,7                       solvent               543211         4.46
# # Restraints:
# # 1: 1      3043   20.0   0      0      0
# # 2: 722    3044   0.0    3.2    10.    0
# # 3: 1250   3044   0.0    3.2    10.    0
# # 4: 722    723    0.0    1.5    5.     1
# # 5: 3044   3046   0.0    1.5    5.     1
# # 6: 1250   3046   0.0    1.5    5.     2
# # 7: 3044   723    0.0    1.5    5.     2
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28
1.11
# # 2            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               933325         1.11
# # 3            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               232673         1.11
# # 4            0.1        0.1        200     1      2,3,4,5,6,7                       solvent               261060         1.91
# # 5            0.1        0.1        500     1      2,3,4,5,6,7                       solvent               310459         4.31
# # 6            0.1        0.5      50000     1      2,3,4,5,6,7                       solvent               299944         4.47
# # 7            0.1        0.1        100            2,3,4,5,6,7                       solvent               678307         1.11
# # 8            0.1        0.1        100            2,3,4,5,6,7                       solvent               692228         1.11
# # 9            0.1        0.1        100            2,3,4,5,6,7                       solvent               186093         1.11
# # 10           0.1        0.1        200            2,3,4,5,6,7                       solvent               160325         1.91
# # 11           0.1        0.1        500            2,3,4,5,6,7                       solvent               567316         4.31
# # 12           0.1        0.5      50000            2,3,4,5,6,7                       solvent               102484         4.47
# # Restraints:
# # 1: 1      3059   20.0   0      0      0
# # 2: 730    3060   0.0    3.2    10.    0
# # 3: 1258   3060   0.0    3.2    10.    0
# # 4: 730    731    0.0    1.5    5.     1
# # 5: 3060   3062   0.0    1.5    5.     1
# # 6: 1258   3062   0.0    1.5    5.     2
# # 7: 3060   731    0.0    1.5    5.     2
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.06 MB (trj: 23.4, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed /home/hp/nayanika/github/GPX6/prep_structures/mousecys/N192K.pdb with topology /home/hp/nayanika/github/GPX6/prep_structures/mousecys/N192K.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 704962
# # Generated random seed in step 2: 439954
# # Generated random seed in step 3: 914718
# # Generated random seed in step 4: 514836
# # Generated random seed in step 5: 862569
# # Generated random seed in step 6: 359767
# # Generated random seed in step 7: 990424
# # Generated random seed in step 8: 639830
# # Generated random seed in step 9: 928782
# # Generated random seed in step 10: 732881
# # Generated random seed in step 11: 231753
# # Generated random seed in step 12: 514852
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               704962         1.11
# # 2            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               439954         1.11
# # 3            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               914718         1.11
# # 4            0.1        0.1        200     1      2,3,4,5,6,7                       solvent               514836         1.91
# # 5            0.1        0.1        500     1      2,3,4,5,6,7                       solvent               862569         4.31
# # 6            0.1        0.5      50000     1      2,3,4,5,6,7                       solvent               359767         4.46
# # 7            0.1        0.1        100            2,3,4,5,6,7                       solvent               990424         1.11
# # 8            0.1        0.1        100            2,3,4,5,6,7                       solvent               639830         1.11
# # 9            0.1        0.1        100            2,3,4,5,6,7                       solvent               928782         1.11
# # 10           0.1        0.1        200            2,3,4,5,6,7                       solvent               732881         1.91
# # 11           0.1        0.1        500            2,3,4,5,6,7                       solvent               231753         4.31
# # 12           0.1        0.5      50000            2,3,4,5,6,7                       solvent               514852         4.46
# # Restraints:
# # 1: 1      3057   20.0   0      0      0
# # 2: 730    3058   0.0    3.2    10.    0
# # 3: 1258   3058   0.0    3.2    10.    0
# # 4: 730    731    0.0    1.5    5.     1
# # 5: 3058   3060   0.0    1.5    5.     1
# # 6: 1258   3060   0.0    1.5    5.     2
# # 7: 3058   731    0.0    1.5    5.     2
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.05 MB (trj: 23.4, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed /home/hp/nayanika/github/GPX6/prep_structures/mousecys/T194F.pdb with topology /home/hp/nayanika/github/GPX6/prep_structures/mousecys/T194F.top
# # These placeholders will be replaced with atom indices: $1.N$, $195.O$, $49.SG$, $196.O1$, $83.OE1$, $196.O1$, $49.SG$, $49.HG1$, $196.O1$, $196.H1$, $83.OE1$, $196.H1$, $196.O1$, $49.HG1$
# # Restraining to: 'topology'
# # Replacing FEP file placeholders...
# # Generated random seed in step 1: 582368
# # Generated random seed in step 2: 587450
# # Generated random seed in step 3: 805233
# # Generated random seed in step 4: 205478
# # Generated random seed in step 5: 199200
# # Generated random seed in step 6: 643401
# # Generated random seed in step 7: 345484
# # Generated random seed in step 8: 832451
# # Generated random seed in step 9: 80320
# # Generated random seed in step 10: 456827
# # Generated random seed in step 11: 406426
# # Generated random seed in step 12: 358365
# # Created inputs relax_001.inp - relax_012.inp
# # Overridden parameters:
# # 6: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# # 12: md/stepsize:0.1->0.5, md/bath_coupling:0.1->0.5, intervals/output:10->1000, intervals/trajectory:10->1000, intervals/temperature:10->1000
# #
# # Quick summary
# # Step           T   Stepsize      Steps  Seq.rest  Dist.rest   Ang.rest              Shake              Rand.Seed   Data (MB)
# # 1            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               582368         1.11
# # 2            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               587450         1.11
# # 3            0.1        0.1        100     1      2,3,4,5,6,7                       solvent               805233         1.11
# # 4            0.1        0.1        200     1      2,3,4,5,6,7                       solvent               205478         1.91
# # 5            0.1        0.1        500     1      2,3,4,5,6,7                       solvent               199200         4.31
# # 6            0.1        0.5      50000     1      2,3,4,5,6,7                       solvent               643401         4.46
# # 7            0.1        0.1        100            2,3,4,5,6,7                       solvent               345484         1.11
# # 8            0.1        0.1        100            2,3,4,5,6,7                       solvent               832451         1.11
# # 9            0.1        0.1        100            2,3,4,5,6,7                       solvent               80320          1.11
# # 10           0.1        0.1        200            2,3,4,5,6,7                       solvent               456827         1.91
# # 11           0.1        0.1        500            2,3,4,5,6,7                       solvent               406426         4.31
# # 12           0.1        0.5      50000            2,3,4,5,6,7                       solvent               358365         4.46
# # Restraints:
# # 1: 1      3054   20.0   0      0      0
# # 2: 730    3055   0.0    3.2    10.    0
# # 3: 1258   3055   0.0    3.2    10.    0
# # 4: 730    731    0.0    1.5    5.     1
# # 5: 3055   3057   0.0    1.5    5.     1
# # 6: 1258   3057   0.0    1.5    5.     2
# # 7: 3055   731    0.0    1.5    5.     2
# #
# # Total time: 50.2 ps
# # Total wasted storage (wild approximation): 28.04 MB (trj: 23.4, log: 0.9, en: 0.0, rest: 3.7)
# #
# Successfully processed /home/hp/nayanika/github/GPX6/prep_structures/mousecys/S195N.pdb with topology /home/hp/nayanika/github/GPX6/prep_structures/mousecys/S195N.top
