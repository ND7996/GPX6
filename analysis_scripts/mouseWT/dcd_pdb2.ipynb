# %%
import MDAnalysis as mda
import numpy as np
import pandas as pd
import os
import warnings
from MDAnalysis.analysis import align

# Suppress specific warnings
warnings.filterwarnings("ignore", category=UserWarning, module="MDAnalysis.topology.PDBParser")
warnings.filterwarnings("ignore", category=DeprecationWarning, module="MDAnalysis.coordinates.DCD")

# Function to process each trajectory and extract coordinates
def process_trajectory(traj_dir, pdb_file, dcd_file, residues_of_interest):
    # Check if the PDB file exists
    if not os.path.exists(pdb_file):
        print(f"PDB file not found: {pdb_file}")
        return None

    # Check if the DCD file exists
    if not os.path.exists(os.path.join(traj_dir, dcd_file)):
        print(f"DCD file not found: {os.path.join(traj_dir, dcd_file)}")
        return None

    # Load the trajectory and topology
    u = mda.Universe(pdb_file, os.path.join(traj_dir, dcd_file))

    # Select all atoms
    selection = u.select_atoms("all")

    # Optional: guess elements (if needed for further analysis)
    # u.add_TopologyAttr('elements')  # Uncomment this if you need to guess elements based on atom names.

    # RMSD alignment to the first frame to remove global rotation/translation
    align.AlignTraj(u, u, select="all", in_memory=True).run()

    # Initialize a list to accumulate the positions
    data = []

    # Loop over each frame and accumulate the positions
    for ts in u.trajectory:
        positions = selection.positions
        for atom in selection.atoms:
            res_name = atom.resname
            res_id = atom.resid
            atom_name = atom.name
            coord = positions[atom.index]
            data.append([res_name, res_id, atom_name, *coord])

    # Convert to a DataFrame
    df = pd.DataFrame(data, columns=['Residue', 'Residue_ID', 'Atom', 'X', 'Y', 'Z'])

    # Filter for the specific residues of interest
    filtered_df = df[df.apply(lambda row: f"{row['Residue']} {row['Residue_ID']}" in residues_of_interest, axis=1)]

    # Calculate the average coordinates
    avg_df = filtered_df.groupby(['Residue', 'Residue_ID', 'Atom']).mean().reset_index()

    return avg_df

# Main function to automate across multiple trajectory folders
def automate_trajectory_processing(base_dir, residues_of_interest):
    pdb_file = os.path.join(base_dir, "minim.pdb")
    
    # Check if the PDB file exists
    if not os.path.exists(pdb_file):
        print(f"PDB file not found: {pdb_file}")
        return

    for i in range(100):  # For folders traj00 to traj99
        traj_dir = os.path.join(base_dir, f"traj{i:02d}")
        dcd_file = "fep_050_0.000.dcd"
        
        if os.path.exists(os.path.join(traj_dir, dcd_file)):
            print(f"Processing: {traj_dir}/{dcd_file}")
            avg_df = process_trajectory(traj_dir, pdb_file, dcd_file, residues_of_interest)
            
            if avg_df is not None:
                # Save the result to a CSV file
                output_csv = os.path.join(traj_dir, "product_qatoms.csv")
                avg_df.to_csv(output_csv, index=False)
                print(f"Saved: {output_csv}")
            else:
                print(f"Skipping: {traj_dir} due to missing files or processing error.")
        else:
            print(f"File not found: {traj_dir}/{dcd_file}")

# Example usage
base_dir = "./analysis_scripts/mouseWT"
residues_of_interest = ["CYS 49", "GLN 83", "PRX 196"]

# Run the automated processing across all traj00 to traj99 folders
automate_trajectory_processing(base_dir, residues_of_interest)
# Out:
# Processing: ./analysis_scripts/mouseWT/traj00/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj00/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj01/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj01/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj02/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj02/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj03/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj03/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj04/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj04/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj05/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj05/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj06/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj06/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj07/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj07/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj08/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj08/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj09/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj09/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj10/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj10/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj11/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj11/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj12/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj12/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj13/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj13/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj14/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj14/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj15/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj15/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj16/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj16/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj17/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj17/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj18/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj18/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj19/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj19/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj20/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj20/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj21/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj21/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj22/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj22/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj23/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj23/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj24/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj24/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj25/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj25/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj26/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj26/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj27/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj27/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj28/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj28/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj29/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj29/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj30/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj30/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj31/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj31/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj32/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj32/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj33/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj33/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj34/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj34/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj35/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj35/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj36/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj36/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj37/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj37/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj38/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj38/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj39/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj39/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj40/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj40/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj41/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj41/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj42/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj42/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj43/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj43/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj44/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj44/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj45/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj45/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj46/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj46/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj47/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj47/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj48/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj48/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj49/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj49/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj50/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj50/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj51/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj51/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj52/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj52/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj53/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj53/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj54/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj54/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj55/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj55/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj56/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj56/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj57/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj57/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj58/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj58/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj59/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj59/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj60/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj60/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj61/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj61/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj62/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj62/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj63/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj63/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj64/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj64/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj65/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj65/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj66/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj66/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj67/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj67/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj68/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj68/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj69/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj69/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj70/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj70/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj71/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj71/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj72/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj72/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj73/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj73/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj74/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj74/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj75/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj75/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj76/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj76/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj77/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj77/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj78/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj78/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj79/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj79/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj80/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj80/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj81/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj81/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj82/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj82/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj83/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj83/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj84/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj84/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj85/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj85/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj86/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj86/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj87/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj87/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj88/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj88/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj89/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj89/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj90/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj90/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj91/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj91/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj92/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj92/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj93/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj93/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj94/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj94/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj95/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj95/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj96/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj96/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj97/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj97/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj98/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj98/product_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj99/fep_050_0.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj99/product_qatoms.csv
