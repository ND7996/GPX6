# %%
import MDAnalysis as mda
import numpy as np
import pandas as pd
import os
import warnings
from MDAnalysis.analysis import align

# Suppress specific warnings
warnings.filterwarnings("ignore", category=UserWarning, module="MDAnalysis.topology.PDBParser")
warnings.filterwarnings("ignore", category=DeprecationWarning, module="MDAnalysis.coordinates.DCD")

# Function to process each trajectory and extract coordinates
def process_trajectory(traj_dir, pdb_file, dcd_file, residues_of_interest):
    # Check if the PDB file exists
    if not os.path.exists(pdb_file):
        print(f"PDB file not found: {pdb_file}")
        return None

    # Check if the DCD file exists
    if not os.path.exists(os.path.join(traj_dir, dcd_file)):
        print(f"DCD file not found: {os.path.join(traj_dir, dcd_file)}")
        return None

    # Load the trajectory and topology
    u = mda.Universe(pdb_file, os.path.join(traj_dir, dcd_file))

    # Select all atoms
    selection = u.select_atoms("all")

    # Optional: guess elements (if needed for further analysis)
    # u.add_TopologyAttr('elements')  # Uncomment this if you need to guess elements based on atom names.

    # RMSD alignment to the first frame to remove global rotation/translation
    align.AlignTraj(u, u, select="all", in_memory=True).run()

    # Initialize a list to accumulate the positions
    data = []

    # Loop over each frame and accumulate the positions
    for ts in u.trajectory:
        positions = selection.positions
        for atom in selection.atoms:
            res_name = atom.resname
            res_id = atom.resid
            atom_name = atom.name
            coord = positions[atom.index]
            data.append([res_name, res_id, atom_name, *coord])

    # Convert to a DataFrame
    df = pd.DataFrame(data, columns=['Residue', 'Residue_ID', 'Atom', 'X', 'Y', 'Z'])

    # Filter for the specific residues of interest
    filtered_df = df[df.apply(lambda row: f"{row['Residue']} {row['Residue_ID']}" in residues_of_interest, axis=1)]

    # Calculate the average coordinates
    avg_df = filtered_df.groupby(['Residue', 'Residue_ID', 'Atom']).mean().reset_index()

    return avg_df

# Main function to automate across multiple trajectory folders
def automate_trajectory_processing(base_dir, residues_of_interest):
    pdb_file = os.path.join(base_dir, "minim.pdb")
    
    # Check if the PDB file exists
    if not os.path.exists(pdb_file):
        print(f"PDB file not found: {pdb_file}")
        return

    for i in range(100):  # For folders traj00 to traj99
        traj_dir = os.path.join(base_dir, f"traj{i:02d}")
        dcd_file = "fep_000_1.000.dcd"
        
        if os.path.exists(os.path.join(traj_dir, dcd_file)):
            print(f"Processing: {traj_dir}/{dcd_file}")
            avg_df = process_trajectory(traj_dir, pdb_file, dcd_file, residues_of_interest)
            
            if avg_df is not None:
                # Save the result to a CSV file
                output_csv = os.path.join(traj_dir, "reactant_qatoms.csv")
                avg_df.to_csv(output_csv, index=False)
                print(f"Saved: {output_csv}")
            else:
                print(f"Skipping: {traj_dir} due to missing files or processing error.")
        else:
            print(f"File not found: {traj_dir}/{dcd_file}")

# Example usage
base_dir = "./analysis_scripts/mouseWT"
residues_of_interest = ["CYS 49", "GLN 83", "PRX 196"]

# Run the automated processing across all traj00 to traj99 folders
automate_trajectory_processing(base_dir, residues_of_interest)
# Out:
# Processing: ./analysis_scripts/mouseWT/traj00/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj00/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj01/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj01/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj02/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj02/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj03/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj03/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj04/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj04/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj05/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj05/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj06/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj06/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj07/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj07/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj08/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj08/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj09/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj09/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj10/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj10/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj11/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj11/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj12/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj12/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj13/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj13/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj14/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj14/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj15/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj15/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj16/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj16/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj17/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj17/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj18/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj18/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj19/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj19/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj20/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj20/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj21/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj21/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj22/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj22/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj23/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj23/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj24/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj24/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj25/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj25/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj26/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj26/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj27/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj27/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj28/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj28/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj29/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj29/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj30/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj30/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj31/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj31/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj32/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj32/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj33/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj33/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj34/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj34/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj35/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj35/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj36/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj36/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj37/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj37/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj38/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj38/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj39/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj39/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj40/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj40/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj41/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj41/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj42/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj42/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj43/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj43/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj44/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj44/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj45/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj45/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj46/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj46/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj47/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj47/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj48/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj48/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj49/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj49/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj50/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj50/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj51/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj51/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj52/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj52/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj53/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj53/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj54/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj54/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj55/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj55/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj56/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj56/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj57/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj57/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj58/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj58/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj59/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj59/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj60/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj60/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj61/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj61/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj62/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj62/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj63/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj63/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj64/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj64/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj65/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj65/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj66/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj66/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj67/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj67/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj68/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj68/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj69/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj69/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj70/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj70/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj71/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj71/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj72/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj72/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj73/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj73/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj74/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj74/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj75/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj75/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj76/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj76/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj77/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj77/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj78/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj78/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj79/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj79/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj80/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj80/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj81/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj81/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj82/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj82/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj83/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj83/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj84/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj84/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj85/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj85/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj86/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj86/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj87/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj87/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj88/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj88/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj89/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj89/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj90/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj90/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj91/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj91/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj92/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj92/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj93/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj93/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj94/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj94/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj95/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj95/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj96/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj96/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj97/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj97/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj98/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj98/reactant_qatoms.csv
# Processing: ./analysis_scripts/mouseWT/traj99/fep_000_1.000.dcd
# Saved: ./analysis_scripts/mouseWT/traj99/reactant_qatoms.csv
